# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as datetime
import os

# %%
# load data
path = "./Data/SDG_Data_File_Daily.csv"
df_sdg = pd.read_csv(path, index_col=0)

df_sdg.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#     Timestamp Ticker          ISIN              Company_Name  GICS Sector  \
# 0  2013-04-01      A  US00846U1016  agilent technologies inc  Health Care
# 1  2013-04-02      A  US00846U1016  agilent technologies inc  Health Care
# 2  2013-04-03      A  US00846U1016  agilent technologies inc  Health Care
# 3  2013-04-04      A  US00846U1016  agilent technologies inc  Health Care
# 4  2013-04-05      A  US00846U1016  agilent technologies inc  Health Care
#
#    SDG_1  SDG_2  SDG_3  SDG_4  SDG_5  ...  SDG_9_News_Volume  \
# 0    NaN    NaN    NaN    NaN    NaN  ...                NaN
# 1    NaN    NaN    NaN    NaN    NaN  ...                NaN
# 2    NaN    NaN    NaN    NaN    NaN  ...                NaN
# ...

# %%
path = "./Data/SDG_Adjusted_File_Daily.csv"
df_sdg_adj = pd.read_csv(path, index_col=0)

df_sdg_adj.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#     Timestamp Ticker          ISIN              Company_Name  GICS Sector  \
# 0  2013-04-01      A  US00846U1016  agilent technologies inc  Health Care
# 1  2013-04-02      A  US00846U1016  agilent technologies inc  Health Care
# 2  2013-04-03      A  US00846U1016  agilent technologies inc  Health Care
# 3  2013-04-04      A  US00846U1016  agilent technologies inc  Health Care
# 4  2013-04-05      A  US00846U1016  agilent technologies inc  Health Care
#
#    SDG_1_ADJ  SDG_2_ADJ  SDG_3_ADJ  SDG_4_ADJ  SDG_5_ADJ  ...  \
# 0        NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN  ...
# 2        NaN        NaN        NaN        NaN        NaN  ...
# ...

# %%
path = "./Data/Sentiment_Data_File_Daily.csv"
df_sent = pd.read_csv(path, index_col=0)

df_sent.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#     Timestamp Ticker          ISIN      Company_Name  GICS Sector  Sentiment  \
# 0  2013-04-01    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 1  2013-04-02    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 2  2013-04-03    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 3  2013-04-04    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 4  2013-04-05    AOS  US8318652091  a. o. smith corp  Industrials        NaN
#
#    STS  LTS  Sentiment_STD  Sentiment_News_Volume
# 0  NaN  NaN            NaN                    NaN
# 1  NaN  NaN            NaN                    NaN
# 2  NaN  NaN            NaN                    NaN
# 3  NaN  NaN            NaN                    NaN
# ...

# %%
# get tickers from df_sdg
tickers = df_sdg['Ticker'].unique().tolist()
len(tickers)
# Out:
# 622

# %%
# get price
start = '2017-01-03'
df_price = yf.download(tickers, start)['Adj Close']
# Out:
# [*********************100%***********************]  622 of 622 completed
#
# 58 Failed downloads:
# - AGN: No data found, symbol may be delisted
# - XEC: No data found, symbol may be delisted
# - WLTW: No data found, symbol may be delisted
# - EV: No data found, symbol may be delisted
# - COG: No data found, symbol may be delisted
# - DISCA: No data found, symbol may be delisted
# - CREE: No data found, symbol may be delisted
# - QEP: No data found, symbol may be delisted
# - WBC: No data found, symbol may be delisted
# - SYMC: No data found, symbol may be delisted
# - TIF: No data found, symbol may be delisted
# - NBL: No data found, symbol may be delisted
# - CBS: No data found, symbol may be delisted
# - GRA: No data found, symbol may be delisted
# - MYL: No data found, symbol may be delisted
# - ADS: No data found, symbol may be delisted
# - CELG: No data found, symbol may be delisted
# - VER: No data found, symbol may be delisted
# - VAR: No data found, symbol may be delisted
# ...

# %%
# clear delisted symbles and symbles with na value
df_price = df_price.dropna(axis=1)
df_price
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# Date
# 2017-01-03   44.510498  44.741234  163.169724   27.257643   48.673813
# 2017-01-04   45.094524  45.127769  164.508743   27.227139   49.360134
# 2017-01-05   44.558376  44.345024  164.393982   27.365593   49.734489
# 2017-01-06   45.946640  44.654255  162.241959   27.670675   49.750088
# 2017-01-09   46.090256  45.494968  162.146332   27.924120   50.077648
# ...                ...        ...         ...         ...         ...
# 2022-06-27  120.356819  13.560000  183.630005  141.660004  153.139999
# 2022-06-28  116.853020  13.500000  178.750000  137.440002  152.490005
# 2022-06-29  117.691544  13.030000  176.720001  139.229996  154.139999
# 2022-06-30  118.559998  12.680000  173.089996  136.720001  153.160004
# 2022-07-01  119.209999  13.130000  173.639999  138.929993  153.800003
#
#                    ABC         ABT       ACGL         ACN        ADBE  ...  \
# ...

# %%
# 542 remains in tickers
tickers = df_price.columns
len(tickers)
# Out:
# 542

# %%
symbol = yf.Ticker("msft").info
symbol["trailingPE"]
# Out:
# 27.096033

# %%
symbol["priceToBook"]
# Out:
# 11.922104

# %%
dict_PE = {}
dict_PB = {}

for company in tickers:
    symbol = yf.Ticker(company).info
    if "forwardPE" in symbol:
        dict_PE[company]= symbol["forwardPE"]
    if "priceToBook" in symbol:
        dict_PB[company]= symbol["priceToBook"]
# Out:
# Empty DataFrame
# Columns: [A, AAL, AAP, AAPL, ABBV, ABC, ABT, ACGL, ACN, ADBE, ADI, ADM, ADP, ADSK]
# Index: []

# %%
dict_PB
# Out:
# {'A': 6.6851726,
#  'AAL': None,
#  'AAP': 3.361013,
#  'AAPL': 36.170265,
#  'ABBV': 20.065231,
#  'ABC': 133.40169,
#  'ABT': 5.6621804,
#  'ACGL': 1.4110675,
#  'ACN': 8.715838,
#  'ADBE': 11.853568,
#  'ADI': 1.9760513,
#  'ADM': 1.9442255,
#  'ADP': 16.817572,
#  'ADSK': 29.913973,
#  'AEE': 2.4520574,
#  'AEP': 2.2140596,
#  'AES': 5.8720613,
#  'AFG': 2.3075929,
#  'AFL': 1.1110234,
#  'AGCO': 2.3762517,
#  'AIG': 0.6753564,
#  'AIZ': 1.753349,
#  'AJG': 4.0526304,
#  'AKAM': 3.2651615,
#  'ALB': 4.2144294,
#  'ALGN': 5.54574,
#  'ALKS': 4.5029497,
#  'ALL': 1.5203154,
#  'ALLE': 10.338349,
#  'ALLY': 0.7989534,
#  'ALNY': 23.431326,
#  'ALV': 2.4858081,
#  'AMAT': 6.2833214,
#  'AMD': 12.5118885,
#  'AME': 3.931431,
#  'AMG': 1.8228377,
#  'AMGN': 16.88441,
#  'AMP': 4.686755,
#  'AMT': 21.74718,
#  'AMZN': 0.46072522,
#  'AN': 3.1930692,
#  'ANET': 7.4323683,
#  'ANSS': 4.8274546,
#  'ANTM': 3.2793322,
#  'AON': 27.455147,
#  'AOS': 4.702081,
#  'APA': None,
# ...

# %%
dict_PE
# Out:
# {'A': 25.36383,
#  'AAL': -119.36364,
#  'AAP': 13.285387,
#  'AAPL': 22.480581,
#  'ABBV': 11.009306,
#  'ABC': 12.479511,
#  'ABT': 23.155462,
#  'ACGL': 12.156085,
#  'ACN': 26.856459,
#  'ADBE': 22.675694,
#  'ADI': 16.793184,
#  'ADM': 15.985355,
#  'ADP': 28.544846,
#  'ADSK': 25.455345,
#  'AEE': 22.819307,
#  'AEP': 19.70825,
#  'AES': 13.018182,
#  'AFG': 14.447823,
#  'AFL': 10.671727,
#  'AGCO': 9.601146,
#  'AIG': 9.705224,
#  'AIZ': 14.474772,
#  'AJG': 27.576216,
#  'AKAM': 15.508418,
#  'ALB': 34.363483,
#  'ALGN': 18.4307,
#  'ALKS': 71,
#  'ALL': 12.306968,
#  'ALLE': 17.414337,
#  'ALLY': 4.7302904,
#  'ALNY': -37.81888,
#  'ALV': 9.971194,
#  'AMAT': 9.748022,
#  'AMD': 22.056887,
#  'AME': 20.679035,
#  'AMG': 5.716157,
#  'AMGN': 13.679666,
#  'AMP': 9.657874,
#  'AMT': 47.326004,
#  'AMZN': 2.12614,
#  'AN': 6.453625,
#  'ANET': 27.15407,
#  'ANSS': 30.25063,
#  'ANTM': 16.843979,
#  'AON': 20.941896,
#  'AOS': 16.146973,
#  'APA': None,
#  'APD': 20.659575,
# ...
