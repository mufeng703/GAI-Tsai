# %%
import numpy as np
import pandas as pd
from ib_insync import *
from ib_insync.contract import Contract
from bs4 import BeautifulSoup as bs

# %% [markdown]
# 1) Interactive Brokers (IB); 2) ISIN datasets; 3)FIGI datasets; 4)EOD dataset;

# %%
util.startLoop()  # uncomment this line when in a notebook

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=412)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=412>

# %%
path = "./LIst of 19.7 Stocks with FIGI if available - By Evelyn.xlsx"

df_stockList = pd.read_excel(path, index_col=0)  
df_stockList.head()
# Out:
#   symbol_x            longName     Exchange                   Country  \
# 0      1ST       1ST GROUP LTD          ASX                 Australia
# 1     TWOU              2U INC       NASDAQ  United States of America
# 2     DDDX  3DX INDUSTRIES INC         PINK  United States of America
# 3      MMM               3M CO  US Exchange                    Mexico
# 4      88E       88 ENERGY LTD          LSE            United Kingdom
#
#                     country           name      full_name          isin  \
# 0                 australia            NaN            NaN           NaN
# 1  united states of america            NaN            NaN           NaN
# 2  united states of america            NaN            NaN           NaN
# 3                    mexico            NaN            NaN           NaN
# 4            united kingdom  88 Energy Ltd  88 Energy Ltd  AU00000088E2
#
#   currency_x currency_y  ...             Country_Final Code          figi  \
# 0        NaN        AUD  ...                 Australia  1.0  BBG008HNLRF4
# 1        NaN        USD  ...  United States of America  1.0  BBG001KS9450
# 2        NaN        USD  ...  United States of America  1.0  BBG000C129N6
# 3        NaN        NaN  ...                       NaN  NaN           NaN
# 4        GBP        GBP  ...            United Kingdom  1.0  BBG000C4PMQ3
#
#   compositeFIGI shareClassFIGI exchCode marketSector securityDescription  \
# 0  BBG008HNLRF4   BBG008HNLRG3       AU       Equity                 1ST
# 1  BBG001KS9450   BBG001V0RR30       US       Equity                TWOU
# 2  BBG000C129N6   BBG001STRH79       US       Equity                DDDX
# 3           NaN            NaN      NaN          NaN                 NaN
# 4  BBG000C4PMQ3   BBG001SCV1F7       AU       Equity                 88E
#
#    securityType securityType2
# 0  Common Stock  Common Stock
# 1  Common Stock  Common Stock
# 2  Common Stock  Common Stock
# 3           NaN           NaN
# 4  Common Stock  Common Stock
#
# [5 rows x 27 columns]

# %%
# stock = Stock('AMD', 'SMART', 'USD')
isinList = []

for index, row in df_stockList.iterrows():
    try:
        stock = Stock(row['symbol_x'])
        fundamentals = ib.reqFundamentalData(stock, 'ReportSnapshot')

        content = bs(fundamentals, "xml")
        ISIN = content.find(Type='ISIN').getText()
        print(ISIN)
    except:
        ISIN = None

    
    isinList.append(ISIN)
# Out:
# Error 200, reqId 3: The contract description specified for 1ST is ambiguous;
# you must specify the currency., contract: Stock(symbol='1ST')
# Error 200, reqId 4: The contract description specified for TWOU is ambiguous;
# you must specify the currency., contract: Stock(symbol='TWOU')
# Error 200, reqId 5: The contract description specified for DDDX is ambiguous;
# you must specify the currency., contract: Stock(symbol='DDDX')
# Error 200, reqId 6: The contract description specified for MMM is ambiguous;
# you must specify the currency., contract: Stock(symbol='MMM')
# Error 200, reqId 7: The contract description specified for 88E is ambiguous;
# you must specify the currency., contract: Stock(symbol='88E')
# Error 200, reqId 9: The contract description specified for 7063 is ambiguous;
# you must specify the currency., contract: Stock(symbol='7063')
# Error 200, reqId 10: The contract description specified for AMKBY is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMKBY')
# Error 200, reqId 11: The contract description specified for MLATV is ambiguous;
# you must specify the currency., contract: Stock(symbol='MLATV')
# Error 200, reqId 12: The contract description specified for AMRK is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMRK')
# Error 200, reqId 13: The contract description specified for AKH is ambiguous;
# you must specify the currency., contract: Stock(symbol='AKH')
# Error 200, reqId 15: No security definition has been found for the request, contract: Stock(symbol='AACH')
# SG1S12926576
# Error 200, reqId 17: The contract description specified for 2686 is ambiguous;
# you must specify the currency., contract: Stock(symbol='2686')
# Error 200, reqId 18: The contract description specified for AAON is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAON')
# Error 200, reqId 19: The contract description specified for AAALY is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAALY')
# Error 200, reqId 21: The contract description specified for AAN is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAN')
# Error 200, reqId 22: The contract description specified for AARTIDRUG is ambiguous;
# you must specify the currency., contract: Stock(symbol='AARTIDRUG')
# INE721Z01010
# INE769A01020
# Error 200, reqId 25: The contract description specified for ABDP is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABDP')
# Error 200, reqId 26: The contract description specified for ABQQ is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABQQ')
# Error 200, reqId 27: The contract description specified for ABTO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABTO')
# Error 200, reqId 28: The contract description specified for ABP is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABP')
# INE216P01012
# Error 430, reqId 29: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ABKI')
# Error 200, reqId 31: The contract description specified for ATTBF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATTBF')
# INE421A01028
# Error 200, reqId 33: The contract description specified for ABB is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABB')
# Error 200, reqId 34: The contract description specified for ABB is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABB')
# Error 200, reqId 35: The contract description specified for ABA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABA')
# Error 200, reqId 36: The contract description specified for ABBY is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABBY')
# Error 200, reqId 38: The contract description specified for ABT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABT')
# Error 200, reqId 39: The contract description specified for ABBV is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABBV')
# Error 200, reqId 40: The contract description specified for ABBY is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABBY')
# Error 200, reqId 41: The contract description specified for 2670 is ambiguous;
# you must specify the currency., contract: Stock(symbol='2670')
# Error 200, reqId 42: The contract description specified for ABCE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABCE')
# Error 200, reqId 43: The contract description specified for ABMBF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABMBF')
# Error 200, reqId 44: The contract description specified for ABNAF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABNAF')
# Error 200, reqId 45: The contract description specified for ABEO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABEO')
# INE358A01014
# Error 200, reqId 46: The contract description specified for ANF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ANF')
# Error 200, reqId 47: The contract description specified for AAIF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAIF')
# Error 200, reqId 48: The contract description specified for FCO is ambiguous;
# you must specify the currency., contract: Stock(symbol='FCO')
# Error 430, reqId 49: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='GCH')
# Error 200, reqId 50: The contract description specified for IF is ambiguous;
# you must specify the currency., contract: Stock(symbol='IF')
# Error 200, reqId 51: The contract description specified for AABVF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AABVF')
# Error 430, reqId 52: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ISL')
# Error 200, reqId 53: The contract description specified for JEQ is ambiguous;
# you must specify the currency., contract: Stock(symbol='JEQ')
# Error 200, reqId 54: The contract description specified for AJIT is ambiguous;
# you must specify the currency., contract: Stock(symbol='AJIT')
# Error 200, reqId 55: The contract description specified for ANW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ANW')
# Error 200, reqId 56: No security definition has been found for the request, contract: Stock(symbol='APEF')
# Error 200, reqId 57: The contract description specified for AAS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAS')
# Error 200, reqId 58: The contract description specified for ASL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASL')
# Error 200, reqId 59: The contract description specified for ASIZ is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASIZ')
# Error 200, reqId 60: The contract description specified for ASIZ is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASIZ')
# Error 200, reqId 61: The contract description specified for ABL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABL')
# Error 200, reqId 63: The contract description specified for ABMD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABMD')
# Error 430, reqId 64: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='RZZ')
# Error 200, reqId 65: The contract description specified for ABLE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABLE')
# Error 200, reqId 66: The contract description specified for 1627 is ambiguous;
# you must specify the currency., contract: Stock(symbol='1627')
# Error 200, reqId 67: The contract description specified for ABM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABM')
# Error 200, reqId 68: The contract description specified for ABN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABN')
# Error 200, reqId 69: The contract description specified for ABO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABO')
# Error 200, reqId 70: The contract description specified for ABTZY is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABTZY')
# Error 200, reqId 71: The contract description specified for 533 is ambiguous;
# you must specify the currency., contract: Stock(symbol='533')
# Error 200, reqId 72: The contract description specified for ABRA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABRA')
# Error 200, reqId 73: The contract description specified for AXAS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AXAS')
# Error 200, reqId 74: The contract description specified for ABG is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABG')
# SE0006256558
# Error 430, reqId 76: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ABRL')
# SG2C12961455
# SG1I02877971
# Error 430, reqId 79: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACEN')
# Error 200, reqId 80: The contract description specified for ACIU is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACIU')
# Error 200, reqId 81: No security definition has been found for the request, contract: Stock(symbol='AJC')
# Error 430, reqId 82: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACIA')
# Error 200, reqId 83: The contract description specified for ACCA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACCA')
# Error 200, reqId 84: The contract description specified for ACA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACA')
# Error 430, reqId 85: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACPH')
# Error 200, reqId 86: The contract description specified for ACTG is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACTG')
# Error 200, reqId 87: The contract description specified for AKG is ambiguous;
# you must specify the currency., contract: Stock(symbol='AKG')
# Error 200, reqId 88: The contract description specified for ACHC is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACHC')
# Error 200, reqId 89: The contract description specified for ACAD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACAD')
# Error 200, reqId 90: The contract description specified for AKR is ambiguous;
# you must specify the currency., contract: Stock(symbol='AKR')
# Error 200, reqId 91: The contract description specified for ADN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADN')
# Error 430, reqId 92: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACAMU')
# Error 200, reqId 93: The contract description specified for AEF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AEF')
# Error 200, reqId 94: The contract description specified for ACST is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACST')
# Error 200, reqId 95: The contract description specified for ACNV is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACNV')
# Error 430, reqId 96: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='XLRN')
# Error 200, reqId 97: The contract description specified for AXE is ambiguous;
# you must specify the currency., contract: Stock(symbol='AXE')
# Error 200, reqId 98: The contract description specified for ACCEL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACCEL')
# Error 430, reqId 99: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACLP')
# Error 200, reqId 101: The contract description specified for AX1 is ambiguous;
# you must specify the currency., contract: Stock(symbol='AX1')
# INE793A01012
# Error 430, reqId 102: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ABPI')
# Error 200, reqId 103: The contract description specified for ACN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACN')
# Error 200, reqId 104: The contract description specified for 4813 is ambiguous;
# you must specify the currency., contract: Stock(symbol='4813')
# Error 200, reqId 105: The contract description specified for 7042 is ambiguous;
# you must specify the currency., contract: Stock(symbol='7042')
# Error 200, reqId 106: The contract description specified for ACCR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACCR')
# Error 200, reqId 107: The contract description specified for ACSO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACSO')
# Error 200, reqId 108: The contract description specified for ACE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACE')
# Error 200, reqId 109: The contract description specified for ANA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ANA')
# Error 200, reqId 110: The contract description specified for ACCO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACCO')
# Error 200, reqId 112: The contract description specified for ACD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACD')
# Error 200, reqId 113: No security definition has been found for the request, contract: Stock(symbol='ADQU')
# Error 200, reqId 114: The contract description specified for 4395 is ambiguous;
# you must specify the currency., contract: Stock(symbol='4395')
# Error 200, reqId 115: The contract description specified for ACRL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACRL')
# Error 200, reqId 116: The contract description specified for AXS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AXS')
# FR0000120404
# Error 200, reqId 118: The contract description specified for ARAY is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARAY')
# Error 200, reqId 119: The contract description specified for ACW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACW')
# INE648Z01015
# Error 200, reqId 121: The contract description specified for ACRX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACRX')
# Error 200, reqId 122: The contract description specified for ACD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACD')
# Error 200, reqId 123: The contract description specified for ACID is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACID')
# Error 200, reqId 124: The contract description specified for ACER is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACER')
# Error 200, reqId 125: The contract description specified for ASPCF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASPCF')
# INE543V01017
# Error 200, reqId 127: No security definition has been found for the request, contract: Stock(symbol='AKAOQ')
# Error 200, reqId 128: The contract description specified for 1715 is ambiguous;
# you must specify the currency., contract: Stock(symbol='1715')
# Error 200, reqId 129: The contract description specified for 5142 is ambiguous;
# you must specify the currency., contract: Stock(symbol='5142')
# Error 200, reqId 130: The contract description specified for ADA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADA')
# SG1Q66923448
# Error 200, reqId 132: The contract description specified for ACIW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACIW')
# Error 200, reqId 133: The contract description specified for ACKB is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACKB')
# Error 200, reqId 134: The contract description specified for AKRFF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AKRFF')
# Error 200, reqId 135: The contract description specified for ACRS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACRS')
# Error 200, reqId 136: The contract description specified for ACMR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACMR')
# Error 200, reqId 137: The contract description specified for ACU is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACU')
# Error 200, reqId 138: The contract description specified for 6888 is ambiguous;
# you must specify the currency., contract: Stock(symbol='6888')
# Error 200, reqId 139: The contract description specified for ACNB is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACNB')
# Error 200, reqId 140: The contract description specified for 8572 is ambiguous;
# you must specify the currency., contract: Stock(symbol='8572')
# Error 200, reqId 141: The contract description specified for ACX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACX')
# Error 200, reqId 142: The contract description specified for ACOR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACOR')
# Error 200, reqId 143: The contract description specified for ACQ is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACQ')
# Error 200, reqId 144: The contract description specified for ACFN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACFN')
# Error 200, reqId 145: The contract description specified for AIF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AIF')
# Error 200, reqId 146: The contract description specified for ATV is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATV')
# Error 430, reqId 147: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACO')
# Error 430, reqId 148: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AIII')
# Error 430, reqId 149: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACRGF')
# Error 200, reqId 150: The contract description specified for 3823 is ambiguous;
# you must specify the currency., contract: Stock(symbol='3823')
# Error 200, reqId 151: The contract description specified for ACF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACF')
# Error 200, reqId 152: The contract description specified for ACT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACT')
# Error 200, reqId 154: The contract description specified for ATNM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATNM')
# Error 200, reqId 155: The contract description specified for ACW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACW')
# Error 200, reqId 156: The contract description specified for ACE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACE')
# Error 200, reqId 157: The contract description specified for AEG is ambiguous;
# you must specify the currency., contract: Stock(symbol='AEG')
# SE0009269467
# Error 430, reqId 158: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACARQ')
# Error 200, reqId 159: The contract description specified for 3279 is ambiguous;
# you must specify the currency., contract: Stock(symbol='3279')
# Error 200, reqId 160: The contract description specified for ATVI is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATVI')
# Error 200, reqId 161: The contract description specified for ACT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACT')
# Error 200, reqId 162: The contract description specified for AYI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AYI')
# Error 200, reqId 163: The contract description specified for AT is ambiguous;
# you must specify the currency., contract: Stock(symbol='AT')
# Error 200, reqId 164: The contract description specified for ACUR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACUR')
# Error 200, reqId 165: The contract description specified for GOLF is ambiguous;
# you must specify the currency., contract: Stock(symbol='GOLF')
# Error 200, reqId 166: The contract description specified for ACUS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACUS')
# Error 430, reqId 167: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADSYQ')
# Error 200, reqId 168: The contract description specified for ADA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADA')
# Error 200, reqId 169: The contract description specified for ADH is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADH')
# Error 200, reqId 170: The contract description specified for 1AD is ambiguous;
# you must specify the currency., contract: Stock(symbol='1AD')
# CNE0000004V0
# Error 430, reqId 172: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADAC')
# Error 200, reqId 173: No security definition has been found for the request, contract: Stock(symbol='ADAM')
# Error 430, reqId 174: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADMS')
# Error 200, reqId 175: The contract description specified for ADZ is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADZ')
# Error 200, reqId 176: The contract description specified for ADMP is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADMP')
# Error 200, reqId 177: The contract description specified for PEO is ambiguous;
# you must specify the currency., contract: Stock(symbol='PEO')
# Error 200, reqId 178: The contract description specified for ADA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADA')
# Error 200, reqId 180: No security definition has been found for the request, contract: Stock(symbol='ADANIGAS')
# INE423A01024
# Error 200, reqId 182: The contract description specified for ADANIPORT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADANIPORT')
# INE364U01010
# INE814H01011
# Error 200, reqId 185: The contract description specified for ADAP is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADAP')
# Error 200, reqId 186: The contract description specified for AATV is ambiguous;
# you must specify the currency., contract: Stock(symbol='AATV')
# Error 200, reqId 187: The contract description specified for ADPT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADPT')
# Error 200, reqId 188: The contract description specified for ADTM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADTM')
# Error 200, reqId 189: The contract description specified for ADOOY is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADOOY')
# Error 200, reqId 190: The contract description specified for 2685 is ambiguous;
# you must specify the currency., contract: Stock(symbol='2685')
# Error 200, reqId 191: The contract description specified for ADK is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADK')
# Error 200, reqId 192: The contract description specified for ADCO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADCO')
# Error 200, reqId 193: The contract description specified for ATXG is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATXG')
# Error 200, reqId 194: The contract description specified for APE is ambiguous;
# you must specify the currency., contract: Stock(symbol='APE')
# Error 200, reqId 195: The contract description specified for ADKO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADKO')
# INE931S01010
# Error 200, reqId 197: The contract description specified for ADUS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADUS')
# CNE000000DM5
# Error 200, reqId 199: The contract description specified for ADI1 is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADI1')
# Error 200, reqId 200: The contract description specified for 4401 is ambiguous;
# you must specify the currency., contract: Stock(symbol='4401')
# Error 200, reqId 201: The contract description specified for AYT is ambiguous;
# you must specify the currency., contract: Stock(symbol='AYT')
# Error 200, reqId 202: No security definition has been found for the request, contract: Stock(symbol='ADPAS')
# SG1I67883666
# Error 430, reqId 203: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADPTQ')
# Error 200, reqId 204: The contract description specified for ADES is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADES')
# Error 430, reqId 205: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='IOTS')
# Error 200, reqId 206: The contract description specified for ADE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADE')
# Error 200, reqId 208: The contract description specified for DRX is ambiguous;
# you must specify the currency., contract: Stock(symbol='DRX')
# Error 200, reqId 209: No security definition has been found for the request, contract: Stock(symbol='ADFT')
# Error 200, reqId 210: The contract description specified for ATRX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATRX')
# Error 200, reqId 211: The contract description specified for ADR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADR')
# Error 200, reqId 212: No security definition has been found for the request, contract: Stock(symbol='ADHUNIKIN')
# INE982B01019
# Error 430, reqId 213: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADHUNIK')
# Error 200, reqId 214: The contract description specified for ADIL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADIL')
# Error 200, reqId 215: The contract description specified for ADSN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADSN')
# Error 200, reqId 216: The contract description specified for ADDYY is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADDYY')
# Error 200, reqId 217: The contract description specified for ADNT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADNT')
# Error 200, reqId 218: The contract description specified for ADKT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADKT')
# INE674K01013
# Error 200, reqId 221: The contract description specified for ADD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADD')
# Error 200, reqId 222: The contract description specified for ADMA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADMA')
# Error 200, reqId 223: The contract description specified for ADJ is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADJ')
# Error 200, reqId 224: The contract description specified for ADBE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADBE')
# Error 200, reqId 225: No security definition has been found for the request, contract: Stock(symbol='ADOM')
# INE865C01022
# INE045A01017
# Error 200, reqId 228: The contract description specified for ADT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADT')
# FR0010340141
# INE737B01033
# Error 200, reqId 231: No security definition has been found for the request, contract: Stock(symbol='ADT.4')
# Error 200, reqId 232: The contract description specified for ATGE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATGE')
# Error 200, reqId 233: The contract description specified for 6668 is ambiguous;
# you must specify the currency., contract: Stock(symbol='6668')
# Error 200, reqId 234: The contract description specified for ADTN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADTN')
# Error 200, reqId 235: No security definition has been found for the request, contract: Stock(symbol='ADRO')
# Error 200, reqId 236: The contract description specified for ADVN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADVN')
# Error 200, reqId 237: The contract description specified for AAP is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAP')
# Error 200, reqId 238: The contract description specified for 3773 is ambiguous;
# you must specify the currency., contract: Stock(symbol='3773')
# Error 200, reqId 239: The contract description specified for AMD is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMD')
# Error 200, reqId 241: The contract description specified for 5998 is ambiguous;
# you must specify the currency., contract: Stock(symbol='5998')
# SG1CJ7000006
# Error 200, reqId 243: The contract description specified for ASIX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASIX')
# INE199C01026
# Error 430, reqId 244: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AVLIF')
# Error 430, reqId 245: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AVLIF')
# Error 200, reqId 246: The contract description specified for AAVVF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAVVF')
# Error 200, reqId 247: The contract description specified for 8769 is ambiguous;
# you must specify the currency., contract: Stock(symbol='8769')
# Error 200, reqId 248: The contract description specified for AOC is ambiguous;
# you must specify the currency., contract: Stock(symbol='AOC')
# Error 200, reqId 249: The contract description specified for ADGO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADGO')
# Error 200, reqId 250: The contract description specified for 6857 is ambiguous;
# you must specify the currency., contract: Stock(symbol='6857')
# Error 200, reqId 251: The contract description specified for ADVT is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADVT')
# Error 200, reqId 252: The contract description specified for ADXS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADXS')
# Error 200, reqId 253: The contract description specified for 6030 is ambiguous;
# you must specify the currency., contract: Stock(symbol='6030')
# Error 200, reqId 254: The contract description specified for ADZN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADZN')
# Error 430, reqId 255: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADV2')
# Error 200, reqId 256: The contract description specified for ADVM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADVM')
# Error 200, reqId 257: No security definition has been found for the request, contract: Stock(symbol='ADVIC')
# Error 200, reqId 258: The contract description specified for AADR is ambiguous;
# you must specify the currency., contract: Stock(symbol='AADR')
# Error 200, reqId 259: The contract description specified for FNG is ambiguous;
# you must specify the currency., contract: Stock(symbol='FNG')
# Error 200, reqId 260: The contract description specified for ADH is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADH')
# Error 200, reqId 261: The contract description specified for 2489 is ambiguous;
# you must specify the currency., contract: Stock(symbol='2489')
# Error 200, reqId 262: The contract description specified for GHU is ambiguous;
# you must specify the currency., contract: Stock(symbol='GHU')
# Error 200, reqId 263: The contract description specified for ADYX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADYX')
# Error 200, reqId 265: The contract description specified for ACM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACM')
# Error 200, reqId 266: The contract description specified for AED is ambiguous;
# you must specify the currency., contract: Stock(symbol='AED')
# CNE000000RM5
# Error 430, reqId 267: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AEGN')
# Error 200, reqId 269: The contract description specified for AGLE is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGLE')
# INE208C01025
# Error 430, reqId 270: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AEB')
# Error 200, reqId 271: The contract description specified for AWX is ambiguous;
# you must specify the currency., contract: Stock(symbol='AWX')
# Error 200, reqId 272: The contract description specified for AMTX is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMTX')
# Error 200, reqId 273: The contract description specified for AOLS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AOLS')
# Error 200, reqId 275: No security definition has been found for the request, contract: Stock(symbol='0900')
# Error 200, reqId 276: The contract description specified for 8570 is ambiguous;
# you must specify the currency., contract: Stock(symbol='8570')
# Error 200, reqId 278: The contract description specified for 8905 is ambiguous;
# you must specify the currency., contract: Stock(symbol='8905')
# Error 200, reqId 279: The contract description specified for AML is ambiguous;
# you must specify the currency., contract: Stock(symbol='AML')
# Error 200, reqId 280: No security definition has been found for the request, contract: Stock(symbol='0984')
# Error 200, reqId 281: The contract description specified for AQSZF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AQSZF')
# Error 200, reqId 282: The contract description specified for AER is ambiguous;
# you must specify the currency., contract: Stock(symbol='AER')
# Error 200, reqId 283: The contract description specified for AERI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AERI')
# Error 200, reqId 284: The contract description specified for AEI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AEI')
# Error 200, reqId 285: The contract description specified for AIS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AIS')
# Error 200, reqId 286: The contract description specified for AKOM is ambiguous;
# you must specify the currency., contract: Stock(symbol='AKOM')
# Error 430, reqId 287: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AERP')
# Error 200, reqId 288: No security definition has been found for the request, contract: Stock(symbol='ACY')
# Error 200, reqId 289: The contract description specified for ARX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARX')
# Error 200, reqId 290: The contract description specified for AFLT is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFLT')
# Error 430, reqId 291: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AERZY')
# Error 200, reqId 292: The contract description specified for AJRD is ambiguous;
# you must specify the currency., contract: Stock(symbol='AJRD')
# Error 430, reqId 293: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='600677')
# CNE000000Y86
# CNE000001857
# Error 430, reqId 296: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AOTL')
# Error 200, reqId 297: The contract description specified for AVAV is ambiguous;
# you must specify the currency., contract: Stock(symbol='AVAV')
# Error 200, reqId 298: No security definition has been found for the request, contract: Stock(symbol='ARPO')
# Error 200, reqId 299: The contract description specified for AES is ambiguous;
# you must specify the currency., contract: Stock(symbol='AES')
# Error 200, reqId 300: The contract description specified for 8341 is ambiguous;
# you must specify the currency., contract: Stock(symbol='8341')
# Error 200, reqId 301: The contract description specified for AEZS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AEZS')
# Error 200, reqId 303: The contract description specified for AET is ambiguous;
# you must specify the currency., contract: Stock(symbol='AET')
# Error 200, reqId 304: The contract description specified for HE8 is ambiguous;
# you must specify the currency., contract: Stock(symbol='HE8')
# Error 200, reqId 305: The contract description specified for HE8 is ambiguous;
# you must specify the currency., contract: Stock(symbol='HE8')
# Error 200, reqId 307: The contract description specified for AEVS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AEVS')
# Error 430, reqId 306: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='GNMX')
# Error 200, reqId 309: The contract description specified for AFRK is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFRK')
# Error 200, reqId 310: The contract description specified for AFC is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFC')
# SG1C01001033
# Error 200, reqId 312: The contract description specified for ACS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACS')
# Error 200, reqId 313: The contract description specified for AMG is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMG')
# Error 200, reqId 314: The contract description specified for ABVG is ambiguous;
# you must specify the currency., contract: Stock(symbol='ABVG')
# IL0005780130
# Error 430, reqId 315: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AEB')
# Error 200, reqId 316: The contract description specified for AFYG is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFYG')
# Error 200, reqId 317: The contract description specified for AFF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFF')
# Error 430, reqId 318: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFFN')
# Error 200, reqId 319: The contract description specified for AFI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFI')
# Error 430, reqId 320: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFFMQ')
# Error 200, reqId 321: The contract description specified for 1466 is ambiguous;
# you must specify the currency., contract: Stock(symbol='1466')
# Error 200, reqId 322: The contract description specified for AFFY is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFFY')
# Error 200, reqId 323: No security definition has been found for the request, contract: Stock(symbol='AFHP')
# Error 200, reqId 324: The contract description specified for AFID is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFID')
# Error 200, reqId 325: The contract description specified for AFL is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFL')
# Error 200, reqId 326: The contract description specified for AFR is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFR')
# Error 200, reqId 327: The contract description specified for HPMCF is ambiguous;
# you must specify the currency., contract: Stock(symbol='HPMCF')
# Error 200, reqId 328: The contract description specified for AFGC is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFGC')
# Error 200, reqId 330: The contract description specified for AOIFF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AOIFF')
# IL0010979487
# Error 430, reqId 331: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACCS')
# Error 200, reqId 332: The contract description specified for AFR is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFR')
# Error 200, reqId 333: The contract description specified for AGGFF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGGFF')
# Error 200, reqId 334: The contract description specified for A1G is ambiguous;
# you must specify the currency., contract: Stock(symbol='A1G')
# Error 430, reqId 335: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFMCF')
# Error 200, reqId 336: The contract description specified for AMLZF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMLZF')
# Error 200, reqId 337: The contract description specified for ARI is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARI')
# Error 200, reqId 338: The contract description specified for ATM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATM')
# Error 200, reqId 339: The contract description specified for AFTM is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFTM')
# Error 430, reqId 340: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFY')
# Error 200, reqId 341: The contract description specified for AGGZF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGGZF')
# Error 200, reqId 342: The contract description specified for MITT is ambiguous;
# you must specify the currency., contract: Stock(symbol='MITT')
# Error 200, reqId 344: The contract description specified for 5201 is ambiguous;
# you must specify the currency., contract: Stock(symbol='5201')
# Error 200, reqId 345: No security definition has been found for the request, contract: Stock(symbol='AGCNET')
# Error 200, reqId 346: The contract description specified for AGCO is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGCO')
# Error 200, reqId 347: The contract description specified for UAVS is ambiguous;
# you must specify the currency., contract: Stock(symbol='UAVS')
# Error 200, reqId 348: The contract description specified for AU1 is ambiguous;
# you must specify the currency., contract: Stock(symbol='AU1')
# Error 200, reqId 349: The contract description specified for AIFS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AIFS')
# INE204E01012
# Error 430, reqId 350: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGMC')
# Error 200, reqId 351: The contract description specified for AGEN is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGEN')
# Error 200, reqId 352: The contract description specified for AGE is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGE')
# Error 200, reqId 353: The contract description specified for AGFMF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGFMF')
# Error 200, reqId 354: The contract description specified for AFGVY is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFGVY')
# Error 430, reqId 355: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGK')
# Error 200, reqId 357: The contract description specified for AGRX is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGRX')
# Error 200, reqId 358: The contract description specified for A is ambiguous;
# you must specify the currency., contract: Stock(symbol='A')
# Error 200, reqId 359: No security definition has been found for the request, contract: Stock(symbol='AGLY')
# Error 200, reqId 360: The contract description specified for AGYS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGYS')
# Error 200, reqId 361: The contract description specified for AGIO is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGIO')
# Error 200, reqId 362: The contract description specified for AGI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGI')
# Error 200, reqId 363: The contract description specified for AJX is ambiguous;
# you must specify the currency., contract: Stock(symbol='AJX')
# Error 200, reqId 364: The contract description specified for AGL is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGL')
# Error 200, reqId 365: The contract description specified for GAS is ambiguous;
# you must specify the currency., contract: Stock(symbol='GAS')
# Error 200, reqId 366: The contract description specified for AGMH is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGMH')
# Error 200, reqId 367: The contract description specified for AGNCM is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGNCM')
# Error 200, reqId 368: The contract description specified for AGNCM is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGNCM')
# Error 200, reqId 369: The contract description specified for AEM is ambiguous;
# you must specify the currency., contract: Stock(symbol='AEM')
# Error 430, reqId 370: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGHI')
# Error 200, reqId 371: The contract description specified for 9704 is ambiguous;
# you must specify the currency., contract: Stock(symbol='9704')
# Error 200, reqId 372: The contract description specified for 3467 is ambiguous;
# you must specify the currency., contract: Stock(symbol='3467')
# Error 430, reqId 373: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='GRO')
# Error 200, reqId 375: The contract description specified for AGJ is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGJ')
# Error 200, reqId 376: The contract description specified for EURI is ambiguous;
# you must specify the currency., contract: Stock(symbol='EURI')
# Error 200, reqId 377: The contract description specified for AMN is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMN')
# Error 200, reqId 378: The contract description specified for ANO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ANO')
# Error 200, reqId 379: The contract description specified for AGRO is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGRO')
# CNE100000Q43
# Error 430, reqId 380: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='FBER')
# Error 200, reqId 381: The contract description specified for AGTK is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGTK')
# Error 200, reqId 382: The contract description specified for AGTA is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGTA')
# Error 200, reqId 383: No security definition has been found for the request, contract: Stock(symbol='1131')
# Error 430, reqId 384: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGU')
# Error 200, reqId 385: The contract description specified for ACMB is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACMB')
# INE740V01019
# Error 200, reqId 388: The contract description specified for 4955 is ambiguous;
# you must specify the currency., contract: Stock(symbol='4955')
# Error 200, reqId 389: The contract description specified for AGFS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGFS')
# Error 200, reqId 390: The contract description specified for AGL is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGL')
# Error 200, reqId 391: The contract description specified for AGT is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGT')
# Error 200, reqId 392: No security definition has been found for the request, contract: Stock(symbol='AGGL')
# Error 200, reqId 393: The contract description specified for 8279 is ambiguous;
# you must specify the currency., contract: Stock(symbol='8279')
# INE209A01019
# Error 200, reqId 395: The contract description specified for AGL is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGL')
# ...
# you must specify the currency., contract: Stock(symbol='RCUS')
# Error 200, reqId 1223: The contract description specified for ADG is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADG')
# Error 200, reqId 1224: The contract description specified for AWX is ambiguous;
# you must specify the currency., contract: Stock(symbol='AWX')
# Error 200, reqId 1225: The contract description specified for ARD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARD')
# Error 200, reqId 1226: The contract description specified for ARL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARL')
# Error 200, reqId 1227: The contract description specified for ARDX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARDX')
# Error 200, reqId 1228: The contract description specified for ALG is ambiguous;
# you must specify the currency., contract: Stock(symbol='ALG')
# CNE000000784
# Error 200, reqId 1229: The contract description specified for ADV is ambiguous;
# you must specify the currency., contract: Stock(symbol='ADV')
# Error 200, reqId 1230: The contract description specified for ASC is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASC')
# Error 200, reqId 1231: The contract description specified for 8912 is ambiguous;
# you must specify the currency., contract: Stock(symbol='8912')
# Error 200, reqId 1232: The contract description specified for ARPC is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARPC')
# Error 200, reqId 1233: The contract description specified for ARNA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARNA')
# Error 200, reqId 1234: No security definition has been found for the request, contract: Stock(symbol='0645')
# Error 200, reqId 1235: The contract description specified for ARCC is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARCC')
# Error 200, reqId 1236: The contract description specified for ACRE is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACRE')
# Error 200, reqId 1237: The contract description specified for ARES is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARES')
# Error 200, reqId 1238: The contract description specified for ARET is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARET')
# Error 200, reqId 1239: The contract description specified for AGX is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGX')
# Error 430, reqId 1240: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ANGYF')
# Error 200, reqId 1241: The contract description specified for ARD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARD')
# Error 200, reqId 1242: The contract description specified for AGFX is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGFX')
# Error 430, reqId 1243: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGXMF')
# Error 200, reqId 1244: The contract description specified for ASL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASL')
# Error 430, reqId 1245: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='RGX.CAD')
# Error 200, reqId 1246: The contract description specified for ARB is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARB')
# Error 200, reqId 1248: The contract description specified for 7595 is ambiguous;
# you must specify the currency., contract: Stock(symbol='7595')
# Error 200, reqId 1249: The contract description specified for ARGO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARGO')
# Error 200, reqId 1250: The contract description specified for ARGD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARGD')
# Error 200, reqId 1251: The contract description specified for ARNGF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARNGF')
# Error 430, reqId 1252: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARGSQ')
# Error 200, reqId 1253: The contract description specified for AGY is ambiguous;
# you must specify the currency., contract: Stock(symbol='AGY')
# Error 200, reqId 1254: The contract description specified for ARGW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARGW')
# Error 200, reqId 1255: The contract description specified for ARGL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARGL')
# Error 200, reqId 1256: The contract description specified for ART is ambiguous;
# you must specify the currency., contract: Stock(symbol='ART')
# Error 430, reqId 1257: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARIA')
# Error 200, reqId 1258: The contract description specified for ARA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARA')
# Error 200, reqId 1259: The contract description specified for 2815 is ambiguous;
# you must specify the currency., contract: Stock(symbol='2815')
# Error 200, reqId 1260: The contract description specified for AAU is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAU')
# Error 200, reqId 1261: The contract description specified for DRRSF is ambiguous;
# you must specify the currency., contract: Stock(symbol='DRRSF')
# Error 430, reqId 1262: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ASNT')
# Error 200, reqId 1263: The contract description specified for ARDS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARDS')
# Error 200, reqId 1264: No security definition has been found for the request, contract: Stock(symbol='ACEZ')
# INE298I01015
# INE413D01011
# Error 200, reqId 1268: The contract description specified for ARM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARM')
# INE643K01018
# Error 430, reqId 1269: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARIONSDB')
# Error 200, reqId 1270: The contract description specified for ARGC is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARGC')
# Error 200, reqId 1271: The contract description specified for ANET is ambiguous;
# you must specify the currency., contract: Stock(symbol='ANET')
# Error 200, reqId 1272: The contract description specified for ASPW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASPW')
# Error 200, reqId 1273: The contract description specified for ASCC is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASCC')
# Error 200, reqId 1274: The contract description specified for ATZ is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATZ')
# Error 200, reqId 1275: The contract description specified for ARIX is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARIX')
# Error 200, reqId 1276: No security definition has been found for the request, contract: Stock(symbol='AZ1')
# Error 200, reqId 1277: The contract description specified for AZS is ambiguous;
# you must specify the currency., contract: Stock(symbol='AZS')
# Error 200, reqId 1278: No security definition has been found for the request, contract: Stock(symbol='ARJOB')
# Error 430, reqId 1279: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARJ')
# Error 200, reqId 1280: The contract description specified for AHK is ambiguous;
# you must specify the currency., contract: Stock(symbol='AHK')
# Error 200, reqId 1281: The contract description specified for ARKR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARKR')
# Error 200, reqId 1282: The contract description specified for AKVA is ambiguous;
# you must specify the currency., contract: Stock(symbol='AKVA')
# Error 200, reqId 1284: The contract description specified for ARKO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARKO')
# Error 200, reqId 1285: The contract description specified for RKOS is ambiguous;
# you must specify the currency., contract: Stock(symbol='RKOS')
# Error 200, reqId 1286: The contract description specified for AI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AI')
# Error 200, reqId 1287: The contract description specified for ARLO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARLO')
# Error 200, reqId 1288: The contract description specified for ARM is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARM')
# Error 200, reqId 1289: The contract description specified for ARD is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARD')
# Error 200, reqId 1290: The contract description specified for AHH is ambiguous;
# you must specify the currency., contract: Stock(symbol='AHH')
# Error 200, reqId 1291: The contract description specified for AAMTF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAMTF')
# FR0010313833
# Error 430, reqId 1292: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AOILQ')
# Error 200, reqId 1293: The contract description specified for ARO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARO')
# Error 200, reqId 1295: The contract description specified for AMNF is ambiguous;
# you must specify the currency., contract: Stock(symbol='AMNF')
# Error 200, reqId 1296: The contract description specified for ARMP is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARMP')
# INE109C01017
# Error 430, reqId 1297: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AMCO')
# Error 200, reqId 1298: The contract description specified for AJQ is ambiguous;
# you must specify the currency., contract: Stock(symbol='AJQ')
# Error 200, reqId 1299: The contract description specified for ARR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARR')
# Error 200, reqId 1300: The contract description specified for AFI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AFI')
# Error 200, reqId 1301: The contract description specified for AWI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AWI')
# Error 200, reqId 1302: The contract description specified for ARNI is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARNI')
# Error 200, reqId 1303: The contract description specified for MN is ambiguous;
# you must specify the currency., contract: Stock(symbol='MN')
# Error 200, reqId 1305: The contract description specified for ARTW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARTW')
# Error 430, reqId 1306: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARWA')
# Error 200, reqId 1307: The contract description specified for ARW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARW')
# INE210C01013
# Error 200, reqId 1308: The contract description specified for RPT is ambiguous;
# you must specify the currency., contract: Stock(symbol='RPT')
# Error 430, reqId 1309: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARQL')
# Error 200, reqId 1310: The contract description specified for ARYC is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARYC')
# Error 200, reqId 1312: The contract description specified for ARO is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARO')
# Error 200, reqId 1313: The contract description specified for ARW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARW')
# Error 200, reqId 1314: The contract description specified for AXL is ambiguous;
# you must specify the currency., contract: Stock(symbol='AXL')
# Error 200, reqId 1315: The contract description specified for AROW is ambiguous;
# you must specify the currency., contract: Stock(symbol='AROW')
# Error 200, reqId 1316: The contract description specified for ARW is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARW')
# GB00BGDFBC25
# INE570D01018
# Error 430, reqId 1318: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARROWTEX')
# Error 200, reqId 1319: The contract description specified for ARWR is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARWR')
# INE968D01022
# Error 200, reqId 1322: No security definition has been found for the request, contract: Stock(symbol='0565')
# Error 200, reqId 1323: No security definition has been found for the request, contract: Stock(symbol='2406')
# Error 200, reqId 1324: The contract description specified for ACTL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ACTL')
# Error 200, reqId 1325: No security definition has been found for the request, contract: Stock(symbol='ALNBT')
# Error 200, reqId 1326: The contract description specified for ARTL is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARTL')
# Error 200, reqId 1327: The contract description specified for ATS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATS')
# Error 200, reqId 1328: The contract description specified for ARV is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARV')
# Error 200, reqId 1329: The contract description specified for ATMS is ambiguous;
# you must specify the currency., contract: Stock(symbol='ATMS')
# Error 200, reqId 1330: The contract description specified for AAM is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAM')
# Error 200, reqId 1331: The contract description specified for 4423 is ambiguous;
# you must specify the currency., contract: Stock(symbol='4423')
# Error 200, reqId 1332: The contract description specified for ARTNA is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARTNA')
# INE267I01010
# Error 200, reqId 1334: The contract description specified for AJG is ambiguous;
# you must specify the currency., contract: Stock(symbol='AJG')
# Error 200, reqId 1335: The contract description specified for ALIF is ambiguous;
# you must specify the currency., contract: Stock(symbol='ALIF')
# Error 200, reqId 1336: The contract description specified for ASAI is ambiguous;
# you must specify the currency., contract: Stock(symbol='ASAI')
# Error 200, reqId 1337: The contract description specified for ART is ambiguous;
# you must specify the currency., contract: Stock(symbol='ART')
# Error 200, reqId 1338: The contract description specified for APAM is ambiguous;
# you must specify the currency., contract: Stock(symbol='APAM')
# Error 430, reqId 1339: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AHFP')
# Error 200, reqId 1340: The contract description specified for AIGI is ambiguous;
# you must specify the currency., contract: Stock(symbol='AIGI')
# Error 200, reqId 1341: The contract description specified for 6778 is ambiguous;
# you must specify the currency., contract: Stock(symbol='6778')
# Error 200, reqId 1343: The contract description specified for 7198 is ambiguous;
# you must specify the currency., contract: Stock(symbol='7198')
# Error 200, reqId 1344: The contract description specified for AAJ is ambiguous;
# you must specify the currency., contract: Stock(symbol='AAJ')
# Error 200, reqId 1345: The contract description specified for ARON is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARON')
# Error 200, reqId 1346: The contract description specified for ARVN is ambiguous;
# you must specify the currency., contract: Stock(symbol='ARVN')
# INE034A01011
# Error 200, reqId 1349: No security definition has been found for the request, contract: Stock(symbol='ARYA')
# INE034S01021
# Peer closed connection.

# %%
isinList
# Out:
# ['AU0000001ST0',
#  None,
#  None,
#  None,
#  'AU00000088E2',
#  None,
#  'JP3160590000',
#  None,
#  'FR0010050773',
#  None,
#  None,
#  'SG1S12926576',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE721Z01010',
#  None,
#  'INE767A01016',
#  'INE769A01020',
#  'INE216P01012',
#  'GB00B9GQVG73',
#  None,
#  None,
#  'AU000000ABP9',
#  None,
#  'INE421A01028',
#  None,
#  None,
#  'INE117A01022',
#  'INE117A01022',
#  None,
#  None,
#  'INE358A01014',
#  None,
#  None,
#  None,
#  'JP3152740001',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B0P6J834',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB0003920757',
#  None,
#  None,
#  'GB00BMF19B58',
#  'GB0000066554',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'NL0011540547',
#  'BE0974278104',
#  None,
#  'SG0533000253',
#  None,
#  None,
#  'ZAE000255915',
#  'SE0006256558',
#  None,
#  'SG2C12961455',
#  'SG1I02877971',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AKG9',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'NL0009767532',
#  None,
#  'INE793A01012',
#  'AU000000AX19',
#  None,
#  None,
#  'JP3108060009',
#  'JP3108190004',
#  None,
#  'GB0001771426',
#  None,
#  'ES0125220311',
#  None,
#  'FR0000120404',
#  None,
#  None,
#  'JP3108180005',
#  'GB00BZ6VT592',
#  'GB00BQQFX454',
#  'INE648Z01015',
#  None,
#  None,
#  'INE543V01017',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'SG1Q66923448',
#  None,
#  None,
#  'JP3108000005',
#  None,
#  None,
#  None,
#  'BE0003764785',
#  None,
#  None,
#  None,
#  None,
#  'JP3108100003',
#  None,
#  'JP3108600002',
#  None,
#  None,
#  'AU000000ACQ5',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3108120001',
#  'AU0000006124',
#  None,
#  'SE0009269467',
#  None,
#  'AU000000ACW3',
#  'INE731H01025',
#  'GB00BPG7NS80',
#  None,
#  'JP3047490002',
#  None,
#  'GB00BJ05QC14',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000ADA7',
#  'AU000000ADH2',
#  'AU0000001AD2',
#  'CNE0000004V0',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IM00B986V543',
#  'INE423A01024',
#  None,
#  'INE364U01010',
#  'INE742F01042',
#  'INE814H01011',
#  'INE931S01010',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3856000009',
#  None,
#  None,
#  None,
#  'CH0029850754',
#  'AT000ADDIKO0',
#  'CNE000000DM5',
#  None,
#  'SG1I67883666',
#  'CH0012138605',
#  'JP3114800000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE982B01019',
#  None,
#  None,
#  None,
#  'AU000000ADR1',
#  None,
#  None,
#  None,
#  'DE000A1EWWW0',
#  None,
#  None,
#  None,
#  'INE674K01013',
#  'INE865C01022',
#  None,
#  None,
#  'LU1250154413',
#  None,
#  None,
#  'INE045A01017',
#  'FR0010340141',
#  None,
#  'INE737B01033',
#  None,
#  None,
#  None,
#  'JP3122010006',
#  None,
#  None,
#  'CH0008967926',
#  None,
#  'JP3122150000',
#  None,
#  'SG1CJ7000006',
#  'JP3213400009',
#  'INE199C01026',
#  None,
#  None,
#  None,
#  None,
#  'JP3122410008',
#  None,
#  None,
#  'JP3122400009',
#  None,
#  None,
#  'JP3122380003',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ZAE000031035',
#  'JP3121970002',
#  'AU000000ADX9',
#  None,
#  'CNE000000RM5',
#  None,
#  None,
#  None,
#  'INE208C01025',
#  None,
#  None,
#  'SG1BA1000003',
#  None,
#  None,
#  'CNE000001G46',
#  None,
#  'JP3131400008',
#  None,
#  'JP3131430005',
#  'AU000000AML5',
#  None,
#  None,
#  'NL0000687663',
#  None,
#  'AU000000AEI8',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'RU0009062285',
#  None,
#  None,
#  None,
#  'CNE000000Y86',
#  'CNE000001857',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'CH0478634105',
#  'SG1C01001033',
#  'FI0009800098',
#  'GB00B18S7B29',
#  'IL0005780130',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IL0010979487',
#  None,
#  None,
#  None,
#  None,
#  'AU0000036949',
#  None,
#  None,
#  'ZAE000054045',
#  'GG00BD95V148',
#  None,
#  None,
#  None,
#  None,
#  'INE204E01012',
#  'JP3112000009',
#  None,
#  None,
#  None,
#  'AU000000AU12',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AGL7',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3561200001',
#  'JP3108170006',
#  None,
#  'CNE100000Q43',
#  None,
#  None,
#  'AU000000AMN1',
#  None,
#  None,
#  None,
#  None,
#  'GG00BDG13C09',
#  None,
#  None,
#  None,
#  'INE740V01019',
#  'INE209A01019',
#  'JP3108200001',
#  None,
#  None,
#  'CY0101062111',
#  None,
#  None,
#  'AU000000AGR4',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3100600000',
#  'JP3105090009',
#  None,
#  'INE212H01026',
#  'HK0000069689',
#  None,
#  'JP3103600007',
#  'JP3102400003',
#  'JP3105040004',
#  'JP3101000002',
#  None,
#  None,
#  None,
#  'JP3105250009',
#  'SE0009242555',
#  'AU000000AGI3',
#  'JP3105050003',
#  'GB00B128C026',
#  None,
#  None,
#  None,
#  'FR0000031122',
#  None,
#  'INE645W01026',
#  None,
#  None,
#  None,
#  'NL0000235190',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IL0010958358',
#  'JP3266050008',
#  None,
#  None,
#  'JP3688100001',
#  'GB00BKDRYJ47',
#  None,
#  'JP3167240005',
#  'JP3101600009',
#  'JP3101800005',
#  'JP3102000001',
#  'CNE000001FB1',
#  None,
#  'JP3160050005',
#  'DE000A0WMPJ6',
#  'JP3101850000',
#  'GB00BFZNLB60',
#  'AU000000AJL1',
#  'INE031B01049',
#  'JP3119600009',
#  None,
#  'INE298G01027',
#  None,
#  None,
#  None,
#  None,
#  'JP3131000006',
#  None,
#  None,
#  'JP3108400007',
#  'NO0010234552',
#  None,
#  None,
#  None,
#  'JP3107400008',
#  'JP3107600003',
#  None,
#  None,
#  None,
#  'INE523B01011',
#  'INE542B01011',
#  'FI4000058870',
#  None,
#  'NO0003097503',
#  'INE133A01011',
#  'NL0013267909',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE914E01040',
#  'AU000000AUQ7',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B06KBB18',
#  'DE0006209901',
#  None,
#  None,
#  'INE155C01010',
#  'JP3126460009',
#  None,
#  None,
#  'GB0004832472',
#  'GB0005581672',
#  None,
#  'SE0008732218',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000ALY0',
#  'AU000000ALC6',
#  None,
#  None,
#  'JP3126210008',
#  None,
#  'AU000000AL88',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'SE0008348072',
#  'INE426A01027',
#  'INE901L01018',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AJX6',
#  None,
#  'GB00BDHXPG30',
#  'SE0000695876',
#  'JP3126340003',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AQI2',
#  None,
#  None,
#  'INE062D01024',
#  None,
#  'SE0007158910',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE773I01017',
#  None,
#  None,
#  'INE540L01014',
#  None,
#  'INE150B01039',
#  None,
#  'DE0005110001',
#  None,
#  None,
#  None,
#  'INE418H01029',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AHQ4',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B02LCQ05',
#  None,
#  'AU000000AQZ6',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'SGXE65282837',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B11V7W98',
#  None,
#  None,
#  'GB00BNG2M159',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AGE2',
#  None,
#  'IL0011014508',
#  None,
#  None,
#  None,
#  None,
#  'CH0008837566',
#  None,
#  'INE835G01018',
#  None,
#  None,
#  None,
#  None,
#  'FI0009013114',
#  None,
#  None,
#  'ES0157097017',
#  'INE326B01027',
#  None,
#  None,
#  None,
#  'IL0011176885',
#  None,
#  'IL0003900136',
#  None,
#  'INE385I01010',
#  'JP3126470008',
#  None,
#  None,
#  None,
#  'GB00BF1TM596',
#  'JP3126370000',
#  'GB00BYWKBC49',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'MU0456S00006',
#  None,
#  None,
#  None,
#  None,
#  'CH0019199550',
#  None,
#  'JP3126400005',
#  'IL0003870198',
#  None,
#  'FR0010220475',
#  'DE000A0LD2U1',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3126350002',
#  'FR0000071946',
#  'HU0000155726',
#  None,
#  'AU0000043945',
#  None,
#  None,
#  None,
#  None,
#  'AU0000001AG5',
#  None,
#  None,
#  None,
#  'AU0000022774',
#  'ES0113312005',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B0LSFV82',
#  'AU000000ALU8',
#  None,
#  None,
#  None,
#  None,
#  'JP3201800004',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB0000280353',
#  None,
#  'AU000000AWC3',
#  None,
#  'CNE1000001T8',
#  None,
#  None,
#  None,
#  'DE000A2YNT30',
#  None,
#  'JP3122800000',
#  'DE0005093108',
#  None,
#  None,
#  None,
#  'JP3124200001',
#  'AU000000ANL3',
#  'JP3124400007',
#  None,
#  'SG1F08854688',
#  'INE885A01032',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE371P01015',
#  None,
#  None,
#  None,
#  None,
#  'INE540G01014',
#  'JP3128650003',
#  None,
#  None,
#  None,
#  None,
#  'INE079A01024',
#  None,
#  None,
#  None,
#  'AU000000AMH3',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'NO0010272065',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00BFFK8T45',
#  'IE0003073255',
#  'IL0010922040',
#  'JP3124440003',
#  None,
#  None,
#  None,
#  None,
#  'IL0010972789',
#  None,
#  None,
#  None,
#  None,
#  'AU0000023822',
#  'IT0004056880',
#  None,
#  None,
#  None,
#  'ES0105375002',
#  'INE098F01031',
#  None,
#  'NL0000313286',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3429800000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IL0010806136',
#  None,
#  'AU000000ALT0',
#  None,
#  None,
#  'INE242C01024',
#  None,
#  None,
#  'AU000000ANR0',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE435A01028',
#  'INE715B01021',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB0002684552',
#  None,
#  'AU000000ADN0',
#  None,
#  'JP3122450004',
#  'GB00BF2G3L29',
#  None,
#  'CNE000000SQ4',
#  None,
#  None,
#  'CNE0000014G0',
#  'JP3127700007',
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
df_stockList_IB = df_stockList[['symbol_x', 'longName', 'Country', 'Exchange', 'currency_y', 'isin']].copy()
df_stockList_IB['ISIN'] = isinList
df_stockList_IB.head()
# Out:
#   symbol_x            longName                   Country     Exchange  \
# 0      1ST       1ST GROUP LTD                 Australia          ASX
# 1     TWOU              2U INC  United States of America       NASDAQ
# 2     DDDX  3DX INDUSTRIES INC  United States of America         PINK
# 3      MMM               3M CO                    Mexico  US Exchange
# 4      88E       88 ENERGY LTD            United Kingdom          LSE
#
#   currency_y          isin          ISIN
# 0        AUD           NaN  AU0000001ST0
# 1        USD           NaN          None
# 2        USD           NaN          None
# 3        NaN           NaN          None
# 4        GBP  AU00000088E2  AU00000088E2

# %%
df_stockList_IB = df_stockList_IB.rename(columns={"symbol_x": "Ticker", "longName": "Name-IB", "Country": "Country-IB", "Exchange": "Exchange-IB", "currency_y": "Currency-IB", "ISIN": "ISIN-IB", "isin": "ISIN-19.7"})
df_stockList_IB.head()
# Out:
#   Ticker             Name-IB                Country-IB  Exchange-IB  \
# 0    1ST       1ST GROUP LTD                 Australia          ASX
# 1   TWOU              2U INC  United States of America       NASDAQ
# 2   DDDX  3DX INDUSTRIES INC  United States of America         PINK
# 3    MMM               3M CO                    Mexico  US Exchange
# 4    88E       88 ENERGY LTD            United Kingdom          LSE
#
#   Currency-IB     ISIN-19.7       ISIN-IB
# 0         AUD           NaN  AU0000001ST0
# 1         USD           NaN          None
# 2         USD           NaN          None
# 3         NaN           NaN          None
# 4         GBP  AU00000088E2  AU00000088E2

# %%
df_stockList_IB.to_csv('ISIN_from_IB.csv', index=False)
# Out:
# Peer closed connection.
