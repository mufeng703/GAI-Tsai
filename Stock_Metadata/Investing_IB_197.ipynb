# %%
import numpy as np
import pandas as pd

# %%
path1 = "./full stock list.csv"

df_inv = pd.read_csv(path1)  
df_inv.head()
# Out:
#                          Name Ticker Exchange    Type         Market  \
# 0  Advanced Micro Devices Inc    AMD   NASDAQ  Equity  United States
# 1                   Apple Inc   AAPL   NASDAQ  Equity  United States
# 2              Amazon.com Inc   AMZN   NASDAQ  Equity  United States
# 3          NVIDIA Corporation   NVDA   NASDAQ  Equity  United States
# 4          Ford Motor Company      F     NYSE  Equity  United States
#
#            ISIN      CUSIP
# 0  US0079031078  007903107
# 1  US0378331005  037833100
# 2  US0231351067  023135106
# 3  US67066G1040  67066G104
# 4  US3453708600  345370860

# %%
path = "/Users/caichengyun/Documents/User/Documents/Master/Intern/Global AI/Projects/Stock_Metadata/ISIN_from_IB.csv"

df_IB = pd.read_csv(path)  
df_IB
# Out:
#       Ticker                       Name-IB                Country-IB  \
# 0        1ST                 1ST GROUP LTD                 Australia
# 1       TWOU                        2U INC  United States of America
# 2       DDDX            3DX INDUSTRIES INC  United States of America
# 3        MMM                         3M CO                    Mexico
# 4        88E                 88 ENERGY LTD            United Kingdom
# ...      ...                           ...                       ...
# 19731   ZYNE   ZYNERBA PHARMACEUTICALS INC  United States of America
# 19732   ZYXI                     ZYNEX INC  United States of America
# 19733   ZNGA              ZYNGA INC - CL A               Switzerland
# 19734    ZYT                  ZYTRONIC PLC            United Kingdom
# 19735   8295  ZZ CAPITAL INTERNATIONAL LTD                 Hong Kong
#
#        Exchange-IB Currency-IB     ISIN-19.7       ISIN-IB
# 0              ASX         AUD           NaN  AU0000001ST0
# ...

# %%
df_IB = df_IB.assign(**{'ISIN-IB': df_IB['ISIN-IB'].fillna(df_IB['ISIN-19.7'])})
df_IB
# Out:
#       Ticker                       Name-IB                Country-IB  \
# 0        1ST                 1ST GROUP LTD                 Australia
# 1       TWOU                        2U INC  United States of America
# 2       DDDX            3DX INDUSTRIES INC  United States of America
# 3        MMM                         3M CO                    Mexico
# 4        88E                 88 ENERGY LTD            United Kingdom
# ...      ...                           ...                       ...
# 19731   ZYNE   ZYNERBA PHARMACEUTICALS INC  United States of America
# 19732   ZYXI                     ZYNEX INC  United States of America
# 19733   ZNGA              ZYNGA INC - CL A               Switzerland
# 19734    ZYT                  ZYTRONIC PLC            United Kingdom
# 19735   8295  ZZ CAPITAL INTERNATIONAL LTD                 Hong Kong
#
#        Exchange-IB Currency-IB     ISIN-19.7       ISIN-IB
# 0              ASX         AUD           NaN  AU0000001ST0
# ...

# %%
df = pd.merge(df_IB, df_inv, how='outer', on='Ticker')
df
# Out:
#       Ticker             Name-IB                Country-IB  Exchange-IB  \
# 0        1ST       1ST GROUP LTD                 Australia          ASX
# 1       TWOU              2U INC  United States of America       NASDAQ
# 2       DDDX  3DX INDUSTRIES INC  United States of America         PINK
# 3        MMM               3M CO                    Mexico  US Exchange
# 4        88E       88 ENERGY LTD            United Kingdom          LSE
# ...      ...                 ...                       ...          ...
# 19896  EDMCQ                 NaN                       NaN          NaN
# 19897  EDSFF                 NaN                       NaN          NaN
# 19898   FALC                 NaN                       NaN          NaN
# 19899   FBSI                 NaN                       NaN          NaN
# 19900   FFDF                 NaN                       NaN          NaN
#
#       Currency-IB     ISIN-19.7       ISIN-IB                       Name  \
# ...

# %%
df = df.assign(**{'ISIN': df['ISIN'].fillna(df['ISIN-IB'])})
df
# Out:
#       Ticker             Name-IB                Country-IB  Exchange-IB  \
# 0        1ST       1ST GROUP LTD                 Australia          ASX
# 1       TWOU              2U INC  United States of America       NASDAQ
# 2       DDDX  3DX INDUSTRIES INC  United States of America         PINK
# 3        MMM               3M CO                    Mexico  US Exchange
# 4        88E       88 ENERGY LTD            United Kingdom          LSE
# ...      ...                 ...                       ...          ...
# 19896  EDMCQ                 NaN                       NaN          NaN
# 19897  EDSFF                 NaN                       NaN          NaN
# 19898   FALC                 NaN                       NaN          NaN
# 19899   FBSI                 NaN                       NaN          NaN
# 19900   FFDF                 NaN                       NaN          NaN
#
#       Currency-IB     ISIN-19.7       ISIN-IB                       Name  \
# ...

# %%
df = df.rename(columns={"Name": "Name-Investing.com", "Exchange": "Exchange-Investing.com", "Type": "Type-Investing.com", "Market": "Market-Investing.com", "CUSIP": "CUSIP-Investing.com"})

# %%
df.head(50)
# Out:
#        Ticker                       Name-IB                Country-IB  \
# 0         1ST                 1ST GROUP LTD                 Australia
# 1        TWOU                        2U INC  United States of America
# 2        DDDX            3DX INDUSTRIES INC  United States of America
# 3         MMM                         3M CO                    Mexico
# 4         88E                 88 ENERGY LTD            United Kingdom
# 5        AQFD           A CLASSIFIED AD INC                       NaN
# 6        7063                  A DOT CO LTD                     Japan
# 7       AMKBY  A P MOLLER-MAERSK-B-UNSP ADR  United States of America
# 8       MLATV           A TOUTE VITESSE-ATV                    France
# 9        AMRK    A-MARK PRECIOUS METALS INC  United States of America
# 10       AMRK     AMIR MARKETING AND INVEST                    Israel
# 11        AKH           A-TEC INDUSTRIES AG                       NaN
# ...

# %%
df.to_csv('Investing_IB_197.csv', index=False)
