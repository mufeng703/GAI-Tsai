# %%
import numpy as np
import pandas as pd
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/caichengyun/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/caichengyun/nltk_data...
# True

# %%
# load data
path = "./withEOD.csv"

df = pd.read_csv(path, index_col=0)  
df
# Out:
#          EOD-Exchange            EOD-Name      EOD-Type EOD-Country  \
# EOD-Code
# 1ST                AU    1stAvailable Ltd  Common Stock   Australia
# TWOU               US              2U Inc  Common Stock         USA
# DDDX               US  3Dx Industries Inc  Common Stock         USA
# MMM                US          3M Company  Common Stock         USA
# MMM                AU    Marley Spoon AGs  Common Stock   Australia
# ...               ...                 ...           ...         ...
# NaN               NaN                 NaN           NaN         NaN
# NaN               NaN                 NaN           NaN         NaN
# NaN               NaN                 NaN           NaN         NaN
# NaN               NaN                 NaN           NaN         NaN
# NaN               NaN                 NaN           NaN         NaN
#
#          EOD-Currency          ISIN  EOD-previousClose EOD-previousCloseDate  \
# EOD-Code
# 1ST               AUD  AU0000001ST0             0.0070            2022-07-20
# TWOU              USD  US90214J1016            11.0700            2022-07-20
# DDDX              USD  US88556A1007             0.0595            2022-07-20
# MMM               USD  US88579Y1010           133.0100            2022-07-20
# MMM               AUD  AU0000013070             0.2200            2022-07-20
# ...               ...           ...                ...                   ...
# NaN               NaN  US28140M1036                NaN                   NaN
# NaN               NaN  VGG323351046                NaN                   NaN
# NaN               NaN  US3061372096                NaN                   NaN
# NaN               NaN  US3186871006                NaN                   NaN
# NaN               NaN  US30243C1071                NaN                   NaN
#
#                      industry-IB          longName-IB  ... Symbol-IB  \
# EOD-Code                                               ...
# 1ST               Communications        1ST GROUP LTD  ...       1ST
# TWOU      Consumer, Non-cyclical               2U INC  ...      TWOU
# DDDX                  Industrial   3DX INDUSTRIES INC  ...      DDDX
# MMM                   Industrial                3M CO  ...       MMM
# MMM       Consumer, Non-cyclical  MARLEY SPOON AG-CDI  ...       MMM
# ...                          ...                  ...  ...       ...
# NaN                          NaN                  NaN  ...       NaN
# NaN                          NaN                  NaN  ...       NaN
# NaN                          NaN                  NaN  ...       NaN
# NaN                          NaN                  NaN  ...       NaN
# NaN                          NaN                  NaN  ...       NaN
#
#                 Name-IB Country-IB  Exchange-IB Currency-IB  \
# EOD-Code
# 1ST       1ST GROUP LTD  Australia          ASX         AUD
# TWOU                NaN        NaN          NaN         NaN
# DDDX                NaN        NaN          NaN         NaN
# MMM               3M CO     Mexico  US Exchange         NaN
# MMM                 NaN        NaN          NaN         NaN
# ...                 ...        ...          ...         ...
# NaN                 NaN        NaN          NaN         NaN
# NaN                 NaN        NaN          NaN         NaN
# NaN                 NaN        NaN          NaN         NaN
# NaN                 NaN        NaN          NaN         NaN
# NaN                 NaN        NaN          NaN         NaN
#
#                  Name-Investing.com Exchange-Investing.com Type-Investing.com  \
# EOD-Code
# 1ST                             NaN                    NaN                NaN
# TWOU                            NaN                    NaN                NaN
# DDDX                            NaN                    NaN                NaN
# MMM                      3M Company                   NYSE             Equity
# MMM                             NaN                    NaN                NaN
# ...                             ...                    ...                ...
# NaN       Education Management Corp            OTC Markets             Equity
# NaN              Exceed Company Ltd            OTC Markets             Equity
# NaN         FalconStor Software Inc            OTC Markets             Equity
# NaN            First Bancshares Inc            OTC Markets             Equity
# NaN              FFD Financial Corp            OTC Markets             Equity
#
#          Market-Investing.com CUSIP-Investing.com
# EOD-Code
# 1ST                       NaN                 NaN
# TWOU                      NaN                 NaN
# DDDX                      NaN                 NaN
# MMM             United States           88579Y101
# MMM                       NaN                 NaN
# ...                       ...                 ...
# NaN             United States           28140M103
# NaN             United States           G32335104
# NaN             United States           306137209
# NaN             United States           318687100
# NaN             United States           30243C107
#
# [22630 rows x 21 columns]

# %%
# get 30 most common words (which can not be used in name matching)
from collections import Counter

all_names = df['EOD-Name'].unique()
names_freq = Counter()
for name in all_names:
    names_freq.update(str(name).split(" "))
key_words = [word for (word,_) in names_freq.most_common(30)]
print(key_words)
# Out:
# ['Ltd', 'Inc', 'Co', 'Limited', 'Corp', 'Group', 'Holdings', 'PLC', 'Corporation', 'Resources', 'Energy', 'ETF', 'International', 'SA', 'Fund', 'AG', '&', 'Trust', 'Technologies', 'Global', 'Industries', 'China', 'Holding', 'Company', 'Financial', 'Gold', 'Bank', 'Capital', 'Technology', 'Mining']
