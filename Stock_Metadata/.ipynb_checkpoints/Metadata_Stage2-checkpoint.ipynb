# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import datetime
from scipy import stats
import os

# %%
path = "https://www.dropbox.com/s/fcpt5lejcf60n2e/SDG_Data_File_Daily.csv?dl=1"
df_sdg= pd.read_csv(path, error_bad_lines=False, index_col=0)

df_sdg.head()
# Out:
#     Timestamp Ticker          ISIN      Company_Name  GICS Sector  SDG_1  \
# 0  2013-04-01    AOS  US8318652091  a. o. smith corp  Industrials    NaN
# 1  2013-04-02    AOS  US8318652091  a. o. smith corp  Industrials    NaN
# 2  2013-04-03    AOS  US8318652091  a. o. smith corp  Industrials    NaN
# 3  2013-04-04    AOS  US8318652091  a. o. smith corp  Industrials    NaN
# 4  2013-04-05    AOS  US8318652091  a. o. smith corp  Industrials    NaN
#
#    SDG_2  SDG_3  SDG_4  SDG_5  ...  SDG_9_News_Volume  SDG_10_News_Volume  \
# 0    NaN    NaN    NaN    NaN  ...                NaN                 NaN
# 1    NaN    NaN    NaN    NaN  ...                NaN                 NaN
# 2    NaN    NaN    NaN    NaN  ...                NaN                 NaN
# 3    NaN    NaN    NaN    NaN  ...                NaN                 NaN
# 4    NaN    NaN    NaN    NaN  ...                NaN                 NaN
#
#    SDG_11_News_Volume  SDG_12_News_Volume  SDG_13_News_Volume  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    SDG_14_News_Volume  SDG_15_News_Volume  SDG_16_News_Volume  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    SDG_17_News_Volume  SDG_News_Volume_Mean
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4                 NaN                   NaN
#
# [5 rows x 95 columns]

# %%
# load data
path = "https://www.dropbox.com/s/0ta8tx9rkk4jt2s/ESG_Data_File_Daily.csv?dl=1"
df_esg = pd.read_csv(path, error_bad_lines=False)

df_esg.head()
# Out:
#    Unnamed: 0   Timestamp Ticker          ISIN      Company_Name  GICS Sector  \
# 0           0  2013-04-01    AOS  US8318652091  a. o. smith corp  Industrials
# 1           1  2013-04-02    AOS  US8318652091  a. o. smith corp  Industrials
# 2           2  2013-04-03    AOS  US8318652091  a. o. smith corp  Industrials
# 3           3  2013-04-04    AOS  US8318652091  a. o. smith corp  Industrials
# 4           4  2013-04-05    AOS  US8318652091  a. o. smith corp  Industrials
#
#     E   S   G  ESG_Mean  STS_E  STS_S  STS_G  ESG_STS_Mean  LTS_E  LTS_S  \
# 0 NaN NaN NaN       NaN    NaN    NaN    NaN           NaN    NaN    NaN
# 1 NaN NaN NaN       NaN    NaN    NaN    NaN           NaN    NaN    NaN
# 2 NaN NaN NaN       NaN    NaN    NaN    NaN           NaN    NaN    NaN
# 3 NaN NaN NaN       NaN    NaN    NaN    NaN           NaN    NaN    NaN
# 4 NaN NaN NaN       NaN    NaN    NaN    NaN           NaN    NaN    NaN
#
#    LTS_G  ESG_LTS_Mean
# 0    NaN           NaN
# 1    NaN           NaN
# 2    NaN           NaN
# 3    NaN           NaN
# 4    NaN           NaN

# %%
# load data
path = "https://www.dropbox.com/s/dyvqrt8g22y8vk9/Sentiment_Data_File_Daily.csv?dl=1"
df_sent = pd.read_csv(path, error_bad_lines=False, index_col=0)

df_sent.head()
# Out:
#     Timestamp Ticker          ISIN      Company_Name  GICS Sector  Sentiment  \
# 0  2013-04-01    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 1  2013-04-02    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 2  2013-04-03    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 3  2013-04-04    AOS  US8318652091  a. o. smith corp  Industrials        NaN
# 4  2013-04-05    AOS  US8318652091  a. o. smith corp  Industrials        NaN
#
#    STS  LTS  Sentiment_STD  Sentiment_News_Volume
# 0  NaN  NaN            NaN                    NaN
# 1  NaN  NaN            NaN                    NaN
# 2  NaN  NaN            NaN                    NaN
# 3  NaN  NaN            NaN                    NaN
# 4  NaN  NaN            NaN                    NaN

# %%
df = df_sent.copy()
sectors = df.groupby('GICS Sector').sample(1)[['Ticker', 'GICS Sector']]
sectors
# Out:
#         Ticker             GICS Sector
# 1713659   SIRI  Communication Services
# 614742     DKS  Consumer Discretionary
# 1321019    TAP        Consumer Staples
# 450268     XEC                  Energy
# 1556535    PGR              Financials
# 61726     ALXN             Health Care
# 1918516    UAL             Industrials
# 506074    COMM  Information Technology
# 1546995     PX               Materials
# 1721866    SLG             Real Estate
# 222138     ATO               Utilities

# %%
df_comp = df_sent[df_sent['Ticker'].isin(sectors['Ticker'])]
tickers = df_comp[['Ticker', 'Company_Name']].drop_duplicates()
tickers
# Out:
#         Ticker                     Company_Name
# 61416     ALXN      alexion pharmaceuticals inc
# 221780     ATO                atmos energy corp
# 446972     XEC                cimarex energy co
# 504976    COMM        commscope holding company
# 614160     DKS        dick's sporting goods inc
# 1320444    TAP          molson coors brewing co
# 1545636     PX                      praxair inc
# 1555872    PGR                 progressive corp
# 1712824   SIRI           sirius xm holdings inc
# 1719648    SLG             sl green realty corp
# 1917544    UAL  united continental holdings inc

# %%
for i in range(len(tickers)):
    print(tickers['Ticker'].iloc[i])
# Out:
# ALXN
# ATO
# XEC
# COMM
# DKS
# TAP
# PX
# PGR
# SIRI
# SLG
# UAL

# %%
df_comp.to_csv('company.csv', index=False)
df_comp
# Out:
#           Timestamp Ticker          ISIN                     Company_Name  \
# 61416    2013-04-01   ALXN  US0153511094      alexion pharmaceuticals inc
# 61417    2013-04-02   ALXN  US0153511094      alexion pharmaceuticals inc
# 61418    2013-04-03   ALXN  US0153511094      alexion pharmaceuticals inc
# 61419    2013-04-04   ALXN  US0153511094      alexion pharmaceuticals inc
# 61420    2013-04-05   ALXN  US0153511094      alexion pharmaceuticals inc
# ...             ...    ...           ...                              ...
# 1920951  2022-07-30    UAL  US9100471096  united continental holdings inc
# 1920952  2022-07-31    UAL  US9100471096  united continental holdings inc
# 1920953  2022-08-01    UAL  US9100471096  united continental holdings inc
# 1920954  2022-08-02    UAL  US9100471096  united continental holdings inc
# 1920955  2022-08-03    UAL  US9100471096  united continental holdings inc
#
#          GICS Sector  Sentiment       STS       LTS  Sentiment_STD  \
# 61416    Health Care        NaN       NaN       NaN            NaN
# 61417    Health Care        NaN       NaN       NaN            NaN
# 61418    Health Care        NaN       NaN       NaN            NaN
# 61419    Health Care        NaN       NaN       NaN            NaN
# 61420    Health Care        NaN       NaN       NaN            NaN
# ...              ...        ...       ...       ...            ...
# 1920951  Industrials  -0.357414  0.432336 -0.814422       1.285967
# 1920952  Industrials  -0.250725  0.236330 -0.789236       2.258929
# 1920953  Industrials  -0.250290  0.048455 -0.760070       3.706438
# 1920954  Industrials  -2.117841 -0.445583 -0.789209       4.346144
# 1920955  Industrials  -0.043496 -0.454573 -0.759249       2.957765
#
#          Sentiment_News_Volume
# 61416                      NaN
# 61417                      NaN
# 61418                      NaN
# 61419                      NaN
# 61420                      NaN
# ...                        ...
# 1920951                   22.0
# 1920952                   19.0
# 1920953                   27.0
# 1920954                   14.0
# 1920955                   25.0
#
# [37532 rows x 10 columns]

# %%
path = "./Data/company.csv"
df_sent = pd.read_csv(path, index_col=0)

df = df_sent.copy()
sectors = df.groupby('GICS Sector').sample(1)[['Ticker', 'GICS Sector']]

sectors[]
# Out:
#   File "<ipython-input-5-b281b4d1f768>", line 7
#     sectors[]
#             ^
# SyntaxError: invalid syntax

# %%
df_sent[df_sent['Ticker'] == 'S']
# Out:
#            Ticker          ISIN Company_Name             GICS Sector  \
# Timestamp
# 2013-04-01      S  US85207U1051  sprint corp  Communication Services
# 2013-04-02      S  US85207U1051  sprint corp  Communication Services
# 2013-04-03      S  US85207U1051  sprint corp  Communication Services
# 2013-04-04      S  US85207U1051  sprint corp  Communication Services
# 2013-04-05      S  US85207U1051  sprint corp  Communication Services
# ...           ...           ...          ...                     ...
# 2022-07-29      S  US85207U1051  sprint corp  Communication Services
# 2022-07-30      S  US85207U1051  sprint corp  Communication Services
# 2022-07-31      S  US85207U1051  sprint corp  Communication Services
# 2022-08-01      S  US85207U1051  sprint corp  Communication Services
# 2022-08-02      S  US85207U1051  sprint corp  Communication Services
#
#             Sentiment       STS       LTS  Sentiment_STD  \
# Timestamp
# 2013-04-01        NaN       NaN       NaN            NaN
# 2013-04-02        NaN       NaN       NaN            NaN
# 2013-04-03        NaN       NaN       NaN            NaN
# 2013-04-04        NaN       NaN       NaN            NaN
# 2013-04-05        NaN       NaN       NaN            NaN
# ...               ...       ...       ...            ...
# 2022-07-29        NaN -1.078475  0.142569            NaN
# 2022-07-30        NaN -1.078475  0.142569            NaN
# 2022-07-31        NaN -1.078475  0.142569            NaN
# 2022-08-01   0.074166 -0.941650  0.125862            2.0
# 2022-08-02        NaN -0.941650  0.125862            NaN
#
#             Sentiment_News_Volume
# Timestamp
# 2013-04-01                    NaN
# 2013-04-02                    NaN
# 2013-04-03                    NaN
# 2013-04-04                    NaN
# 2013-04-05                    NaN
# ...                           ...
# 2022-07-29                    NaN
# 2022-07-30                    NaN
# 2022-07-31                    NaN
# 2022-08-01                    1.0
# 2022-08-02                    NaN
#
# [3411 rows x 9 columns]

# %%
test = df_sent[df_sent['Ticker'] == 'S']

lineSent = px.line(test, x=test.index, y="Sentiment",
                   title='Time Series Line Chart')
lineSent.show()
# Out:
# <div>                            <div id="1dccde13-d667-4160-aa70-d7167fc19865" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dccde13-d667-4160-aa70-d7167fc19865")) {                    Plotly.newPlot(                        "1dccde13-d667-4160-aa70-d7167fc19865",                        [{"hovertemplate":"Timestamp=%{x}<br>Sentiment=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-04-01","2013-04-02","2013-04-03","2013-04-04","2013-04-05","2013-04-06","2013-04-07","2013-04-08","2013-04-09","2013-04-10","2013-04-11","2013-04-12","2013-04-13","2013-04-14","2013-04-15","2013-04-16","2013-04-17","2013-04-18","2013-04-19","2013-04-20","2013-04-21","2013-04-22","2013-04-23","2013-04-24","2013-04-25","2013-04-26","2013-04-27","2013-04-28","2013-04-29","2013-04-30","2013-05-01","2013-05-02","2013-05-03","2013-05-04","2013-05-05","2013-05-06","2013-05-07","2013-05-08","2013-05-09","2013-05-10","2013-05-11","2013-05-12","2013-05-13","2013-05-14","2013-05-15","2013-05-16","2013-05-17","2013-05-18","2013-05-19","2013-05-20","2013-05-21","2013-05-22","2013-05-23","2013-05-24","2013-05-25","2013-05-26","2013-05-27","2013-05-28","2013-05-29","2013-05-30","2013-05-31","2013-06-01","2013-06-02","2013-06-03","2013-06-04","2013-06-05","2013-06-06","2013-06-07","2013-06-08","2013-06-09","2013-06-10","2013-06-11","2013-06-12","2013-06-13","2013-06-14","2013-06-15","2013-06-16","2013-06-17","2013-06-18","2013-06-19","2013-06-20","2013-06-21","2013-06-22","2013-06-23","2013-06-24","2013-06-25","2013-06-26","2013-06-27","2013-06-28","2013-06-29","2013-06-30","2013-07-01","2013-07-02","2013-07-03","2013-07-04","2013-07-05","2013-07-06","2013-07-07","2013-07-08","2013-07-09","2013-07-10","2013-07-11","2013-07-12","2013-07-13","2013-07-14","2013-07-15","2013-07-16","2013-07-17","2013-07-18","2013-07-19","2013-07-20","2013-07-21","2013-07-22","2013-07-23","2013-07-24","2013-07-25","2013-07-26","2013-07-27","2013-07-28","2013-07-29","2013-07-30","2013-07-31","2013-08-01","2013-08-02","2013-08-03","2013-08-04","2013-08-05","2013-08-06","2013-08-07","2013-08-08","2013-08-09","2013-08-10","2013-08-11","2013-08-12","2013-08-13","2013-08-14","2013-08-15","2013-08-16","2013-08-17","2013-08-18","2013-08-19","2013-08-20","2013-08-21","2013-08-22","2013-08-23","2013-08-24","2013-08-25","2013-08-26","2013-08-27","2013-08-28","2013-08-29","2013-08-30","2013-08-31","2013-09-01","2013-09-02","2013-09-03","2013-09-04","2013-09-05","2013-09-06","2013-09-07","2013-09-08","2013-09-09","2013-09-10","2013-09-11","2013-09-12","2013-09-13","2013-09-14","2013-09-15","2013-09-16","2013-09-17","2013-09-18","2013-09-19","2013-09-20","2013-09-21","2013-09-22","2013-09-23","2013-09-24","2013-09-25","2013-09-26","2013-09-27","2013-09-28","2013-09-29","2013-09-30","2013-10-01","2013-10-02","2013-10-03","2013-10-04","2013-10-05","2013-10-06","2013-10-07","2013-10-08","2013-10-09","2013-10-10","2013-10-11","2013-10-12","2013-10-13","2013-10-14","2013-10-15","2013-10-16","2013-10-17","2013-10-18","2013-10-19","2013-10-20","2013-10-21","2013-10-22","2013-10-23","2013-10-24","2013-10-25","2013-10-26","2013-10-27","2013-10-28","2013-10-29","2013-10-30","2013-10-31","2013-11-01","2013-11-02","2013-11-03","2013-11-04","2013-11-05","2013-11-06","2013-11-07","2013-11-08","2013-11-09","2013-11-10","2013-11-11","2013-11-12","2013-11-13","2013-11-14","2013-11-15","2013-11-16","2013-11-17","2013-11-18","2013-11-19","2013-11-20","2013-11-21","2013-11-22","2013-11-23","2013-11-24","2013-11-25","2013-11-26","2013-11-27","2013-11-28","2013-11-29","2013-11-30","2013-12-01","2013-12-02","2013-12-03","2013-12-04","2013-12-05","2013-12-06","2013-12-07","2 ...

# %%
sectors['Ticker'].to_numpy()
# Out:
# array(['S', 'HLT', 'TSN', 'PXD', 'HBAN', 'RMD', 'URI', 'WU', 'PX', 'WELL',
#        'EIX'], dtype=object)

# %%
test = df_sent[df_sent['Ticker'] == sectors['Ticker'].iloc[0]]
test
# Out:
#           Timestamp Ticker          ISIN Company_Name             GICS Sector  \
# 1739610  2013-04-01      S  US85207U1051  sprint corp  Communication Services
# 1739611  2013-04-02      S  US85207U1051  sprint corp  Communication Services
# 1739612  2013-04-03      S  US85207U1051  sprint corp  Communication Services
# 1739613  2013-04-04      S  US85207U1051  sprint corp  Communication Services
# 1739614  2013-04-05      S  US85207U1051  sprint corp  Communication Services
# ...             ...    ...           ...          ...                     ...
# 1743016  2022-07-29      S  US85207U1051  sprint corp  Communication Services
# 1743017  2022-07-30      S  US85207U1051  sprint corp  Communication Services
# 1743018  2022-07-31      S  US85207U1051  sprint corp  Communication Services
# 1743019  2022-08-01      S  US85207U1051  sprint corp  Communication Services
# 1743020  2022-08-02      S  US85207U1051  sprint corp  Communication Services
#
#          Sentiment       STS       LTS  Sentiment_STD  Sentiment_News_Volume
# 1739610        NaN       NaN       NaN            NaN                    NaN
# 1739611        NaN       NaN       NaN            NaN                    NaN
# 1739612        NaN       NaN       NaN            NaN                    NaN
# 1739613        NaN       NaN       NaN            NaN                    NaN
# 1739614        NaN       NaN       NaN            NaN                    NaN
# ...            ...       ...       ...            ...                    ...
# 1743016        NaN -1.078475  0.142569            NaN                    NaN
# 1743017        NaN -1.078475  0.142569            NaN                    NaN
# 1743018        NaN -1.078475  0.142569            NaN                    NaN
# 1743019   0.074166 -0.941650  0.125862            2.0                    1.0
# 1743020        NaN -0.941650  0.125862            NaN                    NaN
#
# [3411 rows x 10 columns]

# %%
lineC = px.line(test, x="Timestamp", y="Sentiment", title='Time Series Line Chart')
lineC.show()
# Out:
# <div>                            <div id="837d82c6-1a77-40cb-9ad9-2ddae4a5cb4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("837d82c6-1a77-40cb-9ad9-2ddae4a5cb4e")) {                    Plotly.newPlot(                        "837d82c6-1a77-40cb-9ad9-2ddae4a5cb4e",                        [{"hovertemplate":"Timestamp=%{x}<br>Sentiment=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-04-01","2013-04-02","2013-04-03","2013-04-04","2013-04-05","2013-04-06","2013-04-07","2013-04-08","2013-04-09","2013-04-10","2013-04-11","2013-04-12","2013-04-13","2013-04-14","2013-04-15","2013-04-16","2013-04-17","2013-04-18","2013-04-19","2013-04-20","2013-04-21","2013-04-22","2013-04-23","2013-04-24","2013-04-25","2013-04-26","2013-04-27","2013-04-28","2013-04-29","2013-04-30","2013-05-01","2013-05-02","2013-05-03","2013-05-04","2013-05-05","2013-05-06","2013-05-07","2013-05-08","2013-05-09","2013-05-10","2013-05-11","2013-05-12","2013-05-13","2013-05-14","2013-05-15","2013-05-16","2013-05-17","2013-05-18","2013-05-19","2013-05-20","2013-05-21","2013-05-22","2013-05-23","2013-05-24","2013-05-25","2013-05-26","2013-05-27","2013-05-28","2013-05-29","2013-05-30","2013-05-31","2013-06-01","2013-06-02","2013-06-03","2013-06-04","2013-06-05","2013-06-06","2013-06-07","2013-06-08","2013-06-09","2013-06-10","2013-06-11","2013-06-12","2013-06-13","2013-06-14","2013-06-15","2013-06-16","2013-06-17","2013-06-18","2013-06-19","2013-06-20","2013-06-21","2013-06-22","2013-06-23","2013-06-24","2013-06-25","2013-06-26","2013-06-27","2013-06-28","2013-06-29","2013-06-30","2013-07-01","2013-07-02","2013-07-03","2013-07-04","2013-07-05","2013-07-06","2013-07-07","2013-07-08","2013-07-09","2013-07-10","2013-07-11","2013-07-12","2013-07-13","2013-07-14","2013-07-15","2013-07-16","2013-07-17","2013-07-18","2013-07-19","2013-07-20","2013-07-21","2013-07-22","2013-07-23","2013-07-24","2013-07-25","2013-07-26","2013-07-27","2013-07-28","2013-07-29","2013-07-30","2013-07-31","2013-08-01","2013-08-02","2013-08-03","2013-08-04","2013-08-05","2013-08-06","2013-08-07","2013-08-08","2013-08-09","2013-08-10","2013-08-11","2013-08-12","2013-08-13","2013-08-14","2013-08-15","2013-08-16","2013-08-17","2013-08-18","2013-08-19","2013-08-20","2013-08-21","2013-08-22","2013-08-23","2013-08-24","2013-08-25","2013-08-26","2013-08-27","2013-08-28","2013-08-29","2013-08-30","2013-08-31","2013-09-01","2013-09-02","2013-09-03","2013-09-04","2013-09-05","2013-09-06","2013-09-07","2013-09-08","2013-09-09","2013-09-10","2013-09-11","2013-09-12","2013-09-13","2013-09-14","2013-09-15","2013-09-16","2013-09-17","2013-09-18","2013-09-19","2013-09-20","2013-09-21","2013-09-22","2013-09-23","2013-09-24","2013-09-25","2013-09-26","2013-09-27","2013-09-28","2013-09-29","2013-09-30","2013-10-01","2013-10-02","2013-10-03","2013-10-04","2013-10-05","2013-10-06","2013-10-07","2013-10-08","2013-10-09","2013-10-10","2013-10-11","2013-10-12","2013-10-13","2013-10-14","2013-10-15","2013-10-16","2013-10-17","2013-10-18","2013-10-19","2013-10-20","2013-10-21","2013-10-22","2013-10-23","2013-10-24","2013-10-25","2013-10-26","2013-10-27","2013-10-28","2013-10-29","2013-10-30","2013-10-31","2013-11-01","2013-11-02","2013-11-03","2013-11-04","2013-11-05","2013-11-06","2013-11-07","2013-11-08","2013-11-09","2013-11-10","2013-11-11","2013-11-12","2013-11-13","2013-11-14","2013-11-15","2013-11-16","2013-11-17","2013-11-18","2013-11-19","2013-11-20","2013-11-21","2013-11-22","2013-11-23","2013-11-24","2013-11-25","2013-11-26","2013-11-27","2013-11-28","2013-11-29","2013-11-30","2013-12-01","2013-12-02","2013-12-03","2013-12-04","2013-12-05","2013-12-06","2013-12-07","2 ...
