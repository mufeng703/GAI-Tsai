# %%
import requests     
import json         
import pandas as pd 
import numpy as np
import time
from fuzzywuzzy import fuzz

# %%
path = "./Data/withFIGI.csv"

df = pd.read_csv(path)  
df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,1,2,3,5,6,8,9,10,11,12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0         TWOU         USA          USD           US  US90214J1016
# 1          88E          UK          GBX          LSE  AU00000088E2
# 2         7063       Japan          JPY          TSE  JP3160590000
# 3         2018   Hong Kong          HKD           HK  KYG2953R1149
# 4         2686   Hong Kong          HKD           HK  KYG000371040
# ...        ...         ...          ...          ...           ...
# 17506      NaN         NaN          NaN          NaN  US98979J1097
# 17507      NaN         NaN          NaN          NaN  CA98977K1084
# 17508      NaN         NaN          NaN          NaN  CA98977R1038
# 17509      NaN         NaN          NaN          NaN  GB00BMHTHT14
# 17510      NaN         NaN          NaN          NaN  US98986T1088
#
#                             Name-EOD      Type-EOD  previousClose-EOD  \
# 0                             2U Inc  Common Stock              9.200
# 1                      88 Energy Ltd  Common Stock              0.625
# 2                       A Dot Co Ltd  Common Stock           2064.000
# 3      AAC Technologies Holdings Inc  Common Stock             14.580
# 4            AAG Energy Holdings Ltd  Common Stock              1.410
# ...                              ...           ...                ...
# 17506                            NaN           NaN                NaN
# 17507                            NaN           NaN                NaN
# 17508                            NaN           NaN                NaN
# 17509                            NaN           NaN                NaN
# 17510                            NaN           NaN                NaN
#
#       previousCloseDate-EOD     country-Inv  ...  \
# 0                2022-08-02   united states  ...
# 1                2022-08-03  united kingdom  ...
# 2                2022-08-03           japan  ...
# 3                2022-08-03       hong kong  ...
# 4                2022-08-03       hong kong  ...
# ...                     ...             ...  ...
# 17506                   NaN             NaN  ...
# 17507                   NaN             NaN  ...
# 17508                   NaN             NaN  ...
# 17509                   NaN             NaN  ...
# 17510                   NaN             NaN  ...
#
#                       longName-FIGI symbol-FIGI          figi compositeFIGI  \
# 0                            2U INC        TWOU  BBG001KS9450  BBG001KS9450
# 1                     88 ENERGY LTD         POQ  BBG000BWTTK9  BBG000BWTTK9
# 2                       BIRDMAN INC        7063  BBG00NG9S234  BBG00NG9S234
# 3      AAC TECHNOLOGIES HOLDINGS IN        A2XN  BBG000C162Q4  BBG000C162Q4
# 4           AAG ENERGY HOLDINGS LTD        2686  BBG009CXGZ63  BBG009CXGZ45
# ...                             ...         ...           ...           ...
# 17506                           NaN         NaN           NaN           NaN
# 17507                           NaN         NaN           NaN           NaN
# 17508                   ZOOMMED INC       ZMD/H  BBG000BYKYT4  BBG000BYKYT4
# 17509                           NaN         NaN           NaN           NaN
# 17510              ZYNGA INC - CL A     ZNGAEUR  BBG005YZL376  BBG005YZL2R6
#
#       shareClassFIGI exchCode-FIGI marketSector-FIGI securityDescription-FIGI  \
# 0       BBG001V0RR30            US            Equity                     TWOU
# 1       BBG001SCV1F7            GR            Equity                      POQ
# 2       BBG00NG9S261            JP            Equity                     7063
# 3       BBG001SKMWN2            GR            Equity                     A2XN
# 4       BBG009CXGZ54            HK            Equity                     2686
# ...              ...           ...               ...                      ...
# 17506            NaN           NaN               NaN                      NaN
# 17507            NaN           NaN               NaN                      NaN
# 17508   BBG001SJS399            CN            Equity                    ZMD/H
# 17509            NaN           NaN               NaN                      NaN
# 17510   BBG001T24RN2            XS            Equity                  ZNGAEUR
#
#       securityType-FIGI securityType2-FIGI
# 0          Common Stock       Common Stock
# 1          Common Stock       Common Stock
# 2          Common Stock       Common Stock
# 3          Common Stock       Common Stock
# 4          Common Stock       Common Stock
# ...                 ...                ...
# 17506               NaN                NaN
# 17507               NaN                NaN
# 17508      Common Stock       Common Stock
# 17509               NaN                NaN
# 17510      Common Stock       Common Stock
#
# [17511 rows x 33 columns]

# %% [markdown]
# ## EOD vs 19.7k

# %%
df_Name = df[['ISIN', 'Name_197', 'Name-EOD']].dropna(subset=['Name_197'])
df_Name = df_Name[['ISIN', 'Name_197', 'Name-EOD']].dropna(subset=['Name-EOD'])

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['Name_197'],row['Name-EOD'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])

df_matchFinal = df_match[df_match['fuzz_socre1']<60]
df_matchFinal.to_csv('./Data/eod-197.csv', index=False)
df_matchFinal
# Out:
# 13016
# progress: 0.00%
# progress: 10.00%
# progress: 19.99%
# progress: 29.99%
# progress: 39.98%
# progress: 49.98%
# progress: 59.97%
# progress: 69.97%
# progress: 79.96%
# progress: 89.96%
# progress: 99.95%
#                ISIN                      Name_197  \
# 38     JP3108120001                   ACRODEA INC
# 53     LU1250154413             ADO PROPERTIES SA
# 78     US0077371096              AEROCENTURY CORP
# 165    US0185811082    ALLIANCE DATA SYSTEMS CORP
# 223    US0259321042  AMERICAN FINANCIAL GROUP INC
# ...             ...                           ...
# 12934  US98585L1008   YIREN DIGITAL LTD - SPS ADR
# 12942  CNE100002W92     YOUON TECHNOLOGY CO LTD-A
# 12970  CH0276534614           ZEHNDER GROUP AG-RG
# 12996  CNE000000FL2  ZHONGTIAN FINANCIAL GROUP -A
# 13024  HU0000074844               ZWACK UNICUM RT
#
#                                             Name-EOD  fuzz_socre1
# 38                                 Why How Do Co Inc           50
# 53                                    Adler Group SA           58
# 78                                  Mega Matrix Corp           25
# 165                     Bread Financial Holdings Inc           26
# 223                          Aquatic Foods Group plc           51
# ...                                              ...          ...
# 12934                                   Yirendai Ltd           49
# 12942  Changzhou Youon Pubilic Bicycle System Co Ltd           49
# 12970                                        Zehnder           54
# 12996       Zhongtian Urban Development Group Co Ltd           54
# 13024  Zwack Unicum Likoripari es Kereskedelmi Nyrt.           51
#
# [315 rows x 4 columns]

# %% [markdown]
# ## Investing.com vs 19.7k

# %%
df_Name = df[['ISIN', 'Name_197', 'full_name-Inv']].dropna(subset=['Name_197'])
df_Name = df_Name[['ISIN', 'Name_197', 'full_name-Inv']].dropna(subset=['full_name-Inv'])

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['Name_197'],row['full_name-Inv'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])

df_matchFinal = df_match[df_match['fuzz_socre1']<60]
df_matchFinal.to_csv('./Data/inv-197.csv', index=False)
df_matchFinal
# Out:
# 6141
# progress: 0.00%
# progress: 10.00%
# progress: 20.00%
# progress: 30.00%
# progress: 39.99%
# progress: 49.99%
# progress: 59.99%
# progress: 69.99%
# progress: 79.99%
# progress: 219.96%
#               ISIN            Name_197  \
# 246   IL0010806136      ANALYST I.M.S.
# 562   RU000A0HL5M1              BELUGA
# 2779  US5006432000          KORN FERRY
# 2965  IL0004730177         LUZON GROUP
# 3794  PLPKO0000016  PKO BANK POLSKI SA
# 4167  FR0006239109               SCBSM
#
#                                        full_name-Inv  fuzz_socre1
# 246   Analyst IMS Investment Management Services Ltd           44
# 562                                 Beluga Group PAO           55
# 2779                        Korn/Ferry International           59
# 2965     Amos Luzon Development and Energy Group Ltd           41
# 3794     Powszechna Kasa Oszczednosci Bank Polski SA           56
# 4167            Soc Centrale Bois Scieries Manche SA           15

# %% [markdown]
# ## IB vs 19.7k

# %%
df_Name = df[['ISIN', 'Name_197', 'longName-IB']].dropna(subset=['Name_197'])
df_Name = df_Name[['ISIN', 'Name_197', 'longName-IB']].dropna(subset=['longName-IB'])

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['Name_197'],row['longName-IB'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])

df_matchFinal = df_match[df_match['fuzz_socre1']<60]
df_matchFinal.to_csv('./Data/ib-197.csv', index=False)
df_matchFinal
# Out:
# 16912
# progress: 0.00%
# progress: 10.00%
# progress: 20.00%
# progress: 30.00%
# progress: 40.00%
# progress: 49.99%
# progress: 59.99%
# progress: 69.99%
# progress: 89.99%
# progress: 99.99%
# Empty DataFrame
# Columns: [ISIN, Name_197, longName-IB, fuzz_socre1]
# Index: []

# %% [markdown]
# ## FIGI vs 19.7k

# %%
df_Name = df[['ISIN', 'Name_197', 'longName-FIGI']].dropna(subset=['Name_197'])
df_Name = df_Name[['ISIN', 'Name_197', 'longName-FIGI']].dropna(subset=['longName-FIGI'])

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['Name_197'],row['longName-FIGI'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])
df_matchFinal = df_match[df_match['fuzz_socre1']<60]
df_matchFinal.to_csv('./Data/figi-197.csv', index=False)
df_matchFinal
# Out:
# 15485
# progress: 0.00%
# progress: 10.00%
# progress: 19.99%
# progress: 29.99%
# progress: 39.99%
# progress: 49.98%
# progress: 59.98%
# progress: 69.98%
# progress: 79.97%
# progress: 99.97%
#                ISIN                                           Name_197  \
# 2      JP3160590000                                       A DOT CO LTD
# 38     JP3108120001                                        ACRODEA INC
# 53     LU1250154413                                  ADO PROPERTIES SA
# 78     US0077371096                                   AEROCENTURY CORP
# 121    JP3102000001                                 AISIN SEIKI CO LTD
# ...             ...                                                ...
# 16577  US74838C1062                                     QUIKSILVER INC
# 16581  US7472623013                         QVC INC 6 3/8 09/13/67 PFD
# 16690  SE0010520155                          ROLLING OPTICS HOLDING AB
# 17055  US7847882005  SYNTHETIC FIXED-INCOME SEC STRATS 2004-2, 6.50...
# 17103  MHY8564M1057                             TEEKAY LNG PARTNERS LP
#
#                     longName-FIGI  fuzz_socre1
# 2                     BIRDMAN INC           26
# 38     THE WHY HOW DO COMPANY INC           32
# 53                 ADLER GROUP SA           58
# 78               MEGA MATRIX CORP           25
# 121                    AISIN CORP           57
# ...                           ...          ...
# 16577             BOARDRIDERS INC           21
# 16581                     QVC INC           42
# 16690                     ICTA AB           31
# 17055             STRATS-FON-04-2           36
# 17103                 SEAPEAK LLC           30
#
# [158 rows x 4 columns]

# %% [markdown]
# ## Merge after manually check

# %%
path = "./Data/withFIGI.csv"

df_figiCk = pd.read_csv("./Data/figi-197.csv")
df_ibCk = pd.read_csv("./Data/ib-197.csv") 
df_eodCk = pd.read_csv("./Data/eod-197.csv") 
df_invCk = pd.read_csv("./Data/inv-197.csv")

# %%
df_ck = pd.merge(df_figiCk, df_ibCk, how='outer', on=['ISIN', 'Name_197'])
df_ck = pd.merge(df_ck, df_eodCk, how='outer', on=['ISIN', 'Name_197'])
df_ck = pd.merge(df_ck, df_invCk, how='outer', on=['ISIN', 'Name_197'])

df_ck = df_ck[['ISIN', 'Name_197', 'longName-FIGI', 'check-FIGI', 'longName-IB', 'check-IB', 'Name-EOD', 'check-EOD', 'full_name-Inv', 'Check-Inv']]

df_ck
# Out:
#              ISIN                      Name_197               longName-FIGI  \
# 0    JP3160590000                  A DOT CO LTD                 BIRDMAN INC
# 1    JP3108120001                   ACRODEA INC  THE WHY HOW DO COMPANY INC
# 2    LU1250154413             ADO PROPERTIES SA              ADLER GROUP SA
# 3    US0077371096              AEROCENTURY CORP            MEGA MATRIX CORP
# 4    JP3102000001            AISIN SEIKI CO LTD                  AISIN CORP
# ..            ...                           ...                         ...
# 405  CNE100002W92     YOUON TECHNOLOGY CO LTD-A                         NaN
# 406  CH0276534614           ZEHNDER GROUP AG-RG                         NaN
# 407  CNE000000FL2  ZHONGTIAN FINANCIAL GROUP -A                         NaN
# 408  HU0000074844               ZWACK UNICUM RT                         NaN
# 409  US5006432000                    KORN FERRY                         NaN
#
#      check-FIGI longName-IB check-IB  \
# 0           0.0         NaN      NaN
# 1           0.0         NaN      NaN
# 2           0.0         NaN      NaN
# 3           0.0         NaN      NaN
# 4           1.0         NaN      NaN
# ..          ...         ...      ...
# 405         NaN         NaN      NaN
# 406         NaN         NaN      NaN
# 407         NaN         NaN      NaN
# 408         NaN         NaN      NaN
# 409         NaN         NaN      NaN
#
#                                           Name-EOD  check-EOD  \
# 0                                              NaN        NaN
# 1                                Why How Do Co Inc        0.0
# 2                                   Adler Group SA        0.0
# 3                                 Mega Matrix Corp        0.0
# 4                                              NaN        NaN
# ..                                             ...        ...
# 405  Changzhou Youon Pubilic Bicycle System Co Ltd        1.0
# 406                                        Zehnder        1.0
# 407       Zhongtian Urban Development Group Co Ltd        1.0
# 408  Zwack Unicum Likoripari es Kereskedelmi Nyrt.        1.0
# 409                                            NaN        NaN
#
#                 full_name-Inv  Check-Inv
# 0                         NaN        NaN
# 1                         NaN        NaN
# 2                         NaN        NaN
# 3                         NaN        NaN
# 4                         NaN        NaN
# ..                        ...        ...
# 405                       NaN        NaN
# 406                       NaN        NaN
# 407                       NaN        NaN
# 408                       NaN        NaN
# 409  Korn/Ferry International        1.0
#
# [410 rows x 10 columns]

# %%
df_ck['Not_Match'] = ""

df_ck.loc[df_ck['check-FIGI']==0,'Not_Match'] = 'FIGI;'
df_ck.loc[df_ck['check-IB']==0,'Not_Match'] = 'IB;' + df_ck['Not_Match'].astype(str)
df_ck.loc[df_ck['check-EOD']==0,'Not_Match'] = 'EOD;' + df_ck['Not_Match'].astype(str)
df_ck.loc[df_ck['Check-Inv']==0,'Not_Match'] = 'Inv;' + df_ck['Not_Match'].astype(str)

df_ck['Not_Match'] = df_ck['Not_Match'].replace('', np.nan)

df_ck
# Out:
#              ISIN                      Name_197               longName-FIGI  \
# 0    JP3160590000                  A DOT CO LTD                 BIRDMAN INC
# 1    JP3108120001                   ACRODEA INC  THE WHY HOW DO COMPANY INC
# 2    LU1250154413             ADO PROPERTIES SA              ADLER GROUP SA
# 3    US0077371096              AEROCENTURY CORP            MEGA MATRIX CORP
# 4    JP3102000001            AISIN SEIKI CO LTD                  AISIN CORP
# ..            ...                           ...                         ...
# 405  CNE100002W92     YOUON TECHNOLOGY CO LTD-A                         NaN
# 406  CH0276534614           ZEHNDER GROUP AG-RG                         NaN
# 407  CNE000000FL2  ZHONGTIAN FINANCIAL GROUP -A                         NaN
# 408  HU0000074844               ZWACK UNICUM RT                         NaN
# 409  US5006432000                    KORN FERRY                         NaN
#
#      check-FIGI longName-IB check-IB  \
# 0           0.0         NaN      NaN
# 1           0.0         NaN      NaN
# 2           0.0         NaN      NaN
# 3           0.0         NaN      NaN
# 4           1.0         NaN      NaN
# ..          ...         ...      ...
# 405         NaN         NaN      NaN
# 406         NaN         NaN      NaN
# 407         NaN         NaN      NaN
# 408         NaN         NaN      NaN
# 409         NaN         NaN      NaN
#
#                                           Name-EOD  check-EOD  \
# 0                                              NaN        NaN
# 1                                Why How Do Co Inc        0.0
# 2                                   Adler Group SA        0.0
# 3                                 Mega Matrix Corp        0.0
# 4                                              NaN        NaN
# ..                                             ...        ...
# 405  Changzhou Youon Pubilic Bicycle System Co Ltd        1.0
# 406                                        Zehnder        1.0
# 407       Zhongtian Urban Development Group Co Ltd        1.0
# 408  Zwack Unicum Likoripari es Kereskedelmi Nyrt.        1.0
# 409                                            NaN        NaN
#
#                 full_name-Inv  Check-Inv  Not_Match
# 0                         NaN        NaN      FIGI;
# 1                         NaN        NaN  EOD;FIGI;
# 2                         NaN        NaN  EOD;FIGI;
# 3                         NaN        NaN  EOD;FIGI;
# 4                         NaN        NaN        NaN
# ..                        ...        ...        ...
# 405                       NaN        NaN        NaN
# 406                       NaN        NaN        NaN
# 407                       NaN        NaN        NaN
# 408                       NaN        NaN        NaN
# 409  Korn/Ferry International        1.0        NaN
#
# [410 rows x 11 columns]

# %%
df_matchFinal = df_ck[df_ck['Not_Match']!='']
df_matchFinal
# Out:
#              ISIN                      Name_197               longName-FIGI  \
# 0    JP3160590000                  A DOT CO LTD                 BIRDMAN INC
# 1    JP3108120001                   ACRODEA INC  THE WHY HOW DO COMPANY INC
# 2    LU1250154413             ADO PROPERTIES SA              ADLER GROUP SA
# 3    US0077371096              AEROCENTURY CORP            MEGA MATRIX CORP
# 4    JP3102000001            AISIN SEIKI CO LTD                  AISIN CORP
# ..            ...                           ...                         ...
# 405  CNE100002W92     YOUON TECHNOLOGY CO LTD-A                         NaN
# 406  CH0276534614           ZEHNDER GROUP AG-RG                         NaN
# 407  CNE000000FL2  ZHONGTIAN FINANCIAL GROUP -A                         NaN
# 408  HU0000074844               ZWACK UNICUM RT                         NaN
# 409  US5006432000                    KORN FERRY                         NaN
#
#      check-FIGI longName-IB check-IB  \
# 0           0.0         NaN      NaN
# 1           0.0         NaN      NaN
# 2           0.0         NaN      NaN
# 3           0.0         NaN      NaN
# 4           1.0         NaN      NaN
# ..          ...         ...      ...
# 405         NaN         NaN      NaN
# 406         NaN         NaN      NaN
# 407         NaN         NaN      NaN
# 408         NaN         NaN      NaN
# 409         NaN         NaN      NaN
#
#                                           Name-EOD  check-EOD  \
# 0                                              NaN        NaN
# 1                                Why How Do Co Inc        0.0
# 2                                   Adler Group SA        0.0
# 3                                 Mega Matrix Corp        0.0
# 4                                              NaN        NaN
# ..                                             ...        ...
# 405  Changzhou Youon Pubilic Bicycle System Co Ltd        1.0
# 406                                        Zehnder        1.0
# 407       Zhongtian Urban Development Group Co Ltd        1.0
# 408  Zwack Unicum Likoripari es Kereskedelmi Nyrt.        1.0
# 409                                            NaN        NaN
#
#                 full_name-Inv  Check-Inv  Not_Match
# 0                         NaN        NaN      FIGI;
# 1                         NaN        NaN  EOD;FIGI;
# 2                         NaN        NaN  EOD;FIGI;
# 3                         NaN        NaN  EOD;FIGI;
# 4                         NaN        NaN        NaN
# ..                        ...        ...        ...
# 405                       NaN        NaN        NaN
# 406                       NaN        NaN        NaN
# 407                       NaN        NaN        NaN
# 408                       NaN        NaN        NaN
# 409  Korn/Ferry International        1.0        NaN
#
# [410 rows x 11 columns]

# %%
df = pd.merge(df, df_matchFinal[['ISIN','Not_Match']], how='outer', on='ISIN')

df
# Out:
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0         TWOU         USA          USD           US  US90214J1016
# 1          88E          UK          GBX          LSE  AU00000088E2
# 2         7063       Japan          JPY          TSE  JP3160590000
# 3         2018   Hong Kong          HKD           HK  KYG2953R1149
# 4         2686   Hong Kong          HKD           HK  KYG000371040
# ...        ...         ...          ...          ...           ...
# 17506      NaN         NaN          NaN          NaN  US98979J1097
# 17507      NaN         NaN          NaN          NaN  CA98977K1084
# 17508      NaN         NaN          NaN          NaN  CA98977R1038
# 17509      NaN         NaN          NaN          NaN  GB00BMHTHT14
# 17510      NaN         NaN          NaN          NaN  US98986T1088
#
#                             Name-EOD      Type-EOD  previousClose-EOD  \
# 0                             2U Inc  Common Stock              9.200
# 1                      88 Energy Ltd  Common Stock              0.625
# 2                       A Dot Co Ltd  Common Stock           2064.000
# 3      AAC Technologies Holdings Inc  Common Stock             14.580
# 4            AAG Energy Holdings Ltd  Common Stock              1.410
# ...                              ...           ...                ...
# 17506                            NaN           NaN                NaN
# 17507                            NaN           NaN                NaN
# 17508                            NaN           NaN                NaN
# 17509                            NaN           NaN                NaN
# 17510                            NaN           NaN                NaN
#
#       previousCloseDate-EOD     country-Inv  ... compositeFIGI shareClassFIGI  \
# 0                2022-08-02   united states  ...  BBG001KS9450   BBG001V0RR30
# 1                2022-08-03  united kingdom  ...  BBG000BWTTK9   BBG001SCV1F7
# 2                2022-08-03           japan  ...  BBG00NG9S234   BBG00NG9S261
# 3                2022-08-03       hong kong  ...  BBG000C162Q4   BBG001SKMWN2
# 4                2022-08-03       hong kong  ...  BBG009CXGZ45   BBG009CXGZ54
# ...                     ...             ...  ...           ...            ...
# 17506                   NaN             NaN  ...           NaN            NaN
# 17507                   NaN             NaN  ...           NaN            NaN
# 17508                   NaN             NaN  ...  BBG000BYKYT4   BBG001SJS399
# 17509                   NaN             NaN  ...           NaN            NaN
# 17510                   NaN             NaN  ...  BBG005YZL2R6   BBG001T24RN2
#
#       exchCode-FIGI marketSector-FIGI securityDescription-FIGI  \
# 0                US            Equity                     TWOU
# 1                GR            Equity                      POQ
# 2                JP            Equity                     7063
# 3                GR            Equity                     A2XN
# 4                HK            Equity                     2686
# ...             ...               ...                      ...
# 17506           NaN               NaN                      NaN
# 17507           NaN               NaN                      NaN
# 17508            CN            Equity                    ZMD/H
# 17509           NaN               NaN                      NaN
# 17510            XS            Equity                  ZNGAEUR
#
#       securityType-FIGI securityType2-FIGI Not_Match_x Not_Match_y Not_Match
# 0          Common Stock       Common Stock         NaN         NaN       NaN
# 1          Common Stock       Common Stock         NaN         NaN       NaN
# 2          Common Stock       Common Stock       FIGI;       FIGI;     FIGI;
# 3          Common Stock       Common Stock         NaN         NaN       NaN
# 4          Common Stock       Common Stock         NaN         NaN       NaN
# ...                 ...                ...         ...         ...       ...
# 17506               NaN                NaN         NaN         NaN       NaN
# 17507               NaN                NaN         NaN         NaN       NaN
# 17508      Common Stock       Common Stock         NaN         NaN       NaN
# 17509               NaN                NaN         NaN         NaN       NaN
# 17510      Common Stock       Common Stock         NaN         NaN       NaN
#
# [17511 rows x 36 columns]

# %%
df.to_csv('./Data/withFIGI.csv')

# %%
df_notMatch = df[df['Not_Match']=='EOD;FIGI;']
df_notMatch = df_notMatch[['ISIN', 'Name-EOD', 'longName-FIGI']]

df_notMatch
# Out:
#                ISIN                                           Name-EOD  \
# 38     JP3108120001                                  Why How Do Co Inc
# 53     LU1250154413                                     Adler Group SA
# 78     US0077371096                                   Mega Matrix Corp
# 165    US0185811082                       Bread Financial Holdings Inc
# 484    JP3160770008                                      Wow World Inc
# 491    IL0011016669                  Abra Information Technologies Ltd
# 574    CNE0000005N4                  New Guomai Digital Culture Co Ltd
# 595    US09074B1070                         Renovare Environmental Inc
# 696    US1143401024                                         Azenta Inc
# 736    US1270971039                                 Coterra Energy Inc
# 1008   IL0004560129                       Upsellon Brands Holdings Ltd
# 1197   JP3236100008    Small and medium Sized Enterprises Holdings Inc
# 1227   US2289031005                                       Artivion Inc
# 1312   GB00B1722W11                                           Jet2 PLC
# 1496   GB0003085445                                  Unbound Group PLC
# 1899   JP3386460004                           Kidswell Bio Corporation
# 2051   GB00BYRH4982                           Rockwood Realisation PLC
# 2054   FR0011038348                                         Klarsen SA
# 2083   IM00B5VQMV65                                         Entain PLC
# 2332   JP3142450000                                          Bruno Inc
# 2510   US48123V1026                                     Ziff Davis Inc
# 2560   JP3385950005                                       Delsole Corp
# 2667   JP3226700007                       OLBA Healthcare Holdings Inc
# 2848   US5207761058                   Distribution Solutions Group Inc
# 2862   JP3980300002                                    CL Holdings Inc
# 2876   US5290431015                               LXP Industrial Trust
# 2894   US53261M1045                                          Edgio Inc
# 3104   IL0010826191                               Sharplink Gaming Ltd
# 3410   JP3754200008                                        Biprogy Inc
# 3682   JP3781520006                                Success Holders Inc
# 3707   JP3780150003                                         Tameny Inc
# 3943   US75605Y1064                           Anywhere Real Estate Inc
# 4061   GB00B7T77214                                  NatWest Group PLC
# 4177   US80874P1093                                 Light & Wonder Inc
# 4194   JP3347010005           Meldia Development & Construction CO LTD
# 4245   CNE000000C17                  DLG Exhibitions & Events Corp Ltd
# 4257   IL0003410169                          Nala Digital Commerce Ltd
# 4281   JP3373200009                                Kobelco Wire Co Ltd
# 4402   GB00BF1BK408                                Scirocco Energy PLC
# 4408   VGG826421023                                Nostromo Energy Ltd
# 4496   GB00B4X3Q493                                        Afentra PLC
# 4499   GB00B03HDJ73                                          Esken Ltd
# 4544   KYG857AT1018                       Imperium Financial Group Ltd
# 4573   JP3397150008                          Food & Life Companies Ltd
# 5153   CNE000000024                               Wushang Group Co Ltd
# 6830   US1255258576  Creative Media & Community Trust Corporation P...
# 7070   US74913G8731                  Qwest Corp 6 75 Notes Expiry 2057
# 11591  DE000A0DPRE6                                          Allane SE
# 11847  US22532R1014  Credit Enhanced Corts Trust For Aon Capital A GIC
# 12735  US94770G1058                                      Veridetx Corp
#
#                       longName-FIGI
# 38       THE WHY HOW DO COMPANY INC
# 53                   ADLER GROUP SA
# 78                 MEGA MATRIX CORP
# 165    BREAD FINANCIAL HOLDINGS INC
# 484                   WOW WORLD INC
# 491    ABRA INFORMATION TECHNOLOGIE
# 574    NEW GUOMAI DIGITAL CULTURE-A
# 595      RENOVARE ENVIRONMENTAL INC
# 696                      AZENTA INC
# 736              COTERRA ENERGY INC
# 1008   UPSELLON BRANDS HOLDINGS LTD
# 1197   SMALL AND MEDIUM SIZED ENTER
# 1227                   ARTIVION INC
# 1312                       JET2 PLC
# 1496              UNBOUND GROUP PLC
# 1899              KIDSWELL BIO CORP
# 2051         ROCKWOOD STRATEGIC PLC
# 2054                        KLARSEN
# 2083                     ENTAIN PLC
# 2332                      BRUNO INC
# 2510                 ZIFF DAVIS INC
# 2560                   DELSOLE CORP
# 2667   OLBA HEALTHCARE HOLDINGS INC
# 2848   DISTRIBUTION SOLUTIONS GROUP
# 2862                CL HOLDINGS INC
# 2876           LXP INDUSTRIAL TRUST
# 2894                      EDGIO INC
# 3104           SHARPLINK GAMING LTD
# 3410                    BIPROGY INC
# 3682            SUCCESS HOLDERS INC
# 3707                     TAMENY INC
# 3943       ANYWHERE REAL ESTATE INC
# 4061              NATWEST GROUP PLC
# 4177             LIGHT & WONDER INC
# 4194   MELDIA DEVELOPMENT & CONSTRU
# 4245   DLG EXHIBITIONS & EVENTS C-A
# 4257      NALA DIGITAL COMMERCE LTD
# 4281            KOBELCO WIRE CO LTD
# 4402            SCIROCCO ENERGY PLC
# 4408            NOSTROMO ENERGY LTD
# 4496                    AFENTRA PLC
# 4499                      ESKEN LTD
# 4544   IMPERIUM FINANCIAL GROUP LTD
# 4573      FOOD & LIFE COMPANIES LTD
# 5153         WUSHANG GROUP CO LTD-A
# 6830         CREATIVE MEDIA & CMNTY
# 7070                     QWEST CORP
# 11591                     ALLANE SE
# 11847       CORTS TRUST FOR AON CAP
# 12735                    ONEMETA AI

# %%
df_Name = df_notMatch.copy()

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['Name-EOD'],row['longName-FIGI'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])
df_match[df_match['fuzz_socre1']<60]
# Out:
# 50
# progress: 330.00%
# progress: 1190.00%
# progress: 5020.00%
# progress: 5120.00%
# progress: 6820.00%
# progress: 8490.00%
# progress: 13660.00%
# progress: 14140.00%
# progress: 25470.00%
#                ISIN                                           Name-EOD  \
# 2051   GB00BYRH4982                           Rockwood Realisation PLC
# 6830   US1255258576  Creative Media & Community Trust Corporation P...
# 7070   US74913G8731                  Qwest Corp 6 75 Notes Expiry 2057
# 12735  US94770G1058                                      Veridetx Corp
#
#                 longName-FIGI  fuzz_socre1
# 2051   ROCKWOOD STRATEGIC PLC           52
# 6830   CREATIVE MEDIA & CMNTY           49
# 7070               QWEST CORP           47
# 12735              ONEMETA AI           35
