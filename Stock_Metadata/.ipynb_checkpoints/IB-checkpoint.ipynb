# %%
import numpy as np
import pandas as pd
from ib_insync import *
from ib_insync.contract import Contract
from bs4 import BeautifulSoup as bs

# %% [markdown]
# 1) Interactive Brokers (IB); 2) ISIN datasets; 3)FIGI datasets; 4)EOD dataset;

# %%
util.startLoop()  # uncomment this line when in a notebook

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=412)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=412>

# %%
path = "./LIst of 19.7 Stocks with FIGI if available - By Evelyn.xlsx"

df_stockList = pd.read_excel(path, index_col=0)  
df_stockList.head()
# Out:
#   symbol_x            longName     Exchange                   Country  \
# 0      1ST       1ST GROUP LTD          ASX                 Australia
# 1     TWOU              2U INC       NASDAQ  United States of America
# 2     DDDX  3DX INDUSTRIES INC         PINK  United States of America
# 3      MMM               3M CO  US Exchange                    Mexico
# 4      88E       88 ENERGY LTD          LSE            United Kingdom
#
#                     country           name      full_name          isin  \
# 0                 australia            NaN            NaN           NaN
# 1  united states of america            NaN            NaN           NaN
# 2  united states of america            NaN            NaN           NaN
# 3                    mexico            NaN            NaN           NaN
# 4            united kingdom  88 Energy Ltd  88 Energy Ltd  AU00000088E2
#
#   currency_x currency_y  ...             Country_Final Code          figi  \
# 0        NaN        AUD  ...                 Australia  1.0  BBG008HNLRF4
# 1        NaN        USD  ...  United States of America  1.0  BBG001KS9450
# 2        NaN        USD  ...  United States of America  1.0  BBG000C129N6
# 3        NaN        NaN  ...                       NaN  NaN           NaN
# 4        GBP        GBP  ...            United Kingdom  1.0  BBG000C4PMQ3
#
#   compositeFIGI shareClassFIGI exchCode marketSector securityDescription  \
# 0  BBG008HNLRF4   BBG008HNLRG3       AU       Equity                 1ST
# 1  BBG001KS9450   BBG001V0RR30       US       Equity                TWOU
# 2  BBG000C129N6   BBG001STRH79       US       Equity                DDDX
# 3           NaN            NaN      NaN          NaN                 NaN
# 4  BBG000C4PMQ3   BBG001SCV1F7       AU       Equity                 88E
#
#    securityType securityType2
# 0  Common Stock  Common Stock
# 1  Common Stock  Common Stock
# 2  Common Stock  Common Stock
# 3           NaN           NaN
# 4  Common Stock  Common Stock
#
# [5 rows x 27 columns]

# %%
# stock = Stock('AMD', 'SMART', 'USD')
isinList = []

for index, row in df_stockList.iterrows():
    try:
        stock = Stock(row['symbol_x'], row['Exchange'], row['currency_y'])
        fundamentals = ib.reqFundamentalData(stock, 'ReportSnapshot')

        content = bs(fundamentals, "xml")
        ISIN = content.find(Type='ISIN').getText()
        print(ISIN)
    except:
        ISIN = None

    
    isinList.append(ISIN)
# Out:
# Error 200, reqId 4: No security definition has been found for the request, contract: Stock(symbol='TWOU', exchange='NASDAQ', currency='USD')
# Error 200, reqId 5: No security definition has been found for the request, contract: Stock(symbol='DDDX', exchange='PINK', currency='USD')
# Error 321, reqId 6: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='MMM', exchange='US Exchange')
# AU0000001ST0
# AU00000088E2
# Error 200, reqId 10: No security definition has been found for the request, contract: Stock(symbol='AMKBY', exchange='PINK', currency='USD')
# JP3160590000
# Error 200, reqId 12: No security definition has been found for the request, contract: Stock(symbol='AMRK', exchange='NASDAQ', currency='USD')
# FR0010050773
# Error 430, reqId 13: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AKH', exchange='VALUE', currency='EUR')
# Error 200, reqId 15: No security definition has been found for the request, contract: Stock(symbol='AACH', exchange='PINK', currency='USD')
# SG1S12926576
# Error 200, reqId 18: No security definition has been found for the request, contract: Stock(symbol='AAON', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19: No security definition has been found for the request, contract: Stock(symbol='AAALY', exchange='PINK', currency='USD')
# INE721Z01010
# INE767A01016
# INE769A01020
# INE216P01012
# Error 200, reqId 26: No security definition has been found for the request, contract: Stock(symbol='ABQQ', exchange='PINK', currency='USD')
# Error 200, reqId 27: No security definition has been found for the request, contract: Stock(symbol='ABTO', exchange='PINK', currency='USD')
# GB00B9GQVG73
# Error 200, reqId 29: No security definition has been found for the request, contract: Stock(symbol='ABKI', exchange='VALUE', currency='USD')
# AU000000ABP9
# Error 200, reqId 31: No security definition has been found for the request, contract: Stock(symbol='ATTBF', exchange='PINK', currency='USD')
# INE421A01028
# Error 430, reqId 32: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ABAX', exchange='VALUE', currency='USD')
# INE117A01022
# Error 200, reqId 35: No security definition has been found for the request, contract: Stock(symbol='ABA', exchange='PURE', currency='CAD')
# Error 200, reqId 36: No security definition has been found for the request, contract: Stock(symbol='ABBY', exchange='LSE', currency='GBP')
# INE117A01022
# Error 321, reqId 38: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ABT', exchange='US Exchange')
# INE358A01014
# Error 200, reqId 40: No security definition has been found for the request, contract: Stock(symbol='ABBY', exchange='PINK', currency='USD')
# Error 200, reqId 42: No security definition has been found for the request, contract: Stock(symbol='ABCE', exchange='PINK', currency='USD')
# Error 200, reqId 43: No security definition has been found for the request, contract: Stock(symbol='ABMBF', exchange='PINK', currency='USD')
# Error 200, reqId 44: No security definition has been found for the request, contract: Stock(symbol='ABNAF', exchange='PINK', currency='USD')
# Error 200, reqId 45: No security definition has been found for the request, contract: Stock(symbol='ABEO', exchange='NASDAQ', currency='USD')
# Error 321, reqId 46: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ANF', exchange='US Exchange')
# JP3152740001
# GB00B0P6J834
# Error 430, reqId 49: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='GCH', exchange='VALUE', currency='USD')
# Error 430, reqId 50: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='IF', exchange='VALUE', currency='USD')
# Error 200, reqId 51: No security definition has been found for the request, contract: Stock(symbol='AABVF', exchange='PINK', currency='USD')
# Error 430, reqId 52: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ISL', exchange='VALUE', currency='USD')
# Error 200, reqId 55: No security definition has been found for the request, contract: Stock(symbol='ANW', exchange='LSE', currency='GBP')
# Error 200, reqId 56: No security definition has been found for the request, contract: Stock(symbol='APEF', exchange='VALUE', currency='GBP')
# GB0003920757
# GB00BMF19B58
# GB0000066554
# Error 430, reqId 59: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ASIZ', exchange='LSE', currency='GBP')
# Error 430, reqId 60: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ASIZ', exchange='LSE', currency='GBP')
# Error 200, reqId 61: No security definition has been found for the request, contract: Stock(symbol='ABL', exchange='ASX', currency='AUD')
# Error 321, reqId 63: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ABMD', exchange='US Exchange')
# Error 200, reqId 64: No security definition has been found for the request, contract: Stock(symbol='RZZ', exchange='VENTURE', currency='CAD')
# Error 200, reqId 65: No security definition has been found for the request, contract: Stock(symbol='ABLE', exchange='VALUE', currency='USD')
# NL0011540547
# Error 200, reqId 70: No security definition has been found for the request, contract: Stock(symbol='ABTZY', exchange='PINK', currency='USD')
# BE0974278104
# SG0533000253
# Error 200, reqId 73: No security definition has been found for the request, contract: Stock(symbol='AXAS', exchange='NASDAQ', currency='USD')
# ZAE000255915
# SE0006256558
# Error 430, reqId 76: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ABRL', exchange='VALUE', currency='GBP')
# SG2C12961455
# Error 200, reqId 79: No security definition has been found for the request, contract: Stock(symbol='ACEN', exchange='VALUE', currency='USD')
# Error 200, reqId 80: No security definition has been found for the request, contract: Stock(symbol='ACIU', exchange='NASDAQ', currency='USD')
# Error 200, reqId 81: No security definition has been found for the request, contract: Stock(symbol='AJC', exchange='ASX', currency='AUD')
# Error 200, reqId 82: No security definition has been found for the request, contract: Stock(symbol='ACIA', exchange='NASDAQ', currency='USD')
# Error 200, reqId 83: No security definition has been found for the request, contract: Stock(symbol='ACCA', exchange='PINK', currency='USD')
# SG1I02877971
# Error 430, reqId 84: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACA', exchange='VALUE', currency='GBP')
# Error 200, reqId 85: No security definition has been found for the request, contract: Stock(symbol='ACPH', exchange='ENEXT.BE', currency='EUR')
# Error 200, reqId 86: No security definition has been found for the request, contract: Stock(symbol='ACTG', exchange='NASDAQ', currency='USD')
# Error 200, reqId 88: No security definition has been found for the request, contract: Stock(symbol='ACHC', exchange='NASDAQ', currency='USD')
# Error 200, reqId 89: No security definition has been found for the request, contract: Stock(symbol='ACAD', exchange='NASDAQ', currency='USD')
# AU000000AKG9
# Error 200, reqId 92: No security definition has been found for the request, contract: Stock(symbol='ACAMU', exchange='NASDAQ', currency='USD')
# Error 200, reqId 93: No security definition has been found for the request, contract: Stock(symbol='AEF', exchange='TSE', currency='CAD')
# Error 200, reqId 94: No security definition has been found for the request, contract: Stock(symbol='ACST', exchange='NASDAQ', currency='USD')
# Error 200, reqId 95: No security definition has been found for the request, contract: Stock(symbol='ACNV', exchange='PINK', currency='USD')
# Error 200, reqId 96: No security definition has been found for the request, contract: Stock(symbol='XLRN', exchange='NASDAQ', currency='USD')
# Error 200, reqId 99: No security definition has been found for the request, contract: Stock(symbol='ACLP', exchange='VALUE', currency='USD')
# NL0009767532
# INE793A01012
# Error 200, reqId 102: No security definition has been found for the request, contract: Stock(symbol='ABPI', exchange='VALUE', currency='USD')
# Error 321, reqId 103: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ACN', exchange='US Exchange')
# AU000000AX19
# JP3108060009
# Error 200, reqId 106: No security definition has been found for the request, contract: Stock(symbol='ACCR', exchange='PINK', currency='USD')
# JP3108190004
# GB0001771426
# Error 430, reqId 108: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACE', exchange='VALUE', currency='GBP')
# ES0125220311
# FR0000120404
# Error 200, reqId 113: No security definition has been found for the request, contract: Stock(symbol='ADQU', exchange='SGX', currency='SGD')
# JP3108180005
# GB00BZ6VT592
# GB00BQQFX454
# Error 200, reqId 118: No security definition has been found for the request, contract: Stock(symbol='ARAY', exchange='NASDAQ', currency='USD')
# INE648Z01015
# Error 430, reqId 119: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACW', exchange='VALUE', currency='USD')
# Error 200, reqId 121: No security definition has been found for the request, contract: Stock(symbol='ACRX', exchange='NASDAQ', currency='USD')
# INE543V01017
# Error 430, reqId 122: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACD', exchange='VALUE', currency='USD')
# Error 430, reqId 123: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACID', exchange='LSEIOB1', currency='USD')
# Error 200, reqId 124: No security definition has been found for the request, contract: Stock(symbol='ACER', exchange='NASDAQ', currency='USD')
# Error 200, reqId 125: No security definition has been found for the request, contract: Stock(symbol='ASPCF', exchange='PINK', currency='USD')
# Error 200, reqId 127: No security definition has been found for the request, contract: Stock(symbol='AKAOQ', exchange='PINK', currency='USD')
# SG1Q66923448
# Error 430, reqId 128: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='1715', exchange='VALUE', currency='TWD')
# JP3108000005
# Error 430, reqId 130: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADA', exchange='FWB2', currency='EUR')
# Error 200, reqId 132: No security definition has been found for the request, contract: Stock(symbol='ACIW', exchange='NASDAQ', currency='USD')
# Error 200, reqId 134: No security definition has been found for the request, contract: Stock(symbol='AKRFF', exchange='PINK', currency='USD')
# Error 200, reqId 135: No security definition has been found for the request, contract: Stock(symbol='ACRS', exchange='NASDAQ', currency='USD')
# Error 200, reqId 136: No security definition has been found for the request, contract: Stock(symbol='ACMR', exchange='NASDAQ', currency='USD')
# BE0003764785
# Error 200, reqId 139: No security definition has been found for the request, contract: Stock(symbol='ACNB', exchange='NASDAQ', currency='USD')
# JP3108100003
# JP3108600002
# Error 430, reqId 141: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACX', exchange='VALUE', currency='AUD')
# Error 200, reqId 142: No security definition has been found for the request, contract: Stock(symbol='ACOR', exchange='NASDAQ', currency='USD')
# Error 200, reqId 144: No security definition has been found for the request, contract: Stock(symbol='ACFN', exchange='PINK', currency='USD')
# Error 200, reqId 145: No security definition has been found for the request, contract: Stock(symbol='AIF', exchange='LSE', currency='GBP')
# Error 200, reqId 146: No security definition has been found for the request, contract: Stock(symbol='ATV', exchange='NYSE', currency='USD')
# Error 200, reqId 147: No security definition has been found for the request, contract: Stock(symbol='ACO', exchange='BVME', currency='EUR')
# AU000000ACQ5
# Error 430, reqId 148: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AIII', exchange='DOLLR4LOT', currency='USD')
# Error 200, reqId 149: No security definition has been found for the request, contract: Stock(symbol='ACRGF', exchange='PINK', currency='USD')
# JP3108120001
# AU0000006124
# Error 430, reqId 152: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ACT', exchange='VALUE', currency='EUR')
# SE0009269467
# AU000000ACW3
# INE731H01025
# Error 200, reqId 158: No security definition has been found for the request, contract: Stock(symbol='ACARQ', exchange='VALUE', currency='USD')
# GB00BPG7NS80
# Error 321, reqId 160: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ATVI', exchange='US Exchange')
# JP3047490002
# Error 321, reqId 162: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AYI', exchange='US Exchange')
# GB00BJ05QC14
# Error 200, reqId 164: No security definition has been found for the request, contract: Stock(symbol='ACUR', exchange='PINK', currency='USD')
# Error 200, reqId 166: No security definition has been found for the request, contract: Stock(symbol='ACUS', exchange='PINK', currency='USD')
# Error 430, reqId 167: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADSYQ', exchange='DOLLR4LOT', currency='USD')
# AU000000ADA7
# AU000000ADH2
# AU0000001AD2
# Error 200, reqId 172: No security definition has been found for the request, contract: Stock(symbol='ADAC', exchange='VALUE', currency='USD')
# Error 200, reqId 173: No security definition has been found for the request, contract: Stock(symbol='ADAM', exchange='LSE', currency='GBP')
# Error 200, reqId 174: No security definition has been found for the request, contract: Stock(symbol='ADMS', exchange='NASDAQ', currency='USD')
# CNE0000004V0
# Error 200, reqId 176: No security definition has been found for the request, contract: Stock(symbol='ADMP', exchange='NASDAQ', currency='USD')
# IM00B986V543
# Error 200, reqId 180: No security definition has been found for the request, contract: Stock(symbol='ADANIGAS', exchange='NSE', currency='INR')
# INE423A01024
# INE364U01010
# INE742F01042
# INE814H01011
# Error 200, reqId 185: No security definition has been found for the request, contract: Stock(symbol='ADAP', exchange='NASDAQ', currency='USD')
# Error 200, reqId 186: No security definition has been found for the request, contract: Stock(symbol='AATV', exchange='PINK', currency='USD')
# Error 200, reqId 187: No security definition has been found for the request, contract: Stock(symbol='ADPT', exchange='NASDAQ', currency='USD')
# Error 200, reqId 188: No security definition has been found for the request, contract: Stock(symbol='ADTM', exchange='PINK', currency='USD')
# Error 200, reqId 189: No security definition has been found for the request, contract: Stock(symbol='ADOOY', exchange='PINK', currency='USD')
# INE931S01010
# JP3856000009
# Error 430, reqId 191: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADK', exchange='VALUE', currency='USD')
# Error 200, reqId 192: No security definition has been found for the request, contract: Stock(symbol='ADCO', exchange='VENTURE', currency='CAD')
# Error 200, reqId 193: No security definition has been found for the request, contract: Stock(symbol='ATXG', exchange='PINK', currency='USD')
# CH0029850754
# AT000ADDIKO0
# Error 200, reqId 197: No security definition has been found for the request, contract: Stock(symbol='ADUS', exchange='NASDAQ', currency='USD')
# CNE000000DM5
# SG1I67883666
# CH0012138605
# JP3114800000
# Error 430, reqId 201: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AYT', exchange='VALUE', currency='AUD')
# Error 200, reqId 202: No security definition has been found for the request, contract: Stock(symbol='ADPAS', exchange='VALUE', currency='USD')
# Error 430, reqId 203: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADPTQ', exchange='VALUE', currency='USD')
# Error 200, reqId 204: No security definition has been found for the request, contract: Stock(symbol='ADES', exchange='LSE', currency='USD')
# Error 430, reqId 205: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='IOTS', exchange='VALUE', currency='USD')
# INE982B01019
# Error 200, reqId 209: No security definition has been found for the request, contract: Stock(symbol='ADFT', exchange='PINK', currency='USD')
# Error 200, reqId 210: No security definition has been found for the request, contract: Stock(symbol='ATRX', exchange='PINK', currency='USD')
# Error 200, reqId 212: No security definition has been found for the request, contract: Stock(symbol='ADHUNIKIN', exchange='NSE', currency='INR')
# AU000000ADR1
# Error 430, reqId 213: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADHUNIK', exchange='VALUE', currency='INR')
# Error 200, reqId 214: No security definition has been found for the request, contract: Stock(symbol='ADIL', exchange='NASDAQ', currency='USD')
# Error 200, reqId 216: No security definition has been found for the request, contract: Stock(symbol='ADDYY', exchange='PINK', currency='USD')
# Error 321, reqId 217: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ADNT', exchange='US Exchange')
# Error 200, reqId 218: No security definition has been found for the request, contract: Stock(symbol='ADKT', exchange='PINK', currency='USD')
# DE000A1EWWW0
# INE674K01013
# Error 200, reqId 221: No security definition has been found for the request, contract: Stock(symbol='ADD', exchange='IBIS', currency='EUR')
# Error 200, reqId 222: No security definition has been found for the request, contract: Stock(symbol='ADMA', exchange='NASDAQ', currency='USD')
# INE865C01022
# Error 321, reqId 224: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ADBE', exchange='US Exchange')
# Error 200, reqId 225: No security definition has been found for the request, contract: Stock(symbol='ADOM', exchange='PINK', currency='USD')
# LU1250154413
# INE045A01017
# FR0010340141
# Error 430, reqId 228: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADT', exchange='ASX', currency='AUD')
# INE737B01033
# Error 321, reqId 231: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ADT.4', exchange='US Exchange')
# Error 321, reqId 232: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ATGE', exchange='US Exchange')
# Error 200, reqId 234: No security definition has been found for the request, contract: Stock(symbol='ADTN', exchange='NASDAQ', currency='USD')
# Error 200, reqId 235: No security definition has been found for the request, contract: Stock(symbol='ADRO', exchange='NASDAQ', currency='USD')
# JP3122010006
# Error 321, reqId 237: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AAP', exchange='US Exchange')
# CH0008967926
# Error 321, reqId 239: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AMD', exchange='US Exchange')
# JP3122150000
# SG1CJ7000006
# JP3213400009
# Error 321, reqId 243: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ASIX', exchange='US Exchange')
# Error 200, reqId 244: No security definition has been found for the request, contract: Stock(symbol='AVLIF', exchange='VALUE', currency='CAD')
# INE199C01026
# Error 430, reqId 245: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AVLIF', exchange='VALUE', currency='USD')
# Error 200, reqId 246: No security definition has been found for the request, contract: Stock(symbol='AAVVF', exchange='PINK', currency='USD')
# Error 200, reqId 248: No security definition has been found for the request, contract: Stock(symbol='AOC', exchange='PURE', currency='CAD')
# Error 200, reqId 249: No security definition has been found for the request, contract: Stock(symbol='ADGO', exchange='PINK', currency='USD')
# JP3122410008
# Error 200, reqId 251: No security definition has been found for the request, contract: Stock(symbol='ADVT', exchange='PINK', currency='USD')
# Error 200, reqId 252: No security definition has been found for the request, contract: Stock(symbol='ADXS', exchange='NASDAQ', currency='USD')
# JP3122400009
# JP3122380003
# Error 430, reqId 255: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ADV2', exchange='VALUE', currency='EUR')
# Error 200, reqId 256: No security definition has been found for the request, contract: Stock(symbol='ADVM', exchange='NASDAQ', currency='USD')
# Error 200, reqId 257: No security definition has been found for the request, contract: Stock(symbol='ADVIC', exchange='SBF', currency='EUR')
# Error 430, reqId 258: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AADR', exchange='ARCA', currency='USD')
# Error 430, reqId 259: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='FNG', exchange='VALUE', currency='USD')
# ZAE000031035
# JP3121970002
# Error 200, reqId 263: No security definition has been found for the request, contract: Stock(symbol='ADYX', exchange='PINK', currency='USD')
# AU000000ADX9
# CNE000000RM5
# Error 430, reqId 266: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AED', exchange='VALUE', currency='AUD')
# Error 200, reqId 267: No security definition has been found for the request, contract: Stock(symbol='AEGN', exchange='NASDAQ', currency='USD')
# Error 200, reqId 269: No security definition has been found for the request, contract: Stock(symbol='AGLE', exchange='NASDAQ', currency='USD')
# Error 200, reqId 270: No security definition has been found for the request, contract: Stock(symbol='AEB', exchange='NYSE', currency='USD')
# INE208C01025
# Error 200, reqId 272: No security definition has been found for the request, contract: Stock(symbol='AMTX', exchange='NASDAQ', currency='USD')
# Error 200, reqId 273: No security definition has been found for the request, contract: Stock(symbol='AOLS', exchange='PINK', currency='USD')
# SG1BA1000003
# Error 200, reqId 275: No security definition has been found for the request, contract: Stock(symbol='0900', exchange='SEHK', currency='HKD')
# CNE000001G46
# Error 200, reqId 277: No security definition has been found for the request, contract: Stock(symbol='AGHC', exchange='PINK', currency='USD')
# JP3131400008
# JP3131430005
# Error 200, reqId 280: No security definition has been found for the request, contract: Stock(symbol='0984', exchange='SEHK', currency='HKD')
# Error 200, reqId 281: No security definition has been found for the request, contract: Stock(symbol='AQSZF', exchange='PINK', currency='USD')
# AU000000AML5
# Error 200, reqId 283: No security definition has been found for the request, contract: Stock(symbol='AERI', exchange='NASDAQ', currency='USD')
# NL0000687663
# AU000000AEI8
# Error 430, reqId 285: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AIS', exchange='ASX', currency='AUD')
# Error 200, reqId 286: No security definition has been found for the request, contract: Stock(symbol='AKOM', exchange='PINK', currency='USD')
# Error 200, reqId 287: No security definition has been found for the request, contract: Stock(symbol='AERP', exchange='VALUE', currency='USD')
# Error 200, reqId 288: No security definition has been found for the request, contract: Stock(symbol='ACY', exchange='AMEX', currency='USD')
# Error 430, reqId 289: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ARX', exchange='VALUE', currency='USD')
# Error 200, reqId 291: No security definition has been found for the request, contract: Stock(symbol='AERZY', exchange='PINK', currency='USD')
# RU0009062285
# Error 430, reqId 293: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='600677', exchange='SEHKNTL', currency='CNH')
# CNE000000Y86
# Error 200, reqId 296: No security definition has been found for the request, contract: Stock(symbol='AOTL', exchange='VALUE', currency='USD')
# Error 200, reqId 297: No security definition has been found for the request, contract: Stock(symbol='AVAV', exchange='NASDAQ', currency='USD')
# Error 200, reqId 298: No security definition has been found for the request, contract: Stock(symbol='ARPO', exchange='NASDAQ', currency='USD')
# Error 321, reqId 299: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AES', exchange='US Exchange')
# CNE000001857
# Error 200, reqId 301: No security definition has been found for the request, contract: Stock(symbol='AEZS', exchange='NASDAQ', currency='USD')
# Error 200, reqId 302: No security definition has been found for the request, contract: Stock(symbol='ATHR', exchange='PURE', currency='CAD')
# Error 321, reqId 303: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AET', exchange='US Exchange')
# Error 200, reqId 304: No security definition has been found for the request, contract: Stock(symbol='HE8', exchange='VALUE', currency='USD')
# Error 430, reqId 305: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='HE8', exchange='VALUE', currency='EUR')
# Error 430, reqId 306: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='GNMX', exchange='VALUE', currency='USD')
# CH0478634105
# SG1C01001033
# FI0009800098
# GB00B18S7B29
# Error 321, reqId 312: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ACS', exchange='US Exchange')
# IL0005780130
# Error 200, reqId 314: No security definition has been found for the request, contract: Stock(symbol='ABVG', exchange='PINK', currency='USD')
# Error 200, reqId 315: No security definition has been found for the request, contract: Stock(symbol='AEB', exchange='ASX', currency='AUD')
# Error 200, reqId 316: No security definition has been found for the request, contract: Stock(symbol='AFYG', exchange='PINK', currency='USD')
# Error 430, reqId 318: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFFN', exchange='VALUE', currency='USD')
# Error 200, reqId 319: No security definition has been found for the request, contract: Stock(symbol='AFI', exchange='PURE', currency='CAD')
# Error 200, reqId 320: No security definition has been found for the request, contract: Stock(symbol='AFFMQ', exchange='VALUE', currency='USD')
# Error 200, reqId 322: No security definition has been found for the request, contract: Stock(symbol='AFFY', exchange='PINK', currency='USD')
# Error 200, reqId 323: No security definition has been found for the request, contract: Stock(symbol='AFHP', exchange='LSE', currency='GBP')
# Error 430, reqId 324: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFID', exchange='VALUE', currency='USD')
# Error 321, reqId 325: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AFL', exchange='US Exchange')
# Error 430, reqId 326: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFR', exchange='VALUE', currency='GBP')
# Error 200, reqId 327: No security definition has been found for the request, contract: Stock(symbol='HPMCF', exchange='PINK', currency='USD')
# Error 200, reqId 328: No security definition has been found for the request, contract: Stock(symbol='AFGC', exchange='VALUE', currency='USD')
# Error 200, reqId 330: No security definition has been found for the request, contract: Stock(symbol='AOIFF', exchange='PINK', currency='USD')
# Error 200, reqId 331: No security definition has been found for the request, contract: Stock(symbol='ACCS', exchange='VALUE', currency='USD')
# Error 200, reqId 332: No security definition has been found for the request, contract: Stock(symbol='AFR', exchange='ASX', currency='AUD')
# Error 200, reqId 333: No security definition has been found for the request, contract: Stock(symbol='AGGFF', exchange='VALUE', currency='USD')
# IL0010979487
# AU0000036949
# Error 430, reqId 335: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFMCF', exchange='VALUE', currency='USD')
# Error 200, reqId 336: No security definition has been found for the request, contract: Stock(symbol='AMLZF', exchange='PINK', currency='USD')
# ZAE000054045
# Error 200, reqId 339: No security definition has been found for the request, contract: Stock(symbol='AFTM', exchange='PINK', currency='USD')
# GG00BD95V148
# Error 430, reqId 340: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AFY', exchange='VALUE', currency='AUD')
# Error 200, reqId 341: No security definition has been found for the request, contract: Stock(symbol='AGGZF', exchange='PINK', currency='USD')
# INE204E01012
# Error 200, reqId 345: No security definition has been found for the request, contract: Stock(symbol='AGCNET', exchange='NSE', currency='INR')
# JP3112000009
# Error 200, reqId 349: No security definition has been found for the request, contract: Stock(symbol='AIFS', exchange='PINK', currency='USD')
# Error 200, reqId 350: No security definition has been found for the request, contract: Stock(symbol='AGMC', exchange='VALUE', currency='USD')
# Error 200, reqId 351: No security definition has been found for the request, contract: Stock(symbol='AGEN', exchange='NASDAQ', currency='USD')
# AU000000AU12
# Error 200, reqId 353: No security definition has been found for the request, contract: Stock(symbol='AGFMF', exchange='PINK', currency='USD')
# Error 200, reqId 354: No security definition has been found for the request, contract: Stock(symbol='AFGVY', exchange='PINK', currency='USD')
# Error 200, reqId 355: No security definition has been found for the request, contract: Stock(symbol='AGK', exchange='LSE', currency='GBP')
# Error 200, reqId 357: No security definition has been found for the request, contract: Stock(symbol='AGRX', exchange='NASDAQ', currency='USD')
# Error 321, reqId 358: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='A', exchange='US Exchange')
# Error 200, reqId 359: No security definition has been found for the request, contract: Stock(symbol='AGLY', exchange='PINK', currency='USD')
# Error 200, reqId 360: No security definition has been found for the request, contract: Stock(symbol='AGYS', exchange='NASDAQ', currency='USD')
# Error 200, reqId 361: No security definition has been found for the request, contract: Stock(symbol='AGIO', exchange='NASDAQ', currency='USD')
# Error 430, reqId 362: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGI', exchange='VALUE', currency='EUR')
# Error 200, reqId 363: No security definition has been found for the request, contract: Stock(symbol='AJX', exchange='TSE', currency='CAD')
# AU000000AGL7
# Error 430, reqId 365: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='GAS', exchange='VALUE', currency='USD')
# Error 200, reqId 366: No security definition has been found for the request, contract: Stock(symbol='AGMH', exchange='NASDAQ', currency='USD')
# Error 200, reqId 367: No security definition has been found for the request, contract: Stock(symbol='AGNCM', exchange='NASDAQ', currency='USD')
# Error 200, reqId 368: No security definition has been found for the request, contract: Stock(symbol='AGNCM', exchange='NASDAQ', currency='USD')
# Error 200, reqId 370: No security definition has been found for the request, contract: Stock(symbol='AGHI', exchange='PINK', currency='USD')
# JP3561200001
# JP3108170006
# Error 430, reqId 373: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='GRO', exchange='VALUE', currency='USD')
# Error 200, reqId 375: No security definition has been found for the request, contract: Stock(symbol='AGJ', exchange='ASX', currency='AUD')
# Error 200, reqId 376: No security definition has been found for the request, contract: Stock(symbol='EURI', exchange='VALUE', currency='USD')
# CNE100000Q43
# AU000000AMN1
# Error 430, reqId 378: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ANO', exchange='VALUE', currency='CAD')
# Error 200, reqId 379: No security definition has been found for the request, contract: Stock(symbol='AGRO', exchange='PURE', currency='CAD')
# Error 200, reqId 380: No security definition has been found for the request, contract: Stock(symbol='FBER', exchange='VALUE', currency='USD')
# Error 200, reqId 381: No security definition has been found for the request, contract: Stock(symbol='AGTK', exchange='PINK', currency='USD')
# Error 200, reqId 383: No security definition has been found for the request, contract: Stock(symbol='1131', exchange='SEHK', currency='HKD')
# GG00BDG13C09
# Error 430, reqId 384: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGU', exchange='VALUE', currency='USD')
# Error 200, reqId 385: No security definition has been found for the request, contract: Stock(symbol='ACMB', exchange='PINK', currency='USD')
# INE740V01019
# INE209A01019
# Error 200, reqId 389: No security definition has been found for the request, contract: Stock(symbol='AGFS', exchange='NASDAQ', currency='USD')
# JP3108200001
# Error 430, reqId 390: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGL', exchange='WSE', currency='PLN')
# Error 200, reqId 392: No security definition has been found for the request, contract: Stock(symbol='AGGL', exchange='PINK', currency='USD')
# CY0101062111
# AU000000AGR4
# Error 430, reqId 395: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AGL', exchange='VENTURE', currency='CAD')
# Error 200, reqId 396: No security definition has been found for the request, contract: Stock(symbol='AHC', exchange='NYSE', currency='USD')
# Error 200, reqId 397: No security definition has been found for the request, contract: Stock(symbol='AHL', exchange='ASX', currency='AUD')
# Error 430, reqId 398: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AHIMSA', exchange='NSE', currency='INR')
# Error 200, reqId 399: No security definition has been found for the request, contract: Stock(symbol='AM1S', exchange='SFB', currency='SEK')
# JP3100600000
# JP3105090009
# Error 430, reqId 402: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AIEQ', exchange='ARCA', currency='USD')
# INE212H01026
# Error 200, reqId 405: No security definition has been found for the request, contract: Stock(symbol='AIB', exchange='ISED', currency='EUR')
# HK0000069689
# JP3103600007
# JP3102400003
# JP3105040004
# Error 200, reqId 410: No security definition has been found for the request, contract: Stock(symbol='ALRN', exchange='NASDAQ', currency='USD')
# Error 200, reqId 411: No security definition has been found for the request, contract: Stock(symbol='GAPFF', exchange='PINK', currency='USD')
# Error 200, reqId 412: No security definition has been found for the request, contract: Stock(symbol='AIMT', exchange='NASDAQ', currency='USD')
# JP3101000002
# JP3105250009
# SE0009242555
# AU000000AGI3
# JP3105050003
# GB00B128C026
# Error 200, reqId 419: No security definition has been found for the request, contract: Stock(symbol='0753', exchange='SEHK', currency='HKD')
# Error 200, reqId 420: No security definition has been found for the request, contract: Stock(symbol='AIRYY', exchange='PINK', currency='USD')
# Error 321, reqId 422: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='APD', exchange='US Exchange')
# FR0000031122
# Error 200, reqId 424: No security definition has been found for the request, contract: Stock(symbol='ABPR', exchange='PINK', currency='USD')
# Error 200, reqId 425: No security definition has been found for the request, contract: Stock(symbol='ABWN', exchange='PINK', currency='USD')
# INE645W01026
# NL0000235190
# Error 430, reqId 428: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AYR', exchange='VALUE', currency='USD')
# Error 200, reqId 429: No security definition has been found for the request, contract: Stock(symbol='6944', exchange='TSEJ', currency='JPY')
# Error 200, reqId 430: No security definition has been found for the request, contract: Stock(symbol='AIRG', exchange='NASDAQ', currency='USD')
# Error 321, reqId 431: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ARG', exchange='US Exchange')
# Error 200, reqId 433: No security definition has been found for the request, contract: Stock(symbol='ANTE', exchange='NASDAQ', currency='USD')
# Error 430, reqId 434: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='CSSA', exchange='VALUE', currency='EUR')
# IL0010958358
# Error 200, reqId 437: No security definition has been found for the request, contract: Stock(symbol='AIPUY', exchange='PINK', currency='USD')
# Error 200, reqId 438: No security definition has been found for the request, contract: Stock(symbol='AIRO', exchange='PINK', currency='USD')
# JP3266050008
# JP3688100001
# GB00BKDRYJ47
# Error 430, reqId 441: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ATCH', exchange='DOLLR4LOT', currency='USD')
# JP3167240005
# JP3101600009
# JP3101800005
# JP3102000001
# Error 200, reqId 447: No security definition has been found for the request, contract: Stock(symbol='ASYI', exchange='VALUE', currency='USD')
# CNE000001FB1
# JP3160050005
# DE000A0WMPJ6
# JP3101850000
# GB00BFZNLB60
# AU000000AJL1
# INE031B01049
# Error 200, reqId 455: No security definition has been found for the request, contract: Stock(symbol='0538', exchange='SEHK', currency='HKD')
# JP3119600009
# INE298G01027
# Error 321, reqId 458: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AKS', exchange='US Exchange')
# Error 321, reqId 459: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AKAM', exchange='US Exchange')
# Error 200, reqId 460: No security definition has been found for the request, contract: Stock(symbol='AKTX', exchange='NASDAQ', currency='USD')
# Error 200, reqId 462: No security definition has been found for the request, contract: Stock(symbol='AKCA', exchange='NASDAQ', currency='USD')
# Error 200, reqId 463: No security definition has been found for the request, contract: Stock(symbol='AKBA', exchange='NASDAQ', currency='USD')
# JP3131000006
# JP3108400007
# Error 200, reqId 466: No security definition has been found for the request, contract: Stock(symbol='AKRYY', exchange='PINK', currency='USD')
# Error 200, reqId 467: No security definition has been found for the request, contract: Stock(symbol='KERN', exchange='NASDAQ', currency='USD')
# Error 200, reqId 468: No security definition has been found for the request, contract: Stock(symbol='AKRO', exchange='NASDAQ', currency='USD')
# NO0010234552
# JP3107400008
# Error 200, reqId 471: No security definition has been found for the request, contract: Stock(symbol='AKTAF', exchange='PINK', currency='USD')
# Error 200, reqId 472: No security definition has been found for the request, contract: Stock(symbol='AKRXQ', exchange='PINK', currency='USD')
# Error 200, reqId 473: No security definition has been found for the request, contract: Stock(symbol='AKTS', exchange='NASDAQ', currency='USD')
# JP3107600003
# INE523B01011
# INE542B01011
# Error 200, reqId 477: No security definition has been found for the request, contract: Stock(symbol='AKMNF', exchange='PINK', currency='USD')
# FI4000058870
# NO0003097503
# INE133A01011
# NL0013267909
# Error 200, reqId 482: No security definition has been found for the request, contract: Stock(symbol='AAIIQ', exchange='PINK', currency='USD')
# Error 200, reqId 483: No security definition has been found for the request, contract: Stock(symbol='ASR', exchange='TSE', currency='CAD')
# Error 200, reqId 487: No security definition has been found for the request, contract: Stock(symbol='ALAN', exchange='PINK', currency='USD')
# INE914E01040
# Error 200, reqId 490: No security definition has been found for the request, contract: Stock(symbol='AD', exchange='TSE', currency='CAD')
# Error 200, reqId 491: No security definition has been found for the request, contract: Stock(symbol='ALRM', exchange='NASDAQ', currency='USD')
# Error 321, reqId 492: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ALK', exchange='US Exchange')
# Error 200, reqId 493: No security definition has been found for the request, contract: Stock(symbol='AKGC', exchange='VALUE', currency='USD')
# Error 200, reqId 494: No security definition has been found for the request, contract: Stock(symbol='ASKE', exchange='PINK', currency='USD')
# Error 200, reqId 495: No security definition has been found for the request, contract: Stock(symbol='APTL', exchange='PINK', currency='USD')
# AU000000AUQ7
# GB00B06KBB18
# DE0006209901
# Error 321, reqId 499: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ALB', exchange='US Exchange')
# INE155C01010
# Error 200, reqId 502: No security definition has been found for the request, contract: Stock(symbol='ALAC', exchange='NASDAQ', currency='USD')
# Error 200, reqId 503: No security definition has been found for the request, contract: Stock(symbol='ALAC', exchange='NASDAQ', currency='USD')
# JP3126460009
# GB0004832472
# Error 200, reqId 506: No security definition has been found for the request, contract: Stock(symbol='ALBO', exchange='NASDAQ', currency='USD')
# GB0005581672
# Error 200, reqId 508: No security definition has been found for the request, contract: Stock(symbol='LQSIF', exchange='PINK', currency='USD')
# SE0008732218
# Error 430, reqId 509: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ALU', exchange='VALUE', currency='USD')
# Error 200, reqId 510: No security definition has been found for the request, contract: Stock(symbol='AEFS', exchange='LSE', currency='GBP')
# Error 200, reqId 511: No security definition has been found for the request, contract: Stock(symbol='ALCHEM', exchange='NSE', currency='INR')
# Error 200, reqId 512: No security definition has been found for the request, contract: Stock(symbol='AMS', exchange='PURE', currency='CAD')
# Error 430, reqId 513: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ALMY', exchange='VALUE', currency='USD')
# AU000000ALY0
# Error 200, reqId 516: No security definition has been found for the request, contract: Stock(symbol='0328', exchange='SEHK', currency='HKD')
# Error 321, reqId 517: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='AA', exchange='US Exchange')
# AU000000ALC6
# JP3126210008
# AU000000AL88
# Error 430, reqId 521: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ALD', exchange='VALUE', currency='GBP')
# Error 200, reqId 522: No security definition has been found for the request, contract: Stock(symbol='IRON', exchange='VALUE', currency='USD')
# Error 430, reqId 523: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='IRON', exchange='VALUE', currency='CAD')
# Error 200, reqId 524: No security definition has been found for the request, contract: Stock(symbol='ALDX', exchange='NASDAQ', currency='USD')
# Error 200, reqId 525: No security definition has been found for the request, contract: Stock(symbol='AIW', exchange='VALUE', currency='CAD')
# Error 430, reqId 526: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AIW', exchange='VALUE', currency='EUR')
# Error 200, reqId 527: No security definition has been found for the request, contract: Stock(symbol='LEP', exchange='ASX', currency='AUD')
# Error 200, reqId 529: No security definition has been found for the request, contract: Stock(symbol='ALEC', exchange='NASDAQ', currency='USD')
# SE0008348072
# INE426A01027
# Error 200, reqId 533: No security definition has been found for the request, contract: Stock(symbol='ALR', exchange='VALUE', currency='USD')
# Error 200, reqId 534: No security definition has been found for the request, contract: Stock(symbol='ALRS', exchange='NASDAQ', currency='USD')
# INE901L01018
# Error 200, reqId 536: No security definition has been found for the request, contract: Stock(symbol='AAWC', exchange='PINK', currency='USD')
# Error 430, reqId 537: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='AZX', exchange='VALUE', currency='CAD')
# Error 321, reqId 538: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ARE', exchange='US Exchange')
# Error 321, reqId 540: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ALXN', exchange='US Exchange')
# AU000000AJX6
# Error 430, reqId 542: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ALXA', exchange='VALUE', currency='USD')
# GB00BDHXPG30
# SE0000695876
# Error 200, reqId 546: No security definition has been found for the request, contract: Stock(symbol='AGNPF', exchange='PINK', currency='USD')
# Error 200, reqId 547: No security definition has been found for the request, contract: Stock(symbol='ALG', exchange='VALUE', currency='CAD')
# JP3126340003
# Error 430, reqId 550: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ALH', exchange='VALUE', currency='CAD')
# Error 200, reqId 553: No security definition has been found for the request, contract: Stock(symbol='0241', exchange='SEHK', currency='HKD')
# Error 200, reqId 556: No security definition has been found for the request, contract: Stock(symbol='ACNE', exchange='PINK', currency='USD')
# Error 200, reqId 557: No security definition has been found for the request, contract: Stock(symbol='ALCO', exchange='NASDAQ', currency='USD')
# AU000000AQI2
# Error 321, reqId 559: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ALGN', exchange='US Exchange')
# INE062D01024
# Error 200, reqId 561: No security definition has been found for the request, contract: Stock(symbol='ANCUF', exchange='PINK', currency='USD')
# Error 200, reqId 562: No security definition has been found for the request, contract: Stock(symbol='ALO', exchange='TSE', currency='CAD')
# Error 200, reqId 563: No security definition has been found for the request, contract: Stock(symbol='ALORY', exchange='PINK', currency='USD')
# ...
# Error 200, reqId 19497: No security definition has been found for the request, contract: Stock(symbol='YTY', exchange='HEX', currency='EUR')
# Error 200, reqId 19499: No security definition has been found for the request, contract: Stock(symbol='MAGIS', exchange='SBF', currency='EUR')
# Error 200, reqId 19501: No security definition has been found for the request, contract: Stock(symbol='YOGA', exchange='PINK', currency='USD')
# AU000000YOJ5
# JP3955200005
# JP3955000009
# JP3957000007
# JP3955800002
# JP3954200006
# JP3119950008
# JP3960000002
# CNE100000XX9
# SG1CB9000001
# SG1BA3000001
# CNE0000017Y6
# Error 200, reqId 19515: No security definition has been found for the request, contract: Stock(symbol='YRKB', exchange='PINK', currency='USD')
# Error 200, reqId 19516: No security definition has been found for the request, contract: Stock(symbol='YORW', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19517: No security definition has been found for the request, contract: Stock(symbol='2788', exchange='SEHK', currency='HKD')
# Error 200, reqId 19518: No security definition has been found for the request, contract: Stock(symbol='MR8', exchange='SGX', currency='SGD')
# Error 200, reqId 19519: No security definition has been found for the request, contract: Stock(symbol='YVI', exchange='VENTURE', currency='CAD')
# JP3961400003
# JP3958400008
# JP3958000006
# JP3953600008
# GB00B1VQ6H25
# Error 200, reqId 19526: No security definition has been found for the request, contract: Stock(symbol='YGYI', exchange='NASDAQ', currency='USD')
# JP3953750001
# CNE000000XR2
# CNE100002W92
# Error 200, reqId 19530: No security definition has been found for the request, contract: Stock(symbol='2268', exchange='SEHK', currency='HKD')
# DE000A161N14
# AU000000YOW8
# AU000000YPB9
# Error 200, reqId 19534: No security definition has been found for the request, contract: Stock(symbol='YRCW', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19535: No security definition has been found for the request, contract: Stock(symbol='YSTR', exchange='VALUE', currency='USD')
# CH0019396990
# MYL4677OO000
# Error 200, reqId 19541: No security definition has been found for the request, contract: Stock(symbol='0123', exchange='SEHK', currency='HKD')
# Error 200, reqId 19542: No security definition has been found for the request, contract: Stock(symbol='YUII', exchange='VALUE', currency='USD')
# JP3946000001
# JP3948000009
# Error 321, reqId 19546: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='YUM', exchange='US Exchange')
# Error 321, reqId 19547: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='YUMC', exchange='US Exchange')
# Error 200, reqId 19548: No security definition has been found for the request, contract: Stock(symbol='YUMAQ', exchange='PINK', currency='USD')
# Error 200, reqId 19549: No security definition has been found for the request, contract: Stock(symbol='2362', exchange='TSEJ', currency='JPY')
# Error 200, reqId 19550: No security definition has been found for the request, contract: Stock(symbol='0376', exchange='SEHK', currency='HKD')
# Error 200, reqId 19551: No security definition has been found for the request, contract: Stock(symbol='YJ', exchange='NASDAQ', currency='USD')
# JP3946400003
# CNE000000VG9
# CNE0000008X7
# CNE000000W13
# CNE0000011D3
# CNE100001WB5
# Error 200, reqId 19559: No security definition has been found for the request, contract: Stock(symbol='0096', exchange='SEHK', currency='HKD')
# CNE000000S01
# JP3948400001
# JP3948900000
# JP3949000008
# Error 200, reqId 19565: No security definition has been found for the request, contract: Stock(symbol='ZEL', exchange='ASX', currency='AUD')
# Error 200, reqId 19567: No security definition has been found for the request, contract: Stock(symbol='ZAAG', exchange='PINK', currency='USD')
# Error 200, reqId 19568: No security definition has been found for the request, contract: Stock(symbol='ZAD', exchange='VENTURE', currency='CAD')
# Error 200, reqId 19569: No security definition has been found for the request, contract: Stock(symbol='ZAGG', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19570: No security definition has been found for the request, contract: Stock(symbol='ZLAB', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19571: No security definition has been found for the request, contract: Stock(symbol='KAN', exchange='WSE', currency='PLN')
# Error 200, reqId 19572: No security definition has been found for the request, contract: Stock(symbol='ZMRK', exchange='PINK', currency='USD')
# JP3933800009
# Error 430, reqId 19574: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZAM', exchange='VALUE', currency='AUD')
# ZM0000000201
# Error 430, reqId 19576: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZGM', exchange='VALUE', currency='AUD')
# Error 430, reqId 19577: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZANA', exchange='VALUE', currency='USD')
# Error 200, reqId 19580: No security definition has been found for the request, contract: Stock(symbol='ZARFF', exchange='PINK', currency='USD')
# JP3345770006
# Error 430, reqId 19581: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZAYO', exchange='VALUE', currency='USD')
# Error 200, reqId 19582: No security definition has been found for the request, contract: Stock(symbol='ZAZA', exchange='VALUE', currency='USD')
# Error 430, reqId 19583: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZAZ', exchange='VALUE', currency='CAD')
# Error 430, reqId 19584: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZCL', exchange='VALUE', currency='CAD')
# Error 200, reqId 19585: No security definition has been found for the request, contract: Stock(symbol='ZEAL', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19586: No security definition has been found for the request, contract: Stock(symbol='ZBRA', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19587: No security definition has been found for the request, contract: Stock(symbol='ZMSPF', exchange='PINK', currency='USD')
# INE256A01028
# INE565L01011
# Error 200, reqId 19593: No security definition has been found for the request, contract: Stock(symbol='AMOO', exchange='VALUE', currency='USD')
# INE966H01019
# GB00BVGBY890
# CH0276534614
# AU000000ZLD1
# Error 200, reqId 19599: No security definition has been found for the request, contract: Stock(symbol='ZENA', exchange='TSE', currency='CAD')
# INE251B01027
# Error 200, reqId 19601: No security definition has been found for the request, contract: Stock(symbol='ZNGYQ', exchange='PINK', currency='USD')
# Error 200, reqId 19602: No security definition has been found for the request, contract: Stock(symbol='ZENG', exchange='VALUE', currency='USD')
# JP3427800002
# Error 430, reqId 19604: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZNT', exchange='VALUE', currency='AUD')
# Error 430, reqId 19605: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZENB', exchange='LSEIOB1', currency='USD')
# Error 200, reqId 19606: No security definition has been found for the request, contract: Stock(symbol='ZENITHBIR', exchange='NSE', currency='INR')
# Error 430, reqId 19607: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZNH', exchange='CORPACT', currency='CAD')
# INE058B01018
# Error 200, reqId 19611: No security definition has been found for the request, contract: Stock(symbol='ZENO', exchange='PINK', currency='USD')
# Error 200, reqId 19612: No security definition has been found for the request, contract: Stock(symbol='ZDEC', exchange='PINK', currency='USD')
# AU000000ZNC9
# JP3430400006
# INE520A01027
# Error 200, reqId 19616: No security definition has been found for the request, contract: Stock(symbol='0185', exchange='SEHK', currency='HKD')
# Error 200, reqId 19617: No security definition has been found for the request, contract: Stock(symbol='ZNTR', exchange='VALUE', currency='USD')
# JP3429300001
# Error 200, reqId 19619: No security definition has been found for the request, contract: Stock(symbol='ZEON', exchange='PINK', currency='USD')
# JP3725400000
# Error 430, reqId 19620: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZEP', exchange='VALUE', currency='USD')
# JP3428850006
# Error 430, reqId 19623: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZTA', exchange='VALUE', currency='AUD')
# Error 200, reqId 19626: No security definition has been found for the request, contract: Stock(symbol='ZHYLF', exchange='PINK', currency='USD')
# AU000000ZEU0
# CNE1000004R6
# CNE100001M12
# CNE100000KD8
# Error 200, reqId 19631: No security definition has been found for the request, contract: Stock(symbol='0576', exchange='SEHK', currency='HKD')
# CNE1000023M7
# CNE100001VW3
# CNE000000B18
# CNE000000WQ6
# CNE000001FJ4
# CNE0000010J2
# CNE1000004W6
# CNE0000013L2
# Error 200, reqId 19640: No security definition has been found for the request, contract: Stock(symbol='0564', exchange='SEHK', currency='HKD')
# CNE000000PY4
# CNE100002R65
# DE000ZDWT018
# CNE000001FM8
# CNE000000B75
# CNE100002TK0
# Error 200, reqId 19653: No security definition has been found for the request, contract: Stock(symbol='0881', exchange='SEHK', currency='HKD')
# SG2C76966531
# CNE000000FL2
# CNE100002GY8
# CNE000000149
# Error 200, reqId 19662: No security definition has been found for the request, contract: Stock(symbol='ZICX', exchange='PINK', currency='USD')
# CNE100001666
# MYA007968003
# Error 200, reqId 19665: No security definition has been found for the request, contract: Stock(symbol='ZGCO', exchange='PINK', currency='USD')
# AU000000ZGL4
# Error 200, reqId 19667: No security definition has been found for the request, contract: Stock(symbol='Z', exchange='NASDAQ', currency='USD')
# Error 321, reqId 19668: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ZBH', exchange='US Exchange')
# CNE100000502
# GB0061284906
# Error 200, reqId 19671: No security definition has been found for the request, contract: Stock(symbol='ZZZOF', exchange='VALUE', currency='USD')
# Error 200, reqId 19672: No security definition has been found for the request, contract: Stock(symbol='ZNBR', exchange='VALUE', currency='USD')
# Error 200, reqId 19673: No security definition has been found for the request, contract: Stock(symbol='ZOX', exchange='VALUE', currency='GBP')
# Error 430, reqId 19675: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZNK', exchange='VALUE', currency='EUR')
# Error 200, reqId 19676: No security definition has been found for the request, contract: Stock(symbol='ZN', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19678: No security definition has been found for the request, contract: Stock(symbol='ZIONL', exchange='NASDAQ', currency='USD')
# Error 321, reqId 19679: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ZION', exchange='US Exchange')
# Error 200, reqId 19680: No security definition has been found for the request, contract: Stock(symbol='ZIOP', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19681: No security definition has been found for the request, contract: Stock(symbol='ZIP', exchange='VALUE', currency='USD')
# Error 200, reqId 19683: No security definition has been found for the request, contract: Stock(symbol='ZIVO', exchange='PINK', currency='USD')
# Error 200, reqId 19684: No security definition has been found for the request, contract: Stock(symbol='ZIXI', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19685: No security definition has been found for the request, contract: Stock(symbol='ZKIN', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19686: No security definition has been found for the request, contract: Stock(symbol='ZNRG', exchange='PINK', currency='USD')
# AU0000218307
# INE206B01013
# INE761Y01019
# Error 430, reqId 19689: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZOES', exchange='VALUE', currency='USD')
# Error 200, reqId 19690: No security definition has been found for the request, contract: Stock(symbol='HNR', exchange='LSE', currency='GBP')
# Error 321, reqId 19691: Error validating request.-'bR' : cause - Currency NAN is not allowed., contract: Stock(symbol='ZTS', exchange='US Exchange')
# Error 200, reqId 19692: No security definition has been found for the request, contract: Stock(symbol='ZGNX', exchange='NASDAQ', currency='USD')
# JP3437400009
# Error 430, reqId 19694: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZR', exchange='VALUE', currency='CAD')
# Error 200, reqId 19695: No security definition has been found for the request, contract: Stock(symbol='ZOL', exchange='LSE', currency='GBP')
# Error 200, reqId 19697: No security definition has been found for the request, contract: Stock(symbol='ZDPY', exchange='PINK', currency='USD')
# Error 430, reqId 19698: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZONE', exchange='VENTURE', currency='CAD')
# Error 200, reqId 19701: No security definition has been found for the request, contract: Stock(symbol='ZMA', exchange='VALUE', currency='CAD')
# GB00B1FQDL10
# Error 200, reqId 19704: No security definition has been found for the request, contract: Stock(symbol='ZMD.H', exchange='VALUE', currency='CAD')
# Error 200, reqId 19705: No security definition has been found for the request, contract: Stock(symbol='ZPAS', exchange='PINK', currency='USD')
# CNE000001527
# Error 200, reqId 19707: No security definition has been found for the request, contract: Stock(symbol='ZSAN', exchange='NASDAQ', currency='USD')
# AU000000ZNO4
# INE358U01012
# GB0009896605
# Error 200, reqId 19711: No security definition has been found for the request, contract: Stock(symbol='ZVO', exchange='NASDAQ', currency='USD')
# CNE000001337
# JP3399310006
# Error 430, reqId 19713: The fundamentals data for the security specified is not available.failed to fetch, contract: Stock(symbol='ZPG', exchange='VALUE', currency='GBP')
# Error 200, reqId 19714: No security definition has been found for the request, contract: Stock(symbol='ZS', exchange='NASDAQ', currency='USD')
# CNE000000TK5
# Error 200, reqId 19718: No security definition has been found for the request, contract: Stock(symbol='ZUARIGLOB', exchange='NSE', currency='INR')
# INE840M01016
# CH0148052126
# JP3411900008
# Error 200, reqId 19722: No security definition has been found for the request, contract: Stock(symbol='ZUMZ', exchange='NASDAQ', currency='USD')
# JP3167800006
# AT0000837307
# CNE100001TL0
# Error 200, reqId 19727: No security definition has been found for the request, contract: Stock(symbol='ZURN', exchange='VIRTX', currency='CHF')
# Error 200, reqId 19728: No security definition has been found for the request, contract: Stock(symbol='ZUTEC', exchange='SFB', currency='SEK')
# CH0042615283
# JP3411810009
# Error 200, reqId 19731: No security definition has been found for the request, contract: Stock(symbol='ZYB', exchange='ASX', currency='AUD')
# HU0000074844
# INE768C01010
# Error 200, reqId 19734: No security definition has been found for the request, contract: Stock(symbol='ZYNE', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19735: No security definition has been found for the request, contract: Stock(symbol='ZYXI', exchange='NASDAQ', currency='USD')
# Error 200, reqId 19736: No security definition has been found for the request, contract: Stock(symbol='ZNGA', exchange='NASDAQ', currency='USD')
# GB0006971013
# KYG989MR1033

# %%
isinList
# Out:
# ['AU0000001ST0',
#  None,
#  None,
#  None,
#  'AU00000088E2',
#  None,
#  'JP3160590000',
#  None,
#  'FR0010050773',
#  None,
#  None,
#  'SG1S12926576',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE721Z01010',
#  None,
#  'INE767A01016',
#  'INE769A01020',
#  'INE216P01012',
#  'GB00B9GQVG73',
#  None,
#  None,
#  'AU000000ABP9',
#  None,
#  'INE421A01028',
#  None,
#  None,
#  'INE117A01022',
#  'INE117A01022',
#  None,
#  None,
#  'INE358A01014',
#  None,
#  None,
#  None,
#  'JP3152740001',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B0P6J834',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB0003920757',
#  None,
#  None,
#  'GB00BMF19B58',
#  'GB0000066554',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'NL0011540547',
#  'BE0974278104',
#  None,
#  'SG0533000253',
#  None,
#  None,
#  'ZAE000255915',
#  'SE0006256558',
#  None,
#  'SG2C12961455',
#  'SG1I02877971',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AKG9',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'NL0009767532',
#  None,
#  'INE793A01012',
#  'AU000000AX19',
#  None,
#  None,
#  'JP3108060009',
#  'JP3108190004',
#  None,
#  'GB0001771426',
#  None,
#  'ES0125220311',
#  None,
#  'FR0000120404',
#  None,
#  None,
#  'JP3108180005',
#  'GB00BZ6VT592',
#  'GB00BQQFX454',
#  'INE648Z01015',
#  None,
#  None,
#  'INE543V01017',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'SG1Q66923448',
#  None,
#  None,
#  'JP3108000005',
#  None,
#  None,
#  None,
#  'BE0003764785',
#  None,
#  None,
#  None,
#  None,
#  'JP3108100003',
#  None,
#  'JP3108600002',
#  None,
#  None,
#  'AU000000ACQ5',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3108120001',
#  'AU0000006124',
#  None,
#  'SE0009269467',
#  None,
#  'AU000000ACW3',
#  'INE731H01025',
#  'GB00BPG7NS80',
#  None,
#  'JP3047490002',
#  None,
#  'GB00BJ05QC14',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000ADA7',
#  'AU000000ADH2',
#  'AU0000001AD2',
#  'CNE0000004V0',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IM00B986V543',
#  'INE423A01024',
#  None,
#  'INE364U01010',
#  'INE742F01042',
#  'INE814H01011',
#  'INE931S01010',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3856000009',
#  None,
#  None,
#  None,
#  'CH0029850754',
#  'AT000ADDIKO0',
#  'CNE000000DM5',
#  None,
#  'SG1I67883666',
#  'CH0012138605',
#  'JP3114800000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE982B01019',
#  None,
#  None,
#  None,
#  'AU000000ADR1',
#  None,
#  None,
#  None,
#  'DE000A1EWWW0',
#  None,
#  None,
#  None,
#  'INE674K01013',
#  'INE865C01022',
#  None,
#  None,
#  'LU1250154413',
#  None,
#  None,
#  'INE045A01017',
#  'FR0010340141',
#  None,
#  'INE737B01033',
#  None,
#  None,
#  None,
#  'JP3122010006',
#  None,
#  None,
#  'CH0008967926',
#  None,
#  'JP3122150000',
#  None,
#  'SG1CJ7000006',
#  'JP3213400009',
#  'INE199C01026',
#  None,
#  None,
#  None,
#  None,
#  'JP3122410008',
#  None,
#  None,
#  'JP3122400009',
#  None,
#  None,
#  'JP3122380003',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ZAE000031035',
#  'JP3121970002',
#  'AU000000ADX9',
#  None,
#  'CNE000000RM5',
#  None,
#  None,
#  None,
#  'INE208C01025',
#  None,
#  None,
#  'SG1BA1000003',
#  None,
#  None,
#  'CNE000001G46',
#  None,
#  'JP3131400008',
#  None,
#  'JP3131430005',
#  'AU000000AML5',
#  None,
#  None,
#  'NL0000687663',
#  None,
#  'AU000000AEI8',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'RU0009062285',
#  None,
#  None,
#  None,
#  'CNE000000Y86',
#  'CNE000001857',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'CH0478634105',
#  'SG1C01001033',
#  'FI0009800098',
#  'GB00B18S7B29',
#  'IL0005780130',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IL0010979487',
#  None,
#  None,
#  None,
#  None,
#  'AU0000036949',
#  None,
#  None,
#  'ZAE000054045',
#  'GG00BD95V148',
#  None,
#  None,
#  None,
#  None,
#  'INE204E01012',
#  'JP3112000009',
#  None,
#  None,
#  None,
#  'AU000000AU12',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AGL7',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3561200001',
#  'JP3108170006',
#  None,
#  'CNE100000Q43',
#  None,
#  None,
#  'AU000000AMN1',
#  None,
#  None,
#  None,
#  None,
#  'GG00BDG13C09',
#  None,
#  None,
#  None,
#  'INE740V01019',
#  'INE209A01019',
#  'JP3108200001',
#  None,
#  None,
#  'CY0101062111',
#  None,
#  None,
#  'AU000000AGR4',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3100600000',
#  'JP3105090009',
#  None,
#  'INE212H01026',
#  'HK0000069689',
#  None,
#  'JP3103600007',
#  'JP3102400003',
#  'JP3105040004',
#  'JP3101000002',
#  None,
#  None,
#  None,
#  'JP3105250009',
#  'SE0009242555',
#  'AU000000AGI3',
#  'JP3105050003',
#  'GB00B128C026',
#  None,
#  None,
#  None,
#  'FR0000031122',
#  None,
#  'INE645W01026',
#  None,
#  None,
#  None,
#  'NL0000235190',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IL0010958358',
#  'JP3266050008',
#  None,
#  None,
#  'JP3688100001',
#  'GB00BKDRYJ47',
#  None,
#  'JP3167240005',
#  'JP3101600009',
#  'JP3101800005',
#  'JP3102000001',
#  'CNE000001FB1',
#  None,
#  'JP3160050005',
#  'DE000A0WMPJ6',
#  'JP3101850000',
#  'GB00BFZNLB60',
#  'AU000000AJL1',
#  'INE031B01049',
#  'JP3119600009',
#  None,
#  'INE298G01027',
#  None,
#  None,
#  None,
#  None,
#  'JP3131000006',
#  None,
#  None,
#  'JP3108400007',
#  'NO0010234552',
#  None,
#  None,
#  None,
#  'JP3107400008',
#  'JP3107600003',
#  None,
#  None,
#  None,
#  'INE523B01011',
#  'INE542B01011',
#  'FI4000058870',
#  None,
#  'NO0003097503',
#  'INE133A01011',
#  'NL0013267909',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE914E01040',
#  'AU000000AUQ7',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B06KBB18',
#  'DE0006209901',
#  None,
#  None,
#  'INE155C01010',
#  'JP3126460009',
#  None,
#  None,
#  'GB0004832472',
#  'GB0005581672',
#  None,
#  'SE0008732218',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000ALY0',
#  'AU000000ALC6',
#  None,
#  None,
#  'JP3126210008',
#  None,
#  'AU000000AL88',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'SE0008348072',
#  'INE426A01027',
#  'INE901L01018',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AJX6',
#  None,
#  'GB00BDHXPG30',
#  'SE0000695876',
#  'JP3126340003',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AQI2',
#  None,
#  None,
#  'INE062D01024',
#  None,
#  'SE0007158910',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE773I01017',
#  None,
#  None,
#  'INE540L01014',
#  None,
#  'INE150B01039',
#  None,
#  'DE0005110001',
#  None,
#  None,
#  None,
#  'INE418H01029',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AHQ4',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B02LCQ05',
#  None,
#  'AU000000AQZ6',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'SGXE65282837',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B11V7W98',
#  None,
#  None,
#  'GB00BNG2M159',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'AU000000AGE2',
#  None,
#  'IL0011014508',
#  None,
#  None,
#  None,
#  None,
#  'CH0008837566',
#  None,
#  'INE835G01018',
#  None,
#  None,
#  None,
#  None,
#  'FI0009013114',
#  None,
#  None,
#  'ES0157097017',
#  'INE326B01027',
#  None,
#  None,
#  None,
#  'IL0011176885',
#  None,
#  'IL0003900136',
#  None,
#  'INE385I01010',
#  'JP3126470008',
#  None,
#  None,
#  None,
#  'GB00BF1TM596',
#  'JP3126370000',
#  'GB00BYWKBC49',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'MU0456S00006',
#  None,
#  None,
#  None,
#  None,
#  'CH0019199550',
#  None,
#  'JP3126400005',
#  'IL0003870198',
#  None,
#  'FR0010220475',
#  'DE000A0LD2U1',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3126350002',
#  'FR0000071946',
#  'HU0000155726',
#  None,
#  'AU0000043945',
#  None,
#  None,
#  None,
#  None,
#  'AU0000001AG5',
#  None,
#  None,
#  None,
#  'AU0000022774',
#  'ES0113312005',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00B0LSFV82',
#  'AU000000ALU8',
#  None,
#  None,
#  None,
#  None,
#  'JP3201800004',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB0000280353',
#  None,
#  'AU000000AWC3',
#  None,
#  'CNE1000001T8',
#  None,
#  None,
#  None,
#  'DE000A2YNT30',
#  None,
#  'JP3122800000',
#  'DE0005093108',
#  None,
#  None,
#  None,
#  'JP3124200001',
#  'AU000000ANL3',
#  'JP3124400007',
#  None,
#  'SG1F08854688',
#  'INE885A01032',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE371P01015',
#  None,
#  None,
#  None,
#  None,
#  'INE540G01014',
#  'JP3128650003',
#  None,
#  None,
#  None,
#  None,
#  'INE079A01024',
#  None,
#  None,
#  None,
#  'AU000000AMH3',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'NO0010272065',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB00BFFK8T45',
#  'IE0003073255',
#  'IL0010922040',
#  'JP3124440003',
#  None,
#  None,
#  None,
#  None,
#  'IL0010972789',
#  None,
#  None,
#  None,
#  None,
#  'AU0000023822',
#  'IT0004056880',
#  None,
#  None,
#  None,
#  'ES0105375002',
#  'INE098F01031',
#  None,
#  'NL0000313286',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'JP3429800000',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'IL0010806136',
#  None,
#  'AU000000ALT0',
#  None,
#  None,
#  'INE242C01024',
#  None,
#  None,
#  'AU000000ANR0',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'INE435A01028',
#  'INE715B01021',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'GB0002684552',
#  None,
#  'AU000000ADN0',
#  None,
#  'JP3122450004',
#  'GB00BF2G3L29',
#  None,
#  'CNE000000SQ4',
#  None,
#  None,
#  'CNE0000014G0',
#  'JP3127700007',
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
df_stockList_IB = df_stockList[['symbol_x', 'longName', 'Country', 'Exchange', 'currency_y', 'isin']].copy()
df_stockList_IB['ISIN'] = isinList
df_stockList_IB.head()
# Out:
#   symbol_x            longName                   Country     Exchange  \
# 0      1ST       1ST GROUP LTD                 Australia          ASX
# 1     TWOU              2U INC  United States of America       NASDAQ
# 2     DDDX  3DX INDUSTRIES INC  United States of America         PINK
# 3      MMM               3M CO                    Mexico  US Exchange
# 4      88E       88 ENERGY LTD            United Kingdom          LSE
#
#   currency_y          isin          ISIN
# 0        AUD           NaN  AU0000001ST0
# 1        USD           NaN          None
# 2        USD           NaN          None
# 3        NaN           NaN          None
# 4        GBP  AU00000088E2  AU00000088E2

# %%
df_stockList_IB = df_stockList_IB.rename(columns={"symbol_x": "Ticker", "longName": "Name-IB", "Country": "Country-IB", "Exchange": "Exchange-IB", "currency_y": "Currency-IB", "ISIN": "ISIN-IB", "isin": "ISIN-19.7"})
df_stockList_IB.head()
# Out:
#   Ticker             Name-IB                Country-IB  Exchange-IB  \
# 0    1ST       1ST GROUP LTD                 Australia          ASX
# 1   TWOU              2U INC  United States of America       NASDAQ
# 2   DDDX  3DX INDUSTRIES INC  United States of America         PINK
# 3    MMM               3M CO                    Mexico  US Exchange
# 4    88E       88 ENERGY LTD            United Kingdom          LSE
#
#   Currency-IB     ISIN-19.7       ISIN-IB
# 0         AUD           NaN  AU0000001ST0
# 1         USD           NaN          None
# 2         USD           NaN          None
# 3         NaN           NaN          None
# 4         GBP  AU00000088E2  AU00000088E2

# %%
df_stockList_IB.to_csv('ISIN_from_IB.csv', index=False)
# Out:
# Peer closed connection.
