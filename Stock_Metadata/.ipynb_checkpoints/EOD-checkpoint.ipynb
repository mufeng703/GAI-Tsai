# %%
import numpy as np
import pandas as pd
import requests

# %%
path = "./Investing_IB_197.csv"

df_isin = pd.read_csv(path)  
df_isin
# Out:
#       Ticker             Name-IB                Country-IB  Exchange-IB  \
# 0        1ST       1ST GROUP LTD                 Australia          ASX
# 1       TWOU              2U INC  United States of America       NASDAQ
# 2       DDDX  3DX INDUSTRIES INC  United States of America         PINK
# 3        MMM               3M CO                    Mexico  US Exchange
# 4        88E       88 ENERGY LTD            United Kingdom          LSE
# ...      ...                 ...                       ...          ...
# 19896  EDMCQ                 NaN                       NaN          NaN
# 19897  EDSFF                 NaN                       NaN          NaN
# 19898   FALC                 NaN                       NaN          NaN
# 19899   FBSI                 NaN                       NaN          NaN
# 19900   FFDF                 NaN                       NaN          NaN
#
#       Currency-IB     ISIN-19.7       ISIN-IB         Name-Investing.com  \
# 0             AUD           NaN  AU0000001ST0                        NaN
# 1             USD           NaN           NaN                        NaN
# 2             USD           NaN           NaN                        NaN
# 3             NaN           NaN           NaN                 3M Company
# 4             GBP  AU00000088E2  AU00000088E2                        NaN
# ...           ...           ...           ...                        ...
# 19896         NaN           NaN           NaN  Education Management Corp
# 19897         NaN           NaN           NaN         Exceed Company Ltd
# 19898         NaN           NaN           NaN    FalconStor Software Inc
# 19899         NaN           NaN           NaN       First Bancshares Inc
# 19900         NaN           NaN           NaN         FFD Financial Corp
#
#       Exchange-Investing.com Type-Investing.com Market-Investing.com  \
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        NaN                NaN                  NaN
# 3                       NYSE             Equity        United States
# 4                        NaN                NaN                  NaN
# ...                      ...                ...                  ...
# 19896            OTC Markets             Equity        United States
# 19897            OTC Markets             Equity        United States
# 19898            OTC Markets             Equity        United States
# 19899            OTC Markets             Equity        United States
# 19900            OTC Markets             Equity        United States
#
#                ISIN CUSIP-Investing.com
# 0      AU0000001ST0                 NaN
# 1               NaN                 NaN
# 2               NaN                 NaN
# 3      US88579Y1010           88579Y101
# 4      AU00000088E2                 NaN
# ...             ...                 ...
# 19896  US28140M1036           28140M103
# 19897  VGG323351046           G32335104
# 19898  US3061372096           306137209
# 19899  US3186871006           318687100
# 19900  US30243C1071           30243C107
#
# [19901 rows x 13 columns]

# %%
df_notNull = df_isin[~df_isin['ISIN'].isnull()].copy()
df_notNull
# Out:
#       Ticker              Name-IB      Country-IB  Exchange-IB Currency-IB  \
# 0        1ST        1ST GROUP LTD       Australia          ASX         AUD
# 3        MMM                3M CO          Mexico  US Exchange         NaN
# 4        88E        88 ENERGY LTD  United Kingdom          LSE         GBP
# 6       7063         A DOT CO LTD           Japan         TSEJ         JPY
# 8      MLATV  A TOUTE VITESSE-ATV          France          SBF         EUR
# ...      ...                  ...             ...          ...         ...
# 19896  EDMCQ                  NaN             NaN          NaN         NaN
# 19897  EDSFF                  NaN             NaN          NaN         NaN
# 19898   FALC                  NaN             NaN          NaN         NaN
# 19899   FBSI                  NaN             NaN          NaN         NaN
# 19900   FFDF                  NaN             NaN          NaN         NaN
#
#           ISIN-19.7       ISIN-IB         Name-Investing.com  \
# 0               NaN  AU0000001ST0                        NaN
# 3               NaN           NaN                 3M Company
# 4      AU00000088E2  AU00000088E2                        NaN
# 6      JP3160590000  JP3160590000                        NaN
# 8               NaN  FR0010050773                        NaN
# ...             ...           ...                        ...
# 19896           NaN           NaN  Education Management Corp
# 19897           NaN           NaN         Exceed Company Ltd
# 19898           NaN           NaN    FalconStor Software Inc
# 19899           NaN           NaN       First Bancshares Inc
# 19900           NaN           NaN         FFD Financial Corp
#
#       Exchange-Investing.com Type-Investing.com Market-Investing.com  \
# 0                        NaN                NaN                  NaN
# 3                       NYSE             Equity        United States
# 4                        NaN                NaN                  NaN
# 6                        NaN                NaN                  NaN
# 8                        NaN                NaN                  NaN
# ...                      ...                ...                  ...
# 19896            OTC Markets             Equity        United States
# 19897            OTC Markets             Equity        United States
# 19898            OTC Markets             Equity        United States
# 19899            OTC Markets             Equity        United States
# 19900            OTC Markets             Equity        United States
#
#                ISIN CUSIP-Investing.com
# 0      AU0000001ST0                 NaN
# 3      US88579Y1010           88579Y101
# 4      AU00000088E2                 NaN
# 6      JP3160590000                 NaN
# 8      FR0010050773                 NaN
# ...             ...                 ...
# 19896  US28140M1036           28140M103
# 19897  VGG323351046           G32335104
# 19898  US3061372096           306137209
# 19899  US3186871006           318687100
# 19900  US30243C1071           30243C107
#
# [8582 rows x 13 columns]

# %%
df_eod = pd.DataFrame()
for isin in df_notNull["ISIN"]:
    if str(isin) != 'nan':
        path = "https://eodhistoricaldata.com/api/search/"+str(isin)+"?api_token=5f3afd582bd7b4.95720069"
        
        df = pd.read_json(path) 
        if len(df) != 0:
            df_eod = df_eod.append(df.iloc[0], ignore_index=True)

# %%
df_eod
# Out:
#        Code    Country Currency Exchange          ISIN  \
# 0       1ST  Australia      AUD       AU  AU0000001ST0
# 1       MMM        USA      USD       US  US88579Y1010
# 2       88E         UK      GBX      LSE  AU00000088E2
# 3      7063      Japan      JPY      TSE  JP3160590000
# 4      AMRK     Israel      ILA       TA  IL0010922040
# ...     ...        ...      ...      ...           ...
# 8037  EDMCQ        USA      USD       US  US28140M1036
# 8038  EDSFF        USA      USD       US  VGG323351046
# 8039   FALC        USA      USD       US  US3061372096
# 8040   FBSI        USA      USD       US  US3186871006
# 8041   FFDF        USA      USD       US  US30243C1071
#
#                                                    Name          Type  \
# 0                                      1stAvailable Ltd  Common Stock
# 1                                            3M Company  Common Stock
# 2                                         88 Energy Ltd  Common Stock
# 3                                          A Dot Co Ltd  Common Stock
# 4     Amir Marketing and Investments in Agriculture Ltd  Common Stock
# ...                                                 ...           ...
# 8037                          Education Management Corp  Common Stock
# 8038                                 Exceed Company Ltd  Common Stock
# 8039                            FalconStor Software Inc  Common Stock
# 8040                               First Bancshares Inc  Common Stock
# 8041                                 FFD Financial Corp  Common Stock
#
#       previousClose previousCloseDate
# 0            0.0080        2022-07-21
# 1          133.9500        2022-07-21
# 2            0.7250        2022-07-21
# 3         2136.0000        2022-07-21
# 4         3911.0000        2022-07-21
# ...             ...               ...
# 8037         0.0001        2022-07-21
# 8038         0.0001        2022-07-21
# 8039         1.1700        2022-07-21
# 8040        17.5000        2022-07-21
# 8041        35.0000        2022-07-21
#
# [8042 rows x 9 columns]

# %%
data = pd.merge(df_eod, df_isin, how='outer', on='ISIN')
data
# Out:
#        Code    Country Currency Exchange          ISIN  \
# 0       1ST  Australia      AUD       AU  AU0000001ST0
# 1       MMM        USA      USD       US  US88579Y1010
# 2       88E         UK      GBX      LSE  AU00000088E2
# 3      7063      Japan      JPY      TSE  JP3160590000
# 4      AMRK     Israel      ILA       TA  IL0010922040
# ...     ...        ...      ...      ...           ...
# 20041   NaN        NaN      NaN      NaN  NZZELE0001S1
# 20042   NaN        NaN      NaN      NaN  ZM0000000201
# 20043   NaN        NaN      NaN      NaN  CA98935P1080
# 20044   NaN        NaN      NaN      NaN  AU000000ZYB8
# 20045   NaN        NaN      NaN      NaN  US2836782092
#
#                                                     Name          Type  \
# 0                                       1stAvailable Ltd  Common Stock
# 1                                             3M Company  Common Stock
# 2                                          88 Energy Ltd  Common Stock
# 3                                           A Dot Co Ltd  Common Stock
# 4      Amir Marketing and Investments in Agriculture Ltd  Common Stock
# ...                                                  ...           ...
# 20041                                                NaN           NaN
# 20042                                                NaN           NaN
# 20043                                                NaN           NaN
# 20044                                                NaN           NaN
# 20045                                                NaN           NaN
#
#        previousClose previousCloseDate Ticker  ...      Country-IB  \
# 0              0.008        2022-07-21    1ST  ...       Australia
# 1            133.950        2022-07-21    MMM  ...          Mexico
# 2              0.725        2022-07-21    88E  ...  United Kingdom
# 3           2136.000        2022-07-21   7063  ...           Japan
# 4           3911.000        2022-07-21   AMRK  ...          Israel
# ...              ...               ...    ...  ...             ...
# 20041            NaN               NaN    ZEL  ...       Australia
# 20042            NaN               NaN    ZAM  ...  United Kingdom
# 20043            NaN               NaN    ZEN  ...          Canada
# 20044            NaN               NaN    ZYB  ...       Australia
# 20045            NaN               NaN  EP_pc  ...             NaN
#
#        Exchange-IB Currency-IB     ISIN-19.7       ISIN-IB  \
# 0              ASX         AUD           NaN  AU0000001ST0
# 1      US Exchange         NaN           NaN           NaN
# 2              LSE         GBP  AU00000088E2  AU00000088E2
# 3             TSEJ         JPY  JP3160590000  JP3160590000
# 4             TASE         ILS           NaN  IL0010922040
# ...            ...         ...           ...           ...
# 20041          ASX         AUD  NZZELE0001S1  NZZELE0001S1
# 20042          LSE         GBP           NaN  ZM0000000201
# 20043      VENTURE         CAD  CA98935P1080  CA98935P1080
# 20044          ASX         AUD  AU000000ZYB8  AU000000ZYB8
# 20045          NaN         NaN           NaN           NaN
#
#                    Name-Investing.com Exchange-Investing.com  \
# 0                                 NaN                    NaN
# 1                          3M Company                   NYSE
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
# ...                               ...                    ...
# 20041                             NaN                    NaN
# 20042                             NaN                    NaN
# 20043                             NaN                    NaN
# 20044                             NaN                    NaN
# 20045  El Paso Energy Capital Trust I                   NYSE
#
#       Type-Investing.com Market-Investing.com CUSIP-Investing.com
# 0                    NaN                  NaN                 NaN
# 1                 Equity        United States           88579Y101
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# ...                  ...                  ...                 ...
# 20041                NaN                  NaN                 NaN
# 20042                NaN                  NaN                 NaN
# 20043                NaN                  NaN                 NaN
# 20044                NaN                  NaN                 NaN
# 20045             Equity        United States           283678209
#
# [20046 rows x 21 columns]

# %%
data = data.rename(columns={"Code": "Code-EOD", "Country": "Country-EOD", "Currency": "Currency-EOD", "Exchange": "Exchange-EOD", "Name": "Name-EOD" , "Type": "Type-EOD" , "previousClose": "previousClose-EOD" , "previousCloseDate": "previousCloseDate-EOD"})
data
# Out:
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0          1ST   Australia          AUD           AU  AU0000001ST0
# 1          MMM         USA          USD           US  US88579Y1010
# 2          88E          UK          GBX          LSE  AU00000088E2
# 3         7063       Japan          JPY          TSE  JP3160590000
# 4         AMRK      Israel          ILA           TA  IL0010922040
# ...        ...         ...          ...          ...           ...
# 20041      NaN         NaN          NaN          NaN  NZZELE0001S1
# 20042      NaN         NaN          NaN          NaN  ZM0000000201
# 20043      NaN         NaN          NaN          NaN  CA98935P1080
# 20044      NaN         NaN          NaN          NaN  AU000000ZYB8
# 20045      NaN         NaN          NaN          NaN  US2836782092
#
#                                                 Name-EOD      Type-EOD  \
# 0                                       1stAvailable Ltd  Common Stock
# 1                                             3M Company  Common Stock
# 2                                          88 Energy Ltd  Common Stock
# 3                                           A Dot Co Ltd  Common Stock
# 4      Amir Marketing and Investments in Agriculture Ltd  Common Stock
# ...                                                  ...           ...
# 20041                                                NaN           NaN
# 20042                                                NaN           NaN
# 20043                                                NaN           NaN
# 20044                                                NaN           NaN
# 20045                                                NaN           NaN
#
#        previousClose-EOD previousCloseDate-EOD Ticker  ...      Country-IB  \
# 0                  0.008            2022-07-21    1ST  ...       Australia
# 1                133.950            2022-07-21    MMM  ...          Mexico
# 2                  0.725            2022-07-21    88E  ...  United Kingdom
# 3               2136.000            2022-07-21   7063  ...           Japan
# 4               3911.000            2022-07-21   AMRK  ...          Israel
# ...                  ...                   ...    ...  ...             ...
# 20041                NaN                   NaN    ZEL  ...       Australia
# 20042                NaN                   NaN    ZAM  ...  United Kingdom
# 20043                NaN                   NaN    ZEN  ...          Canada
# 20044                NaN                   NaN    ZYB  ...       Australia
# 20045                NaN                   NaN  EP_pc  ...             NaN
#
#        Exchange-IB Currency-IB     ISIN-19.7       ISIN-IB  \
# 0              ASX         AUD           NaN  AU0000001ST0
# 1      US Exchange         NaN           NaN           NaN
# 2              LSE         GBP  AU00000088E2  AU00000088E2
# 3             TSEJ         JPY  JP3160590000  JP3160590000
# 4             TASE         ILS           NaN  IL0010922040
# ...            ...         ...           ...           ...
# 20041          ASX         AUD  NZZELE0001S1  NZZELE0001S1
# 20042          LSE         GBP           NaN  ZM0000000201
# 20043      VENTURE         CAD  CA98935P1080  CA98935P1080
# 20044          ASX         AUD  AU000000ZYB8  AU000000ZYB8
# 20045          NaN         NaN           NaN           NaN
#
#                    Name-Investing.com Exchange-Investing.com  \
# 0                                 NaN                    NaN
# 1                          3M Company                   NYSE
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
# ...                               ...                    ...
# 20041                             NaN                    NaN
# 20042                             NaN                    NaN
# 20043                             NaN                    NaN
# 20044                             NaN                    NaN
# 20045  El Paso Energy Capital Trust I                   NYSE
#
#       Type-Investing.com Market-Investing.com CUSIP-Investing.com
# 0                    NaN                  NaN                 NaN
# 1                 Equity        United States           88579Y101
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# ...                  ...                  ...                 ...
# 20041                NaN                  NaN                 NaN
# 20042                NaN                  NaN                 NaN
# 20043                NaN                  NaN                 NaN
# 20044                NaN                  NaN                 NaN
# 20045             Equity        United States           283678209
#
# [20046 rows x 21 columns]

# %%
df_eod.to_csv('EOD.csv', index=False)

# %%
data.to_csv('withEOD.csv', index=False)
