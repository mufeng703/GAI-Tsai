# %%
import numpy as np  
import pandas as pd

# %%
path = "./Data/withFIGI.csv"

df = pd.read_csv(path, index_col=0)  
df
# Out:
#                            Name_197 Exchange_197               Country_197  \
# 0                     1ST GROUP LTD          ASX                 Australia
# 1                            2U INC       NASDAQ  United States of America
# 2                3DX INDUSTRIES INC         PINK  United States of America
# 3                             3M CO  US Exchange                    Mexico
# 4                     88 ENERGY LTD          LSE            United Kingdom
# ...                             ...          ...                       ...
# 20217   ZYNERBA PHARMACEUTICALS INC       NASDAQ  United States of America
# 20218                     ZYNEX INC       NASDAQ  United States of America
# 20219              ZYNGA INC - CL A       NASDAQ               Switzerland
# 20220                  ZYTRONIC PLC          LSE            United Kingdom
# 20221  ZZ CAPITAL INTERNATIONAL LTD         SEHK                 Hong Kong
#
#       Currency_197 Code-EOD Country-EOD Currency-EOD Exchange-EOD  \
# 0              AUD      1ST   Australia          AUD           AU
# 1              USD     TWOU         USA          USD           US
# 2              USD     DDDX         USA          USD           US
# 3              NaN      MMM         USA          USD           US
# 4              GBP      88E          UK          GBX          LSE
# ...            ...      ...         ...          ...          ...
# 20217          USD     ZYNE         USA          USD           US
# 20218          USD     ZYXI         USA          USD           US
# 20219          USD      NaN         NaN          NaN          NaN
# 20220          GBP      ZYT          UK          GBX          LSE
# 20221          HKD      NaN         NaN          NaN          NaN
#
#                ISIN                     Name-EOD  ...          figi  \
# 0      AU0000001ST0             1stAvailable Ltd  ...  BBG008HNLRF4
# 1      US90214J1016                       2U Inc  ...  BBG001KS9450
# 2      US88556A1007           3Dx Industries Inc  ...  BBG000C129N6
# 3      US88579Y1010                   3M Company  ...  BBG000BP52R2
# 4      AU00000088E2                88 Energy Ltd  ...  BBG000BWTTK9
# ...             ...                          ...  ...           ...
# 20217  US98986X1090  Zynerba Pharmaceuticals Inc  ...  BBG007BBS8B7
# 20218  US98986M1036                    Zynex Inc  ...  BBG000BJBXZ2
# 20219  US98986T1088                          NaN  ...  BBG005YZL376
# 20220  GB0006971013                     Zytronic  ...  BBG000BZPV76
# 20221  KYG9895T1085                          NaN  ...           NaN
#
#        compositeFIGI shareClassFIGI exchCode-FIGI marketSector-FIGI  \
# 0       BBG008HNLRF4   BBG008HNLRG3            AU            Equity
# 1       BBG001KS9450   BBG001V0RR30            US            Equity
# 2       BBG000C129N6   BBG001STRH79            US            Equity
# 3       BBG000BP52R2   BBG001S5T7X2            US            Equity
# 4       BBG000BWTTK9   BBG001SCV1F7            GR            Equity
# ...              ...            ...           ...               ...
# 20217   BBG007BBS8B7   BBG007BBS8C6            US            Equity
# 20218   BBG000BJBXZ2   BBG001S7T7V0            US            Equity
# 20219   BBG005YZL2R6   BBG001T24RN2            XS            Equity
# 20220   BBG000BZPTJ8   BBG001SFLP13            LN            Equity
# 20221            NaN            NaN           NaN               NaN
#
#       securityDescription-FIGI securityType-FIGI securityType2-FIGI Not_Match  \
# 0                          1ST      Common Stock       Common Stock       NaN
# 1                         TWOU      Common Stock       Common Stock       NaN
# 2                         DDDX      Common Stock       Common Stock       NaN
# 3                          MMM      Common Stock       Common Stock       NaN
# 4                          POQ      Common Stock       Common Stock       NaN
# ...                        ...               ...                ...       ...
# 20217                     ZYNE      Common Stock       Common Stock       NaN
# 20218                     ZYXI      Common Stock       Common Stock       NaN
# 20219                  ZNGAEUR      Common Stock       Common Stock       NaN
# 20220                      ZYT      Common Stock       Common Stock       NaN
# 20221                      NaN               NaN                NaN       NaN
#
#        Source_Available
# 0          FIGI;IB;EOD;
# 1      FIGI;Inv;IB;EOD;
# 2          FIGI;IB;EOD;
# 3          FIGI;IB;EOD;
# 4      FIGI;Inv;IB;EOD;
# ...                 ...
# 20217      FIGI;IB;EOD;
# 20218      FIGI;IB;EOD;
# 20219          FIGI;IB;
# 20220      FIGI;IB;EOD;
# 20221              Inv;
#
# [19565 rows x 35 columns]

# %%
df = df.drop(['Not_Match', 'Source_Available'], axis=1)

df
# Out:
#                            Name_197 Exchange_197               Country_197  \
# 0                     1ST GROUP LTD          ASX                 Australia
# 1                            2U INC       NASDAQ  United States of America
# 2                3DX INDUSTRIES INC         PINK  United States of America
# 3                             3M CO  US Exchange                    Mexico
# 4                     88 ENERGY LTD          LSE            United Kingdom
# ...                             ...          ...                       ...
# 20217   ZYNERBA PHARMACEUTICALS INC       NASDAQ  United States of America
# 20218                     ZYNEX INC       NASDAQ  United States of America
# 20219              ZYNGA INC - CL A       NASDAQ               Switzerland
# 20220                  ZYTRONIC PLC          LSE            United Kingdom
# 20221  ZZ CAPITAL INTERNATIONAL LTD         SEHK                 Hong Kong
#
#       Currency_197 Code-EOD Country-EOD Currency-EOD Exchange-EOD  \
# 0              AUD      1ST   Australia          AUD           AU
# 1              USD     TWOU         USA          USD           US
# 2              USD     DDDX         USA          USD           US
# 3              NaN      MMM         USA          USD           US
# 4              GBP      88E          UK          GBX          LSE
# ...            ...      ...         ...          ...          ...
# 20217          USD     ZYNE         USA          USD           US
# 20218          USD     ZYXI         USA          USD           US
# 20219          USD      NaN         NaN          NaN          NaN
# 20220          GBP      ZYT          UK          GBX          LSE
# 20221          HKD      NaN         NaN          NaN          NaN
#
#                ISIN                     Name-EOD  ...  \
# 0      AU0000001ST0             1stAvailable Ltd  ...
# 1      US90214J1016                       2U Inc  ...
# 2      US88556A1007           3Dx Industries Inc  ...
# 3      US88579Y1010                   3M Company  ...
# 4      AU00000088E2                88 Energy Ltd  ...
# ...             ...                          ...  ...
# 20217  US98986X1090  Zynerba Pharmaceuticals Inc  ...
# 20218  US98986M1036                    Zynex Inc  ...
# 20219  US98986T1088                          NaN  ...
# 20220  GB0006971013                     Zytronic  ...
# 20221  KYG9895T1085                          NaN  ...
#
#                      longName-FIGI  symbol-FIGI          figi compositeFIGI  \
# 0                    1ST GROUP LTD          1ST  BBG008HNLRF4  BBG008HNLRF4
# 1                           2U INC         TWOU  BBG001KS9450  BBG001KS9450
# 2               3DX INDUSTRIES INC         DDDX  BBG000C129N6  BBG000C129N6
# 3                            3M CO          MMM  BBG000BP52R2  BBG000BP52R2
# 4                    88 ENERGY LTD          POQ  BBG000BWTTK9  BBG000BWTTK9
# ...                            ...          ...           ...           ...
# 20217  ZYNERBA PHARMACEUTICALS INC         ZYNE  BBG007BBS8B7  BBG007BBS8B7
# 20218                    ZYNEX INC         ZYXI  BBG000BJBXZ2  BBG000BJBXZ2
# 20219             ZYNGA INC - CL A      ZNGAEUR  BBG005YZL376  BBG005YZL2R6
# 20220                 ZYTRONIC PLC          ZYT  BBG000BZPV76  BBG000BZPTJ8
# 20221                          NaN          NaN           NaN           NaN
#
#       shareClassFIGI exchCode-FIGI marketSector-FIGI securityDescription-FIGI  \
# 0       BBG008HNLRG3            AU            Equity                      1ST
# 1       BBG001V0RR30            US            Equity                     TWOU
# 2       BBG001STRH79            US            Equity                     DDDX
# 3       BBG001S5T7X2            US            Equity                      MMM
# 4       BBG001SCV1F7            GR            Equity                      POQ
# ...              ...           ...               ...                      ...
# 20217   BBG007BBS8C6            US            Equity                     ZYNE
# 20218   BBG001S7T7V0            US            Equity                     ZYXI
# 20219   BBG001T24RN2            XS            Equity                  ZNGAEUR
# 20220   BBG001SFLP13            LN            Equity                      ZYT
# 20221            NaN           NaN               NaN                      NaN
#
#       securityType-FIGI securityType2-FIGI
# 0          Common Stock       Common Stock
# 1          Common Stock       Common Stock
# 2          Common Stock       Common Stock
# 3          Common Stock       Common Stock
# 4          Common Stock       Common Stock
# ...                 ...                ...
# 20217      Common Stock       Common Stock
# 20218      Common Stock       Common Stock
# 20219      Common Stock       Common Stock
# 20220      Common Stock       Common Stock
# 20221               NaN                NaN
#
# [19565 rows x 33 columns]

# %% [markdown]
# Country, Sector/Industry, Exchange, ISIN, FIGI

# %%
df_ck = df.copy()
df_ck['Ranking'] = 0

columns = ['Country-EOD', 'Exchange-EOD', 'ISIN', 'country-Inv', 
           'figi', 'exchCode-FIGI']

for col in columns:
    df_ck.loc[~df_ck[col].isnull(),'Ranking'] = 1 + df_ck['Ranking'].astype(int)

df_ck[['Name_197','Ranking']]
# Out:
#                            Name_197  Ranking
# 0                     1ST GROUP LTD        5
# 1                            2U INC        6
# 2                3DX INDUSTRIES INC        5
# 3                             3M CO        5
# 4                     88 ENERGY LTD        6
# ...                             ...      ...
# 20217   ZYNERBA PHARMACEUTICALS INC        5
# 20218                     ZYNEX INC        5
# 20219              ZYNGA INC - CL A        3
# 20220                  ZYTRONIC PLC        5
# 20221  ZZ CAPITAL INTERNATIONAL LTD        2
#
# [19565 rows x 2 columns]

# %%
df_ck['Ranking'].value_counts().to_frame()
# Out:
#    Ranking
# 5     7721
# 6     5235
# 0     2129
# 3     1853
# 1     1749
# 4      659
# 2      219
