# %%
import requests     
import json         
import pandas as pd 
import time
from fuzzywuzzy import fuzz
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
path = "./Data/withEOD.csv"

df = pd.read_csv(path)  
df
# Out:
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0         TWOU         USA          USD           US  US90214J1016
# 1          88E          UK          GBX          LSE  AU00000088E2
# 2         7063       Japan          JPY          TSE  JP3160590000
# 3         2018   Hong Kong          HKD           HK  KYG2953R1149
# 4         2686   Hong Kong          HKD           HK  KYG000371040
# ...        ...         ...          ...          ...           ...
# 17506      NaN         NaN          NaN          NaN  US98979J1097
# 17507      NaN         NaN          NaN          NaN  CA98977K1084
# 17508      NaN         NaN          NaN          NaN  CA98977R1038
# 17509      NaN         NaN          NaN          NaN  GB00BMHTHT14
# 17510      NaN         NaN          NaN          NaN  US98986T1088
#
#                             Name-EOD      Type-EOD  previousClose-EOD  \
# 0                             2U Inc  Common Stock              9.200
# 1                      88 Energy Ltd  Common Stock              0.625
# 2                       A Dot Co Ltd  Common Stock           2064.000
# 3      AAC Technologies Holdings Inc  Common Stock             14.580
# 4            AAG Energy Holdings Ltd  Common Stock              1.410
# ...                              ...           ...                ...
# 17506                            NaN           NaN                NaN
# 17507                            NaN           NaN                NaN
# 17508                            NaN           NaN                NaN
# 17509                            NaN           NaN                NaN
# 17510                            NaN           NaN                NaN
#
#       previousCloseDate-EOD     country-Inv  ... symbol-Inv asset_class-Inv  \
# 0                2022-08-02   united states  ...       TWOU          equity
# 1                2022-08-03  united kingdom  ...        88E          equity
# 2                2022-08-03           japan  ...       7063          equity
# 3                2022-08-03       hong kong  ...       2018          equity
# 4                2022-08-03       hong kong  ...       2686          equity
# ...                     ...             ...  ...        ...             ...
# 17506                   NaN             NaN  ...        NaN             NaN
# 17507                   NaN             NaN  ...        NaN             NaN
# 17508                   NaN             NaN  ...        NaN             NaN
# 17509                   NaN             NaN  ...        NaN             NaN
# 17510                   NaN             NaN  ...        NaN             NaN
#
#                            Name_197             industry-IB  \
# 0                            2U INC  Consumer, Non-cyclical
# 1                     88 ENERGY LTD                  Energy
# 2                      A DOT CO LTD                     NaN
# 3      AAC TECHNOLOGIES HOLDINGS IN              Industrial
# 4           AAG ENERGY HOLDINGS LTD                  Energy
# ...                             ...                     ...
# 17506             ZOE'S KITCHEN INC      Consumer, Cyclical
# 17507          ZOLOTO RESOURCES LTD         Basic Materials
# 17508                   ZOOMMED INC              Technology
# 17509                       ZPG PLC          Communications
# 17510              ZYNGA INC - CL A              Technology
#
#                         longName-IB marketName-IB Symbol-IB      Country-IB  \
# 0                            2U INC           NMS      TWOU             NaN
# 1                     88 ENERGY LTD           88E       88E  United Kingdom
# 2                               NaN           NaN       NaN             NaN
# 3      AAC TECHNOLOGIES HOLDINGS IN          2018      2018             NaN
# 4           AAG ENERGY HOLDINGS LTD          2686      2686       Hong Kong
# ...                             ...           ...       ...             ...
# 17506             ZOE'S KITCHEN INC          ZOES      ZOES             NaN
# 17507          ZOLOTO RESOURCES LTD            ZR        ZR             NaN
# 17508                   ZOOMMED INC         ZMD.H     ZMD.H             NaN
# 17509                       ZPG PLC           ZPG       ZPG             NaN
# 17510              ZYNGA INC - CL A          ZNGA      ZNGA             NaN
#
#       Exchange-IB Currency-IB
# 0             NaN         NaN
# 1             LSE         GBP
# 2             NaN         NaN
# 3             NaN         NaN
# 4            SEHK         HKD
# ...           ...         ...
# 17506         NaN         NaN
# 17507         NaN         NaN
# 17508         NaN         NaN
# 17509         NaN         NaN
# 17510         NaN         NaN
#
# [17511 rows x 23 columns]

# %%
len(ticker_list)
# Out:
# 100

# %%
# key & urls
# openfigi_apikey = '71aaa940-3567-4040-bce5-9f43490a7703' # GAI
openfigi_apikey = '6531f095-b68a-44c2-9749-20b3b75f9ad8'
openfigi_url = 'https://api.openfigi.com/v2/mapping'
openfigi_headers = {'Content-Type': 'text/json'}

# %%
def map_jobs(jobs):
    if openfigi_apikey:
        openfigi_headers['X-OPENFIGI-APIKEY'] = openfigi_apikey
    response = requests.post(url=openfigi_url, 
                             headers=openfigi_headers,
                             json=jobs)
    if response.status_code != 200:
        raise Exception('Bad response code {}'.format(str(response.status_code)))
    return response.json()

# %%
def get100Figi(ticker_list):
    
    jobs = []
    for i in ticker_list:
        s = "{'idType': 'ID_ISIN', 'idValue': '" + str(i) + "'}"
        json_acceptable_string = s.replace("'", "\"")
        d = json.loads(json_acceptable_string)
        jobs.append(d)
    
    
    job_results = map_jobs(jobs)
    
    # Extract figi from scrape results
    figi_value = [] # store figi information
    figi_count = [] # keep track of the number of each symbol's corresponding figi
    j=0
    for d in job_results:
        if 'data' in d:
            figi_count.append(len(d['data']))
            for i in range(len(d['data'])):   
                figi_value.append(d['data'][i])
                d['data'][i]['ISIN'] = ticker_list[j]
        else:
#             d['data'][i]['ISIN'] = ticker_list[j]
            figi_count.append(0)
        j+=1
        
    df_figi = pd.DataFrame.from_dict(figi_value)
    
    # extract useful information and rename
    df_res = df_figi[['ISIN', 'name', 'ticker', 'figi', 'compositeFIGI', 'shareClassFIGI', 'exchCode', 'marketSector', 'securityDescription', 'securityType', 'securityType2']].rename(columns = {'name':'longName', 'ticker':'symbol'})
    
    return df_res

# %%
len(df)//100 + 1
# Out:
# 176

# %%
requestTimes = len(df)//100 + 1
df_figi = pd.DataFrame()

for i in range(requestTimes):
    # get 100 tickers
    ticker_list = list(df['ISIN'].unique())[100*(i):100*(i+1)]
    # get figi
    df100 = get100Figi(ticker_list)
    df100 = df100.drop_duplicates(subset=['ISIN'])
    df_figi = pd.concat([df_figi, df100])
#     time.sleep()
    
    # print progress
    if i % (requestTimes//10) == 0:
        print("progress: %.2f" % (100*i/requestTimes) + "%")

df_figi
# Out:
# progress: 0.00%
# progress: 9.66%
# progress: 19.32%
# progress: 28.98%
# progress: 38.64%
# progress: 48.30%
# progress: 57.95%
# progress: 67.61%
# progress: 77.27%
# progress: 86.93%
# progress: 96.59%
#              ISIN                      longName               symbol  \
# 0    US90214J1016                        2U INC                 TWOU
# 96   AU00000088E2                 88 ENERGY LTD                  POQ
# 172  JP3160590000                   BIRDMAN INC                 7063
# 179  KYG2953R1149  AAC TECHNOLOGIES HOLDINGS IN                 A2XN
# 251  KYG000371040       AAG ENERGY HOLDINGS LTD                 2686
# ..            ...                           ...                  ...
# 3    US9895063082           ZIEGLER COS INC/THE                 ZGCO
# 6    CA98959W2031        ZINC ONE RESOURCES INC                  Z/H
# 80   US9897018183              ZIONS BANCORP NA  ZION V6.95 09/15/28
# 81   CA98977R1038                   ZOOMMED INC                ZMD/H
# 96   US98986T1088              ZYNGA INC - CL A              ZNGAEUR
#
#              figi compositeFIGI shareClassFIGI    exchCode marketSector  \
# 0    BBG001KS9450  BBG001KS9450   BBG001V0RR30          US       Equity
# 96   BBG000BWTTK9  BBG000BWTTK9   BBG001SCV1F7          GR       Equity
# 172  BBG00NG9S234  BBG00NG9S234   BBG00NG9S261          JP       Equity
# 179  BBG000C162Q4  BBG000C162Q4   BBG001SKMWN2          GR       Equity
# 251  BBG009CXGZ63  BBG009CXGZ45   BBG009CXGZ54          HK       Equity
# ..            ...           ...            ...         ...          ...
# 3    BBG000CG8F44  BBG000CG8F44   BBG001S6VMH2          US       Equity
# 6    BBG000RG2ZZ6  BBG000RG2ZZ6   BBG001STKXP1          CN       Equity
# 80   BBG0058QYKL7          None           None  NASDAQ/NGM          Pfd
# 81   BBG000BYKYT4  BBG000BYKYT4   BBG001SJS399          CN       Equity
# 96   BBG005YZL376  BBG005YZL2R6   BBG001T24RN2          XS       Equity
#
#     securityDescription  securityType    securityType2
# 0                  TWOU  Common Stock     Common Stock
# 96                  POQ  Common Stock     Common Stock
# 172                7063  Common Stock     Common Stock
# 179                A2XN  Common Stock     Common Stock
# 251                2686  Common Stock     Common Stock
# ..                  ...           ...              ...
# 3                  ZGCO  Common Stock     Common Stock
# 6                   Z/H  Common Stock     Common Stock
# 80   ZION 6.95 09/15/28        PUBLIC  Preferred Stock
# 81                ZMD/H  Common Stock     Common Stock
# 96              ZNGAEUR  Common Stock     Common Stock
#
# [15489 rows x 11 columns]

# %%
df_figi = df_figi.rename(columns = {'longName': 'longName-FIGI', 'symbol': 'symbol-FIGI', 'exchCode': 'exchCode-FIGI', 'marketSector': 'marketSector-FIGI', 'securityDescription': 'securityDescription-FIGI', 'securityType': 'securityType-FIGI', 'securityType2': 'securityType2-FIGI'})

df_figi
# Out:
#              ISIN                 longName-FIGI          symbol-FIGI  \
# 0    US90214J1016                        2U INC                 TWOU
# 96   AU00000088E2                 88 ENERGY LTD                  POQ
# 172  JP3160590000                   BIRDMAN INC                 7063
# 179  KYG2953R1149  AAC TECHNOLOGIES HOLDINGS IN                 A2XN
# 251  KYG000371040       AAG ENERGY HOLDINGS LTD                 2686
# ..            ...                           ...                  ...
# 3    US9895063082           ZIEGLER COS INC/THE                 ZGCO
# 6    CA98959W2031        ZINC ONE RESOURCES INC                  Z/H
# 80   US9897018183              ZIONS BANCORP NA  ZION V6.95 09/15/28
# 81   CA98977R1038                   ZOOMMED INC                ZMD/H
# 96   US98986T1088              ZYNGA INC - CL A              ZNGAEUR
#
#              figi compositeFIGI shareClassFIGI exchCode-FIGI  \
# 0    BBG001KS9450  BBG001KS9450   BBG001V0RR30            US
# 96   BBG000BWTTK9  BBG000BWTTK9   BBG001SCV1F7            GR
# 172  BBG00NG9S234  BBG00NG9S234   BBG00NG9S261            JP
# 179  BBG000C162Q4  BBG000C162Q4   BBG001SKMWN2            GR
# 251  BBG009CXGZ63  BBG009CXGZ45   BBG009CXGZ54            HK
# ..            ...           ...            ...           ...
# 3    BBG000CG8F44  BBG000CG8F44   BBG001S6VMH2            US
# 6    BBG000RG2ZZ6  BBG000RG2ZZ6   BBG001STKXP1            CN
# 80   BBG0058QYKL7          None           None    NASDAQ/NGM
# 81   BBG000BYKYT4  BBG000BYKYT4   BBG001SJS399            CN
# 96   BBG005YZL376  BBG005YZL2R6   BBG001T24RN2            XS
#
#     marketSector-FIGI securityDescription-FIGI securityType-FIGI  \
# 0              Equity                     TWOU      Common Stock
# 96             Equity                      POQ      Common Stock
# 172            Equity                     7063      Common Stock
# 179            Equity                     A2XN      Common Stock
# 251            Equity                     2686      Common Stock
# ..                ...                      ...               ...
# 3              Equity                     ZGCO      Common Stock
# 6              Equity                      Z/H      Common Stock
# 80                Pfd       ZION 6.95 09/15/28            PUBLIC
# 81             Equity                    ZMD/H      Common Stock
# 96             Equity                  ZNGAEUR      Common Stock
#
#     securityType2-FIGI
# 0         Common Stock
# 96        Common Stock
# 172       Common Stock
# 179       Common Stock
# 251       Common Stock
# ..                 ...
# 3         Common Stock
# 6         Common Stock
# 80     Preferred Stock
# 81        Common Stock
# 96        Common Stock
#
# [15489 rows x 11 columns]

# %%
len(df['ISIN'].unique())
# Out:
# 17511

# %% [markdown]
# ### Merge to the dataset

# %%
df_withFIGI = pd.merge(df, df_figi, how='outer', on='ISIN')
df_withFIGI
# Out:
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0         TWOU         USA          USD           US  US90214J1016
# 1          88E          UK          GBX          LSE  AU00000088E2
# 2         7063       Japan          JPY          TSE  JP3160590000
# 3         2018   Hong Kong          HKD           HK  KYG2953R1149
# 4         2686   Hong Kong          HKD           HK  KYG000371040
# ...        ...         ...          ...          ...           ...
# 17506      NaN         NaN          NaN          NaN  US98979J1097
# 17507      NaN         NaN          NaN          NaN  CA98977K1084
# 17508      NaN         NaN          NaN          NaN  CA98977R1038
# 17509      NaN         NaN          NaN          NaN  GB00BMHTHT14
# 17510      NaN         NaN          NaN          NaN  US98986T1088
#
#                             Name-EOD      Type-EOD  previousClose-EOD  \
# 0                             2U Inc  Common Stock              9.200
# 1                      88 Energy Ltd  Common Stock              0.625
# 2                       A Dot Co Ltd  Common Stock           2064.000
# 3      AAC Technologies Holdings Inc  Common Stock             14.580
# 4            AAG Energy Holdings Ltd  Common Stock              1.410
# ...                              ...           ...                ...
# 17506                            NaN           NaN                NaN
# 17507                            NaN           NaN                NaN
# 17508                            NaN           NaN                NaN
# 17509                            NaN           NaN                NaN
# 17510                            NaN           NaN                NaN
#
#       previousCloseDate-EOD     country-Inv  ...  \
# 0                2022-08-02   united states  ...
# 1                2022-08-03  united kingdom  ...
# 2                2022-08-03           japan  ...
# 3                2022-08-03       hong kong  ...
# 4                2022-08-03       hong kong  ...
# ...                     ...             ...  ...
# 17506                   NaN             NaN  ...
# 17507                   NaN             NaN  ...
# 17508                   NaN             NaN  ...
# 17509                   NaN             NaN  ...
# 17510                   NaN             NaN  ...
#
#                       longName-FIGI symbol-FIGI          figi compositeFIGI  \
# 0                            2U INC        TWOU  BBG001KS9450  BBG001KS9450
# 1                     88 ENERGY LTD         POQ  BBG000BWTTK9  BBG000BWTTK9
# 2                       BIRDMAN INC        7063  BBG00NG9S234  BBG00NG9S234
# 3      AAC TECHNOLOGIES HOLDINGS IN        A2XN  BBG000C162Q4  BBG000C162Q4
# 4           AAG ENERGY HOLDINGS LTD        2686  BBG009CXGZ63  BBG009CXGZ45
# ...                             ...         ...           ...           ...
# 17506                           NaN         NaN           NaN           NaN
# 17507                           NaN         NaN           NaN           NaN
# 17508                   ZOOMMED INC       ZMD/H  BBG000BYKYT4  BBG000BYKYT4
# 17509                           NaN         NaN           NaN           NaN
# 17510              ZYNGA INC - CL A     ZNGAEUR  BBG005YZL376  BBG005YZL2R6
#
#       shareClassFIGI exchCode-FIGI marketSector-FIGI securityDescription-FIGI  \
# 0       BBG001V0RR30            US            Equity                     TWOU
# 1       BBG001SCV1F7            GR            Equity                      POQ
# 2       BBG00NG9S261            JP            Equity                     7063
# 3       BBG001SKMWN2            GR            Equity                     A2XN
# 4       BBG009CXGZ54            HK            Equity                     2686
# ...              ...           ...               ...                      ...
# 17506            NaN           NaN               NaN                      NaN
# 17507            NaN           NaN               NaN                      NaN
# 17508   BBG001SJS399            CN            Equity                    ZMD/H
# 17509            NaN           NaN               NaN                      NaN
# 17510   BBG001T24RN2            XS            Equity                  ZNGAEUR
#
#       securityType-FIGI securityType2-FIGI
# 0          Common Stock       Common Stock
# 1          Common Stock       Common Stock
# 2          Common Stock       Common Stock
# 3          Common Stock       Common Stock
# 4          Common Stock       Common Stock
# ...                 ...                ...
# 17506               NaN                NaN
# 17507               NaN                NaN
# 17508      Common Stock       Common Stock
# 17509               NaN                NaN
# 17510      Common Stock       Common Stock
#
# [17511 rows x 33 columns]

# %%
df_withFIGI.to_csv('./Data/withFIGI.csv', index=False)

# %% [markdown]
# ## Check FIGI Name vs. 19.7k

# %%
df_Name = df_withFIGI[['ISIN', 'Name_197', 'longName-FIGI']].dropna(subset=['longName-FIGI'])

df_Name
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#                ISIN                      Name_197  \
# 0      US90214J1016                        2U INC
# 1      AU00000088E2                 88 ENERGY LTD
# 2      JP3160590000                  A DOT CO LTD
# 3      KYG2953R1149  AAC TECHNOLOGIES HOLDINGS IN
# 4      KYG000371040       AAG ENERGY HOLDINGS LTD
# ...             ...                           ...
# 17501  US9895063082           ZIEGLER COS INC/THE
# 17502  CA98959W2031        ZINC ONE RESOURCES INC
# 17505  US9897018183          ZIONS BANCORPORATION
# 17508  CA98977R1038                   ZOOMMED INC
# 17510  US98986T1088              ZYNGA INC - CL A
#
#                       longName-FIGI
# 0                            2U INC
# 1                     88 ENERGY LTD
# 2                       BIRDMAN INC
# 3      AAC TECHNOLOGIES HOLDINGS IN
# 4           AAG ENERGY HOLDINGS LTD
# ...                             ...
# 17501           ZIEGLER COS INC/THE
# 17502        ZINC ONE RESOURCES INC
# 17505              ZIONS BANCORP NA
# 17508                   ZOOMMED INC
# 17510              ZYNGA INC - CL A
#
# [15489 rows x 3 columns]

# %%
allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['Name_197'],row['longName-FIGI'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")
# Out:
# progress: 0.00%
# progress: 9.99%
# progress: 19.99%
# progress: 29.98%
# progress: 39.98%
# progress: 49.97%
# progress: 59.97%
# progress: 69.96%
# progress: 79.95%
# progress: 99.94%

# %%
df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])
df_match
# Out:
#                ISIN                      Name_197  \
# 0      US90214J1016                        2U INC
# 1      AU00000088E2                 88 ENERGY LTD
# 2      JP3160590000                  A DOT CO LTD
# 3      KYG2953R1149  AAC TECHNOLOGIES HOLDINGS IN
# 4      KYG000371040       AAG ENERGY HOLDINGS LTD
# ...             ...                           ...
# 17501  US9895063082           ZIEGLER COS INC/THE
# 17502  CA98959W2031        ZINC ONE RESOURCES INC
# 17505  US9897018183          ZIONS BANCORPORATION
# 17508  CA98977R1038                   ZOOMMED INC
# 17510  US98986T1088              ZYNGA INC - CL A
#
#                       longName-FIGI  fuzz_socre1
# 0                            2U INC          100
# 1                     88 ENERGY LTD          100
# 2                       BIRDMAN INC           26
# 3      AAC TECHNOLOGIES HOLDINGS IN          100
# 4           AAG ENERGY HOLDINGS LTD          100
# ...                             ...          ...
# 17501           ZIEGLER COS INC/THE          100
# 17502        ZINC ONE RESOURCES INC          100
# 17505              ZIONS BANCORP NA           78
# 17508                   ZOOMMED INC          100
# 17510              ZYNGA INC - CL A          100
#
# [15489 rows x 4 columns]

# %%
df_match[df_match['fuzz_socre1']<80]
# Out:
#                ISIN                                           Name_197  \
# 2      JP3160590000                                       A DOT CO LTD
# 15     SE0006256558                                  ABSOLENT GROUP AB
# 38     JP3108120001                                        ACRODEA INC
# 53     LU1250154413                                  ADO PROPERTIES SA
# 57     US00486H1059                                         ADTRAN INC
# ...             ...                                                ...
# 16791  KYG735374020                  SCOTTISH RE GROUP LTD PFD B 7.25%
# 17055  US7847882005  SYNTHETIC FIXED-INCOME SEC STRATS 2004-2, 6.50...
# 17103  MHY8564M1057                             TEEKAY LNG PARTNERS LP
# 17110  US8794338520          TELEPHONE AND DATA SYSTEMS INC 6.625% PFD
# 17505  US9897018183                               ZIONS BANCORPORATION
#
#                     longName-FIGI  fuzz_socre1
# 2                     BIRDMAN INC           26
# 15     ABSOLENT AIR CARE GROUP AB           79
# 38     THE WHY HOW DO COMPANY INC           32
# 53                 ADLER GROUP SA           58
# 57            ADTRAN HOLDINGS INC           69
# ...                           ...          ...
# 16791       SCOTTISH RE GROUP LTD           79
# 17055             STRATS-FON-04-2           36
# 17103                 SEAPEAK LLC           30
# 17110    TELEPHONE & DATA SYSTEMS           71
# 17505            ZIONS BANCORP NA           78
#
# [321 rows x 4 columns]

# %%
df_match[df_match['fuzz_socre1']<60]
# Out:
#                ISIN                                           Name_197  \
# 2      JP3160590000                                       A DOT CO LTD
# 38     JP3108120001                                        ACRODEA INC
# 53     LU1250154413                                  ADO PROPERTIES SA
# 78     US0077371096                                   AEROCENTURY CORP
# 121    JP3102000001                                 AISIN SEIKI CO LTD
# ...             ...                                                ...
# 16577  US74838C1062                                     QUIKSILVER INC
# 16581  US7472623013                         QVC INC 6 3/8 09/13/67 PFD
# 16690  SE0010520155                          ROLLING OPTICS HOLDING AB
# 17055  US7847882005  SYNTHETIC FIXED-INCOME SEC STRATS 2004-2, 6.50...
# 17103  MHY8564M1057                             TEEKAY LNG PARTNERS LP
#
#                     longName-FIGI  fuzz_socre1
# 2                     BIRDMAN INC           26
# 38     THE WHY HOW DO COMPANY INC           32
# 53                 ADLER GROUP SA           58
# 78               MEGA MATRIX CORP           25
# 121                    AISIN CORP           57
# ...                           ...          ...
# 16577             BOARDRIDERS INC           21
# 16581                     QVC INC           42
# 16690                     ICTA AB           31
# 17055             STRATS-FON-04-2           36
# 17103                 SEAPEAK LLC           30
#
# [162 rows x 4 columns]

# %% [markdown]
# ## Check Company Name from different sources

# %%
path = "./Data/withFIGI.csv"

df_withFIGI = pd.read_csv(path)  
df_withFIGI
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,1,2,3,5,6,8,9,10,11,12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0         TWOU         USA          USD           US  US90214J1016
# 1          88E          UK          GBX          LSE  AU00000088E2
# 2         7063       Japan          JPY          TSE  JP3160590000
# 3         2018   Hong Kong          HKD           HK  KYG2953R1149
# 4         2686   Hong Kong          HKD           HK  KYG000371040
# ...        ...         ...          ...          ...           ...
# 17506      NaN         NaN          NaN          NaN  US98979J1097
# 17507      NaN         NaN          NaN          NaN  CA98977K1084
# 17508      NaN         NaN          NaN          NaN  CA98977R1038
# 17509      NaN         NaN          NaN          NaN  GB00BMHTHT14
# 17510      NaN         NaN          NaN          NaN  US98986T1088
#
#                             Name-EOD      Type-EOD  previousClose-EOD  \
# 0                             2U Inc  Common Stock              9.200
# 1                      88 Energy Ltd  Common Stock              0.625
# 2                       A Dot Co Ltd  Common Stock           2064.000
# 3      AAC Technologies Holdings Inc  Common Stock             14.580
# 4            AAG Energy Holdings Ltd  Common Stock              1.410
# ...                              ...           ...                ...
# 17506                            NaN           NaN                NaN
# 17507                            NaN           NaN                NaN
# 17508                            NaN           NaN                NaN
# 17509                            NaN           NaN                NaN
# 17510                            NaN           NaN                NaN
#
#       previousCloseDate-EOD     country-Inv  ...  \
# 0                2022-08-02   united states  ...
# 1                2022-08-03  united kingdom  ...
# 2                2022-08-03           japan  ...
# 3                2022-08-03       hong kong  ...
# 4                2022-08-03       hong kong  ...
# ...                     ...             ...  ...
# 17506                   NaN             NaN  ...
# 17507                   NaN             NaN  ...
# 17508                   NaN             NaN  ...
# 17509                   NaN             NaN  ...
# 17510                   NaN             NaN  ...
#
#                       longName-FIGI symbol-FIGI          figi compositeFIGI  \
# 0                            2U INC        TWOU  BBG001KS9450  BBG001KS9450
# 1                     88 ENERGY LTD         POQ  BBG000BWTTK9  BBG000BWTTK9
# 2                       BIRDMAN INC        7063  BBG00NG9S234  BBG00NG9S234
# 3      AAC TECHNOLOGIES HOLDINGS IN        A2XN  BBG000C162Q4  BBG000C162Q4
# 4           AAG ENERGY HOLDINGS LTD        2686  BBG009CXGZ63  BBG009CXGZ45
# ...                             ...         ...           ...           ...
# 17506                           NaN         NaN           NaN           NaN
# 17507                           NaN         NaN           NaN           NaN
# 17508                   ZOOMMED INC       ZMD/H  BBG000BYKYT4  BBG000BYKYT4
# 17509                           NaN         NaN           NaN           NaN
# 17510              ZYNGA INC - CL A     ZNGAEUR  BBG005YZL376  BBG005YZL2R6
#
#       shareClassFIGI exchCode-FIGI marketSector-FIGI securityDescription-FIGI  \
# 0       BBG001V0RR30            US            Equity                     TWOU
# 1       BBG001SCV1F7            GR            Equity                      POQ
# 2       BBG00NG9S261            JP            Equity                     7063
# 3       BBG001SKMWN2            GR            Equity                     A2XN
# 4       BBG009CXGZ54            HK            Equity                     2686
# ...              ...           ...               ...                      ...
# 17506            NaN           NaN               NaN                      NaN
# 17507            NaN           NaN               NaN                      NaN
# 17508   BBG001SJS399            CN            Equity                    ZMD/H
# 17509            NaN           NaN               NaN                      NaN
# 17510   BBG001T24RN2            XS            Equity                  ZNGAEUR
#
#       securityType-FIGI securityType2-FIGI
# 0          Common Stock       Common Stock
# 1          Common Stock       Common Stock
# 2          Common Stock       Common Stock
# 3          Common Stock       Common Stock
# 4          Common Stock       Common Stock
# ...                 ...                ...
# 17506               NaN                NaN
# 17507               NaN                NaN
# 17508      Common Stock       Common Stock
# 17509               NaN                NaN
# 17510      Common Stock       Common Stock
#
# [17511 rows x 33 columns]

# %% [markdown]
# ### EOD & Investing.com

# %%
df_Name = df_withFIGI[['ISIN', 'full_name-Inv', 'Name-EOD']].dropna(subset=['full_name-Inv'])
df_Name = df_Name[['ISIN', 'full_name-Inv', 'Name-EOD']].dropna(subset=['Name-EOD'])

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['full_name-Inv'],row['Name-EOD'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])
df_match[df_match['fuzz_socre1']<60]
# Out:
# 5266
# progress: 0.00%
# progress: 9.99%
# progress: 19.98%
# progress: 29.97%
# progress: 39.95%
# progress: 49.94%
# progress: 59.93%
# progress: 69.92%
# progress: 79.91%
# progress: 89.90%
# progress: 99.89%
#               ISIN                  full_name-Inv  \
# 38    JP3108120001                    Acrodea Inc
# 53    LU1250154413              ADO Properties SA
# 78    US0077371096               AeroCentury Corp
# 165   US0185811082     Alliance Data Systems Corp
# 223   US0259321042   American Financial Group Inc
# ...            ...                            ...
# 4544  KYG857AT1018    Sun International Group Ltd
# 4573  JP3397150008    Sushiro Global Holdings Ltd
# 4757  JP3588600001  Tokyo Broadcasting System Inc
# 5056  PLGPW0000017       Warsaw Stock Exchange SA
# 5153  CNE000000024   Wuhan Department Store Group
#
#                                           Name-EOD  fuzz_socre1
# 38                               Why How Do Co Inc           50
# 53                                  Adler Group SA           58
# 78                                Mega Matrix Corp           25
# 165                   Bread Financial Holdings Inc           26
# 223                        Aquatic Foods Group plc           51
# ...                                            ...          ...
# 4544                  Imperium Financial Group Ltd           51
# 4573                     Food & Life Companies Ltd           24
# 4757                              TBS Holdings Inc           49
# 5056  Gielda Papierow Wartosciowych w Warszawie SA           41
# 5153                          Wushang Group Co Ltd           58
#
# [79 rows x 4 columns]

# %% [markdown]
# ### Investing.com & IB

# %%
df_Name = df_withFIGI[['ISIN', 'full_name-Inv', 'longName-IB']].dropna(subset=['full_name-Inv'])
df_Name = df_Name[['ISIN', 'full_name-Inv', 'longName-IB']].dropna(subset=['longName-IB'])

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['full_name-Inv'],row['longName-IB'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])
df_match[df_match['fuzz_socre1']<60]
# Out:
# 5563
# progress: 0.00%
# progress: 9.99%
# progress: 19.99%
# progress: 29.98%
# progress: 39.98%
# progress: 49.97%
# progress: 59.97%
# progress: 69.96%
# progress: 89.95%
# progress: 239.87%
# progress: 249.87%
#               ISIN                                   full_name-Inv  \
# 246   IL0010806136  Analyst IMS Investment Management Services Ltd
# 562   RU000A0HL5M1                                Beluga Group PAO
# 2779  US5006432000                        Korn/Ferry International
# 2965  IL0004730177     Amos Luzon Development and Energy Group Ltd
# 3794  PLPKO0000016     Powszechna Kasa Oszczednosci Bank Polski SA
# 4167  FR0006239109            Soc Centrale Bois Scieries Manche SA
#
#              longName-IB  fuzz_socre1
# 246       ANALYST I.M.S.           44
# 562               BELUGA           55
# 2779          KORN FERRY           59
# 2965         LUZON GROUP           41
# 3794  PKO BANK POLSKI SA           56
# 4167               SCBSM           15

# %% [markdown]
# ### FIGI & IB

# %%
df_Name = df_withFIGI[['ISIN', 'longName-FIGI', 'longName-IB']].dropna(subset=['longName-FIGI'])
df_Name = df_Name[['ISIN', 'longName-FIGI', 'longName-IB']].dropna(subset=['longName-IB'])

print(len(df_Name))

allD = []

for index, row in df_Name.iterrows():
    # calculate nlp scores
    fuzz_socre1 = fuzz.token_sort_ratio(row['longName-FIGI'],row['longName-IB'])
            
    row['fuzz_socre1'] = fuzz_socre1
    allD.append(row)
       

    if index % (len(df_Name)//10) == 0:
        print("progress: %.2f" % (100*index/len(df_Name)) + "%")

df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])
df_match[df_match['fuzz_socre1']<60]
# Out:
# 14946
# progress: 0.00%
# progress: 10.00%
# progress: 19.99%
# progress: 29.99%
# progress: 39.98%
# progress: 49.98%
# progress: 59.98%
# progress: 69.97%
# progress: 79.97%
# progress: 89.96%
#                ISIN                 longName-FIGI  \
# 196    CA02210D1033             TENAZ ENERGY CORP
# 370    US0441861046                   ASHLAND INC
# 533    IL0007590198        GAV-YAM LANDS CORP LTD
# 562    RU000A0HL5M1             BELUGA GROUP PJSC
# 1008   IL0004560129  UPSELLON BRANDS HOLDINGS LTD
# ...             ...                           ...
# 16577  US74838C1062               BOARDRIDERS INC
# 16581  US7472623013                       QVC INC
# 16690  SE0010520155                       ICTA AB
# 17055  US7847882005               STRATS-FON-04-2
# 17103  MHY8564M1057                   SEAPEAK LLC
#
#                                              longName-IB  fuzz_socre1
# 196                                    ALTURA ENERGY INC           59
# 370                          ASHLAND GLOBAL HOLDINGS INC           58
# 533                         BAYSIDE LAND CORPORATION LTD           56
# 562                                               BELUGA           52
# 1008                               CHIRON REFINERIES LTD           33
# ...                                                  ...          ...
# 16577                                     QUIKSILVER INC           21
# 16581                         QVC INC 6 3/8 09/13/67 PFD           42
# 16690                          ROLLING OPTICS HOLDING AB           31
# 17055  SYNTHETIC FIXED-INCOME SEC STRATS 2004-2, 6.50...           38
# 17103                             TEEKAY LNG PARTNERS LP           36
#
# [62 rows x 4 columns]
