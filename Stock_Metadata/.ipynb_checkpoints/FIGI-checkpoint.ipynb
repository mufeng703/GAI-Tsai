# %%
import requests     
import json         
import pandas as pd

# %%
path = "./withEOD.csv"

df = pd.read_csv(path)  
df
# Out:
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0          1ST   Australia          AUD           AU  AU0000001ST0
# 1          MMM         USA          USD           US  US88579Y1010
# 2          88E          UK          GBX          LSE  AU00000088E2
# 3         7063       Japan          JPY          TSE  JP3160590000
# 4         AMRK      Israel          ILA           TA  IL0010922040
# ...        ...         ...          ...          ...           ...
# 20041      NaN         NaN          NaN          NaN  NZZELE0001S1
# 20042      NaN         NaN          NaN          NaN  ZM0000000201
# 20043      NaN         NaN          NaN          NaN  CA98935P1080
# 20044      NaN         NaN          NaN          NaN  AU000000ZYB8
# 20045      NaN         NaN          NaN          NaN  US2836782092
#
#                                                 Name-EOD      Type-EOD  \
# 0                                       1stAvailable Ltd  Common Stock
# 1                                             3M Company  Common Stock
# 2                                          88 Energy Ltd  Common Stock
# 3                                           A Dot Co Ltd  Common Stock
# 4      Amir Marketing and Investments in Agriculture Ltd  Common Stock
# ...                                                  ...           ...
# 20041                                                NaN           NaN
# 20042                                                NaN           NaN
# 20043                                                NaN           NaN
# 20044                                                NaN           NaN
# 20045                                                NaN           NaN
#
#        previousClose-EOD previousCloseDate-EOD Ticker  ...      Country-IB  \
# 0                  0.008            2022-07-21    1ST  ...       Australia
# 1                133.950            2022-07-21    MMM  ...          Mexico
# 2                  0.725            2022-07-21    88E  ...  United Kingdom
# 3               2136.000            2022-07-21   7063  ...           Japan
# 4               3911.000            2022-07-21   AMRK  ...          Israel
# ...                  ...                   ...    ...  ...             ...
# 20041                NaN                   NaN    ZEL  ...       Australia
# 20042                NaN                   NaN    ZAM  ...  United Kingdom
# 20043                NaN                   NaN    ZEN  ...          Canada
# 20044                NaN                   NaN    ZYB  ...       Australia
# 20045                NaN                   NaN  EP_pc  ...             NaN
#
#        Exchange-IB Currency-IB     ISIN-19.7       ISIN-IB  \
# 0              ASX         AUD           NaN  AU0000001ST0
# 1      US Exchange         NaN           NaN           NaN
# 2              LSE         GBP  AU00000088E2  AU00000088E2
# 3             TSEJ         JPY  JP3160590000  JP3160590000
# 4             TASE         ILS           NaN  IL0010922040
# ...            ...         ...           ...           ...
# 20041          ASX         AUD  NZZELE0001S1  NZZELE0001S1
# 20042          LSE         GBP           NaN  ZM0000000201
# 20043      VENTURE         CAD  CA98935P1080  CA98935P1080
# 20044          ASX         AUD  AU000000ZYB8  AU000000ZYB8
# 20045          NaN         NaN           NaN           NaN
#
#                    Name-Investing.com Exchange-Investing.com  \
# 0                                 NaN                    NaN
# 1                          3M Company                   NYSE
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
# ...                               ...                    ...
# 20041                             NaN                    NaN
# 20042                             NaN                    NaN
# 20043                             NaN                    NaN
# 20044                             NaN                    NaN
# 20045  El Paso Energy Capital Trust I                   NYSE
#
#       Type-Investing.com Market-Investing.com CUSIP-Investing.com
# 0                    NaN                  NaN                 NaN
# 1                 Equity        United States           88579Y101
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# ...                  ...                  ...                 ...
# 20041                NaN                  NaN                 NaN
# 20042                NaN                  NaN                 NaN
# 20043                NaN                  NaN                 NaN
# 20044                NaN                  NaN                 NaN
# 20045             Equity        United States           283678209
#
# [20046 rows x 21 columns]

# %%
ticker_list = list(df['Ticker'].unique())[:100]

# %%
jobs = []
for i in ticker_list:
    s = "{'idType': 'TICKER', 'idValue': '" + str(i) + "'}"
    json_acceptable_string = s.replace("'", "\"")
    d = json.loads(json_acceptable_string)
    jobs.append(d)

openfigi_apikey = '71aaa940-3567-4040-bce5-9f43490a7703' # GAI
# openfigi_apikey = '6531f095-b68a-44c2-9749-20b3b75f9ad8'
openfigi_url = 'https://api.openfigi.com/v2/mapping'
openfigi_headers = {'Content-Type': 'text/json'}

# %%
def map_jobs(jobs):
    if openfigi_apikey:
        openfigi_headers['X-OPENFIGI-APIKEY'] = openfigi_apikey
    response = requests.post(url=openfigi_url, 
                             headers=openfigi_headers,
                             json=jobs)
    if response.status_code != 200:
        raise Exception('Bad response code {}'.format(str(response.status_code)))
    return response.json()

# %%
job_results = map_jobs(jobs)

# %%
len(job_results)==len(ticker_list)
# Out:
# True

# %%
# Extract figi from scrape results
figi_value = [] # store figi information
figi_count = [] # keep track of the number of each symbol's corresponding figi
for d in job_results:
    if 'data' in d:
        figi_count.append(len(d['data']))
        for i in range(len(d['data'])):            
            figi_value.append(d['data'][i])
    else:
        figi_count.append(0)
df_figi = pd.DataFrame.from_dict(figi_value)
print(df_figi.shape)
print(len(figi_count)==len(ticker_list))
df_figi
# Out:
# (1332, 12)
# True
#               figi                name ticker exchCode compositeFIGI uniqueID  \
# 0     BBG008HNLRF4       1ST GROUP LTD    1ST       AU  BBG008HNLRF4     None
# 1     BBG008LMMN69       1ST GROUP LTD    1ST       AT  BBG008HNLRF4     None
# 2     BBG008LMMNB3       1ST GROUP LTD    1ST       AH  BBG008HNLRF4     None
# 3     BBG000BBK8C9  MINCO CAPITAL CORP    MMM       CN  BBG000BBK8C9     None
# 4     BBG000BBKB69  MINCO CAPITAL CORP    MMM       CV  BBG000BBK8C9     None
# ...            ...                 ...    ...      ...           ...      ...
# 1327  BBG00HML4ZZ1      ADLER GROUP SA    ADJ       GZ  BBG00HML4ZY2     None
# 1328  BBG00HMXT619      ADLER GROUP SA    ADJ       AV  BBG00HMXT600     None
# 1329  BBG00HPS3KW0      ADLER GROUP SA    ADJ       SW  BBG00HPS3KW0     None
# 1330  BBG00HPS3L21      ADLER GROUP SA    ADJ       BW  BBG00HPS3KW0     None
# 1331  BBG00KG3Y3D3      ADLER GROUP SA    ADJ       TE  BBG00KG3Y3C4     None
#
#       securityType marketSector shareClassFIGI uniqueIDFutOpt securityType2  \
# 0     Common Stock       Equity   BBG008HNLRG3           None  Common Stock
# 1     Common Stock       Equity   BBG008HNLRG3           None  Common Stock
# 2     Common Stock       Equity   BBG008HNLRG3           None  Common Stock
# 3     Common Stock       Equity   BBG001S5ZLY3           None  Common Stock
# 4     Common Stock       Equity   BBG001S5ZLY3           None  Common Stock
# ...            ...          ...            ...            ...           ...
# 1327  Common Stock       Equity   BBG009BWH892           None  Common Stock
# 1328  Common Stock       Equity   BBG009BWH892           None  Common Stock
# 1329  Common Stock       Equity   BBG009BWH892           None  Common Stock
# 1330  Common Stock       Equity   BBG009BWH892           None  Common Stock
# 1331  Common Stock       Equity   BBG009BWH892           None  Common Stock
#
#      securityDescription
# 0                    1ST
# 1                    1ST
# 2                    1ST
# 3                    MMM
# 4                    MMM
# ...                  ...
# 1327                 ADJ
# 1328                 ADJ
# 1329                 ADJ
# 1330                 ADJ
# 1331                 ADJ
#
# [1332 rows x 12 columns]

# %%
# extract useful information and rename
df_res = df_figi[['name', 'ticker', 'figi', 'compositeFIGI', 'shareClassFIGI', 'exchCode', 'marketSector', 'securityDescription', 'securityType', 'securityType2']].rename(columns = {'name':'longName', 'ticker':'symbol'})
df_res
# Out:
#                 longName symbol          figi compositeFIGI shareClassFIGI  \
# 0          1ST GROUP LTD    1ST  BBG008HNLRF4  BBG008HNLRF4   BBG008HNLRG3
# 1          1ST GROUP LTD    1ST  BBG008LMMN69  BBG008HNLRF4   BBG008HNLRG3
# 2          1ST GROUP LTD    1ST  BBG008LMMNB3  BBG008HNLRF4   BBG008HNLRG3
# 3     MINCO CAPITAL CORP    MMM  BBG000BBK8C9  BBG000BBK8C9   BBG001S5ZLY3
# 4     MINCO CAPITAL CORP    MMM  BBG000BBKB69  BBG000BBK8C9   BBG001S5ZLY3
# ...                  ...    ...           ...           ...            ...
# 1327      ADLER GROUP SA    ADJ  BBG00HML4ZZ1  BBG00HML4ZY2   BBG009BWH892
# 1328      ADLER GROUP SA    ADJ  BBG00HMXT619  BBG00HMXT600   BBG009BWH892
# 1329      ADLER GROUP SA    ADJ  BBG00HPS3KW0  BBG00HPS3KW0   BBG009BWH892
# 1330      ADLER GROUP SA    ADJ  BBG00HPS3L21  BBG00HPS3KW0   BBG009BWH892
# 1331      ADLER GROUP SA    ADJ  BBG00KG3Y3D3  BBG00KG3Y3C4   BBG009BWH892
#
#      exchCode marketSector securityDescription  securityType securityType2
# 0          AU       Equity                 1ST  Common Stock  Common Stock
# 1          AT       Equity                 1ST  Common Stock  Common Stock
# 2          AH       Equity                 1ST  Common Stock  Common Stock
# 3          CN       Equity                 MMM  Common Stock  Common Stock
# 4          CV       Equity                 MMM  Common Stock  Common Stock
# ...       ...          ...                 ...           ...           ...
# 1327       GZ       Equity                 ADJ  Common Stock  Common Stock
# 1328       AV       Equity                 ADJ  Common Stock  Common Stock
# 1329       SW       Equity                 ADJ  Common Stock  Common Stock
# 1330       BW       Equity                 ADJ  Common Stock  Common Stock
# 1331       TE       Equity                 ADJ  Common Stock  Common Stock
#
# [1332 rows x 10 columns]
