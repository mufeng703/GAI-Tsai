# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import datetime
from scipy import stats
import os

# %% [markdown]
# It should have a dropdown menu to show the columns, and several types of graphs to show the data available and the gaps, as well as descriptive statistics for the metadata and the SDG dataset.  The analysis should be for each SDG, GICS Sector, Country, and the relationship between them via heatmaps and other visualizations.

# %%
path = "../Data/withFIGI.csv"
df_metadata = pd.read_csv(path, low_memory=False)

df_metadata
# Out:
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0         TWOU         USA          USD           US  US90214J1016
# 1          88E          UK          GBX          LSE  AU00000088E2
# 2         7063       Japan          JPY          TSE  JP3160590000
# 3         2018   Hong Kong          HKD           HK  KYG2953R1149
# 4         2686   Hong Kong          HKD           HK  KYG000371040
# ...        ...         ...          ...          ...           ...
# 17506      NaN         NaN          NaN          NaN  US98979J1097
# 17507      NaN         NaN          NaN          NaN  CA98977K1084
# 17508      NaN         NaN          NaN          NaN  CA98977R1038
# 17509      NaN         NaN          NaN          NaN  GB00BMHTHT14
# 17510      NaN         NaN          NaN          NaN  US98986T1088
#
#                             Name-EOD      Type-EOD  previousClose-EOD  \
# 0                             2U Inc  Common Stock              9.200
# ...

# %%
path = "../Data/LIst of 19.7 Stocks with FIGI if available - By Evelyn.xlsx"
df_197 = pd.read_excel(path, index_col=0)

df_197
# Out:
#       symbol_x                      longName     Exchange  \
# 0          1ST                 1ST GROUP LTD          ASX
# 1         TWOU                        2U INC       NASDAQ
# 2         DDDX            3DX INDUSTRIES INC         PINK
# 3          MMM                         3M CO  US Exchange
# 4          88E                 88 ENERGY LTD          LSE
# ...        ...                           ...          ...
# 19731     ZYNE   ZYNERBA PHARMACEUTICALS INC       NASDAQ
# 19732     ZYXI                     ZYNEX INC       NASDAQ
# 19733     ZNGA              ZYNGA INC - CL A       NASDAQ
# 19734      ZYT                  ZYTRONIC PLC          LSE
# 19735     8295  ZZ CAPITAL INTERNATIONAL LTD         SEHK
#
#                         Country                   country  \
# 0                     Australia                 australia
# 1      United States of America  united states of america
# 2      United States of America  united states of america
# ...

# %%
df_197 = df_197.rename(columns = {'longName':'Name_197'})
df_metadata = df_metadata[df_metadata['Name_197'].notna()]
df_metadata = pd.merge(df_197['Name_197'], df_metadata, how='outer', on='Name_197').drop_duplicates(subset=['Name_197'])

df_metadata
# Out:
#                            Name_197 Code-EOD Country-EOD Currency-EOD  \
# 0                     1ST GROUP LTD      1ST   Australia          AUD
# 1                            2U INC     TWOU         USA          USD
# 2                3DX INDUSTRIES INC     DDDX         USA          USD
# 3                             3M CO      MMM         USA          USD
# 4                     88 ENERGY LTD      88E          UK          GBX
# ...                             ...      ...         ...          ...
# 20293   ZYNERBA PHARMACEUTICALS INC     ZYNE         USA          USD
# 20294                     ZYNEX INC     ZYXI         USA          USD
# 20295              ZYNGA INC - CL A      NaN         NaN          NaN
# 20296                  ZYTRONIC PLC      ZYT          UK          GBX
# 20297  ZZ CAPITAL INTERNATIONAL LTD      NaN         NaN          NaN
#
#       Exchange-EOD          ISIN                     Name-EOD      Type-EOD  \
# ...

# %%
df_eod = df_metadata.iloc[:, 1:9].dropna()

df_eod
# Out:
#         Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0            1ST   Australia          AUD           AU  AU0000001ST0
# 1           TWOU         USA          USD           US  US90214J1016
# 2           DDDX         USA          USD           US  US88556A1007
# 3            MMM         USA          USD           US  US88579Y1010
# 4            88E          UK          GBX          LSE  AU00000088E2
# ...          ...         ...          ...          ...           ...
# 20291  ZYDUSWELL       India          INR          NSE  INE768C01010
# 20292       ZYME         USA          USD           US  CA98985W1023
# 20293       ZYNE         USA          USD           US  US98986X1090
# 20294       ZYXI         USA          USD           US  US98986M1036
# 20296        ZYT          UK          GBX          LSE  GB0006971013
#
#                           Name-EOD      Type-EOD  previousClose-EOD
# 0                 1stAvailable Ltd  Common Stock              0.010
# ...

# %%
df_inv = df_metadata.iloc[:, 10:15]
df_inv['ISIN'] = df_metadata['ISIN']
df_inv.dropna(inplace = True)

df_inv
# Out:
#           country-Inv                 name-Inv                  full_name-Inv  \
# 1       united states                   2U Inc                         2U Inc
# 4      united kingdom                88 Energy                  88 Energy Ltd
# 6               japan                    A Dot                   A Dot Co Ltd
# 13          hong kong         AAC Technologies  AAC Technologies Holdings Inc
# 14          hong kong  AAG Energy Holdings Ltd        AAG Energy Holdings Ltd
# ...               ...                      ...                            ...
# 20281   united states                   Zumiez                     Zumiez Inc
# 20286     switzerland   Zurich Insurance Group      Zurich Insurance Group AG
# 20288           japan                      ZUU                     ZUU Co Ltd
# 20290       australia           Zyber Holdings             Zyber Holdings Ltd
# 20297       hong kong          ZZ Capital Intl   ZZ Capital International Ltd
#
# ...

# %%
df_ib = df_metadata.iloc[:, 16:23]
df_ib['ISIN'] = df_metadata['ISIN']
df_ib.dropna(inplace = True)

df_ib
# Out:
#                   industry-IB              longName-IB marketName-IB  \
# 0              Communications            1ST GROUP LTD           1ST
# 4                      Energy            88 ENERGY LTD           88E
# 8                  Industrial      A TOUTE VITESSE-ATV         MLATV
# 14                     Energy  AAG ENERGY HOLDINGS LTD          2686
# 17                 Industrial     AARON INDUSTRIES LTD         AARON
# ...                       ...                      ...           ...
# 20288          Communications               ZUU CO LTD          4387
# 20289  Consumer, Non-cyclical          ZWACK UNICUM RT         ZWACK
# 20290              Technology       ZYBER HOLDINGS LTD           ZYB
# 20291  Consumer, Non-cyclical       ZYDUS WELLNESS LTD     ZYDUSWELL
# 20296              Industrial             ZYTRONIC PLC          ASQ1
#
#        Symbol-IB      Country-IB Exchange-IB Currency-IB          ISIN
# ...

# %%
df_figi = df_metadata.iloc[:, 24:]
df_figi['ISIN'] = df_metadata['ISIN']
df_figi.dropna(inplace = True)

df_figi
# Out:
#       symbol-FIGI          figi compositeFIGI shareClassFIGI exchCode-FIGI  \
# 0             1ST  BBG008HNLRF4  BBG008HNLRF4   BBG008HNLRG3            AU
# 1            TWOU  BBG001KS9450  BBG001KS9450   BBG001V0RR30            US
# 2            DDDX  BBG000C129N6  BBG000C129N6   BBG001STRH79            US
# 3             MMM  BBG000BP52R2  BBG000BP52R2   BBG001S5T7X2            US
# 4             POQ  BBG000BWTTK9  BBG000BWTTK9   BBG001SCV1F7            GR
# ...           ...           ...           ...            ...           ...
# 20292        ZYME  BBG00GD15LJ5  BBG00GD15LJ5   BBG00247P1W0            US
# 20293        ZYNE  BBG007BBS8B7  BBG007BBS8B7   BBG007BBS8C6            US
# 20294        ZYXI  BBG000BJBXZ2  BBG000BJBXZ2   BBG001S7T7V0            US
# 20295     ZNGAEUR  BBG005YZL376  BBG005YZL2R6   BBG001T24RN2            XS
# 20296         ZYT  BBG000BZPV76  BBG000BZPTJ8   BBG001SFLP13            LN
#
# ...
