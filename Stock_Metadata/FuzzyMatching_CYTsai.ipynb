# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# load data
path1 = "./Data/withEOD.csv"
path2 = "./Data/metaData_IB_Inv.csv"

df_IB_Inv = pd.read_csv(path2) 
df_eod = pd.read_csv(path1)  

df_eod
# Out:
#       Code-EOD Country-EOD Currency-EOD Exchange-EOD          ISIN  \
# 0         TWOU         USA          USD           US  US90214J1016
# 1          88E          UK          GBX          LSE  AU00000088E2
# 2         7063       Japan          JPY          TSE  JP3160590000
# 3         2018   Hong Kong          HKD           HK  KYG2953R1149
# 4         2686   Hong Kong          HKD           HK  KYG000371040
# ...        ...         ...          ...          ...           ...
# 17506      NaN         NaN          NaN          NaN  US98979J1097
# 17507      NaN         NaN          NaN          NaN  CA98977K1084
# 17508      NaN         NaN          NaN          NaN  CA98977R1038
# 17509      NaN         NaN          NaN          NaN  GB00BMHTHT14
# 17510      NaN         NaN          NaN          NaN  US98986T1088
#
#                             Name-EOD      Type-EOD  previousClose-EOD  \
# 0                             2U Inc  Common Stock              9.200
# 1                      88 Energy Ltd  Common Stock              0.625
# 2                       A Dot Co Ltd  Common Stock           2064.000
# 3      AAC Technologies Holdings Inc  Common Stock             14.580
# 4            AAG Energy Holdings Ltd  Common Stock              1.410
# ...                              ...           ...                ...
# 17506                            NaN           NaN                NaN
# 17507                            NaN           NaN                NaN
# 17508                            NaN           NaN                NaN
# 17509                            NaN           NaN                NaN
# 17510                            NaN           NaN                NaN
#
#       previousCloseDate-EOD     country-Inv  ... symbol-Inv asset_class-Inv  \
# 0                2022-08-02   united states  ...       TWOU          equity
# 1                2022-08-03  united kingdom  ...        88E          equity
# 2                2022-08-03           japan  ...       7063          equity
# 3                2022-08-03       hong kong  ...       2018          equity
# 4                2022-08-03       hong kong  ...       2686          equity
# ...                     ...             ...  ...        ...             ...
# 17506                   NaN             NaN  ...        NaN             NaN
# 17507                   NaN             NaN  ...        NaN             NaN
# 17508                   NaN             NaN  ...        NaN             NaN
# 17509                   NaN             NaN  ...        NaN             NaN
# 17510                   NaN             NaN  ...        NaN             NaN
#
#                            Name_197             industry-IB  \
# 0                            2U INC  Consumer, Non-cyclical
# 1                     88 ENERGY LTD                  Energy
# 2                      A DOT CO LTD                     NaN
# 3      AAC TECHNOLOGIES HOLDINGS IN              Industrial
# 4           AAG ENERGY HOLDINGS LTD                  Energy
# ...                             ...                     ...
# 17506             ZOE'S KITCHEN INC      Consumer, Cyclical
# 17507          ZOLOTO RESOURCES LTD         Basic Materials
# 17508                   ZOOMMED INC              Technology
# 17509                       ZPG PLC          Communications
# 17510              ZYNGA INC - CL A              Technology
#
#                         longName-IB marketName-IB Symbol-IB      Country-IB  \
# 0                            2U INC           NMS      TWOU             NaN
# 1                     88 ENERGY LTD           88E       88E  United Kingdom
# 2                               NaN           NaN       NaN             NaN
# 3      AAC TECHNOLOGIES HOLDINGS IN          2018      2018             NaN
# 4           AAG ENERGY HOLDINGS LTD          2686      2686       Hong Kong
# ...                             ...           ...       ...             ...
# 17506             ZOE'S KITCHEN INC          ZOES      ZOES             NaN
# 17507          ZOLOTO RESOURCES LTD            ZR        ZR             NaN
# 17508                   ZOOMMED INC         ZMD.H     ZMD.H             NaN
# 17509                       ZPG PLC           ZPG       ZPG             NaN
# 17510              ZYNGA INC - CL A          ZNGA      ZNGA             NaN
#
#       Exchange-IB Currency-IB
# 0             NaN         NaN
# 1             LSE         GBP
# 2             NaN         NaN
# 3             NaN         NaN
# 4            SEHK         HKD
# ...           ...         ...
# 17506         NaN         NaN
# 17507         NaN         NaN
# 17508         NaN         NaN
# 17509         NaN         NaN
# 17510         NaN         NaN
#
# [17511 rows x 23 columns]

# %%
# Select the ISIN Column for merging and the Name Column for matching
df_eodName = df_eod[['ISIN', 'Name-EOD']].dropna(subset=['Name-EOD'])
df_name197 = df_IB_Inv[['ISIN', 'Name_197']]

df_eodName
# Out:
#                ISIN                       Name-EOD
# 0      US90214J1016                         2U Inc
# 1      AU00000088E2                  88 Energy Ltd
# 2      JP3160590000                   A Dot Co Ltd
# 3      KYG2953R1149  AAC Technologies Holdings Inc
# 4      KYG000371040        AAG Energy Holdings Ltd
# ...             ...                            ...
# 13025  INE768C01010         Zydus Wellness Limited
# 13026  CA98985W1023                  Zymeworks Inc
# 13027  US98986X1090    Zynerba Pharmaceuticals Inc
# 13028  US98986M1036                      Zynex Inc
# 13029  GB0006971013                       Zytronic
#
# [13030 rows x 2 columns]

# %%
# Inner Merge dfs on ISIN 
# This is the sample input data
df_name = pd.merge(df_name197, df_eodName, how='inner', on='ISIN')

df_name
# Out:
#                ISIN                      Name_197  \
# 0      US90214J1016                        2U INC
# 1      AU00000088E2                 88 ENERGY LTD
# 2      JP3160590000                  A DOT CO LTD
# 3      KYG2953R1149  AAC TECHNOLOGIES HOLDINGS IN
# 4      KYG000371040       AAG ENERGY HOLDINGS LTD
# ...             ...                           ...
# 13153  INE768C01010            ZYDUS WELLNESS LTD
# 13154  CA98985W1023                 ZYMEWORKS INC
# 13155  US98986X1090   ZYNERBA PHARMACEUTICALS INC
# 13156  US98986M1036                     ZYNEX INC
# 13157  GB0006971013                  ZYTRONIC PLC
#
#                             Name-EOD
# 0                             2U Inc
# 1                      88 Energy Ltd
# 2                       A Dot Co Ltd
# 3      AAC Technologies Holdings Inc
# 4            AAG Energy Holdings Ltd
# ...                              ...
# 13153         Zydus Wellness Limited
# 13154                  Zymeworks Inc
# 13155    Zynerba Pharmaceuticals Inc
# 13156                      Zynex Inc
# 13157                       Zytronic
#
# [13158 rows x 3 columns]

# %%
# Match by Name (The Name columns must be 2nd and 3rd columns of the input dataframe)

def matchByName(df_name):
    allD = []

    for index, row in df_name.iterrows():
        # calculate nlp scores
        fuzz_socre1 = fuzz.token_sort_ratio(row[1],row[2]) 
        
        # list append fuzz result
        row['fuzz_score1'] = fuzz_socre1
        allD.append(row)
       
        # print progress
        if index % (len(df_name)//10) == 0:
            print("progress: %.2f" % (100*index/len(df_name)) + "%")
    
    # list to df and drop duplicates
    df_match = pd.DataFrame(allD).drop_duplicates(subset=['ISIN'])
    
    return df_match

# %%
df_nameMatch = matchByName(df_name) # Company names columns be at 2nd and 3rd columns of the input dataframe

df_nameMatch
# Out:
# progress: 0.00%
# progress: 9.99%
# progress: 19.99%
# progress: 29.98%
# progress: 39.98%
# progress: 49.97%
# progress: 59.96%
# progress: 69.96%
# progress: 79.95%
# progress: 89.95%
# progress: 99.94%
#                ISIN                      Name_197  \
# 0      US90214J1016                        2U INC
# 1      AU00000088E2                 88 ENERGY LTD
# 2      JP3160590000                  A DOT CO LTD
# 3      KYG2953R1149  AAC TECHNOLOGIES HOLDINGS IN
# 4      KYG000371040       AAG ENERGY HOLDINGS LTD
# ...             ...                           ...
# 13153  INE768C01010            ZYDUS WELLNESS LTD
# 13154  CA98985W1023                 ZYMEWORKS INC
# 13155  US98986X1090   ZYNERBA PHARMACEUTICALS INC
# 13156  US98986M1036                     ZYNEX INC
# 13157  GB0006971013                  ZYTRONIC PLC
#
#                             Name-EOD  fuzz_score1
# 0                             2U Inc          100
# 1                      88 Energy Ltd          100
# 2                       A Dot Co Ltd          100
# 3      AAC Technologies Holdings Inc           98
# 4            AAG Energy Holdings Ltd          100
# ...                              ...          ...
# 13153         Zydus Wellness Limited           90
# 13154                  Zymeworks Inc          100
# 13155    Zynerba Pharmaceuticals Inc          100
# 13156                      Zynex Inc          100
# 13157                       Zytronic           80
#
# [13016 rows x 4 columns]

# %%
# select rows with score >80

df_nameMatch[df_nameMatch['fuzz_score1']>80]
# Out:
#                ISIN                      Name_197  \
# 0      US90214J1016                        2U INC
# 1      AU00000088E2                 88 ENERGY LTD
# 2      JP3160590000                  A DOT CO LTD
# 3      KYG2953R1149  AAC TECHNOLOGIES HOLDINGS IN
# 4      KYG000371040       AAG ENERGY HOLDINGS LTD
# ...             ...                           ...
# 13150  CNE100001TL0  ZUOLI KECHUANG MICRO-FINAN-H
# 13153  INE768C01010            ZYDUS WELLNESS LTD
# 13154  CA98985W1023                 ZYMEWORKS INC
# 13155  US98986X1090   ZYNERBA PHARMACEUTICALS INC
# 13156  US98986M1036                     ZYNEX INC
#
#                                   Name-EOD  fuzz_score1
# 0                                   2U Inc          100
# 1                            88 Energy Ltd          100
# 2                             A Dot Co Ltd          100
# 3            AAC Technologies Holdings Inc           98
# 4                  AAG Energy Holdings Ltd          100
# ...                                    ...          ...
# 13150  Zuoli Kechuang Micro-finance Co Ltd           83
# 13153               Zydus Wellness Limited           90
# 13154                        Zymeworks Inc          100
# 13155          Zynerba Pharmaceuticals Inc          100
# 13156                            Zynex Inc          100
#
# [11478 rows x 4 columns]

# %%
# select rows with score >80

df_nameMatch[df_nameMatch['fuzz_score1']>80]

# %%
print("Done")
# Out:
# Done
